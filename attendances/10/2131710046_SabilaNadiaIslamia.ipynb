// %% [markdown]
// ### NAMA : SABILA NADIA ISLAMIA
// ### NIM : 2131710046
//
//
// # JOBSHEET 10 - Array 1
//
// ## Tujuan
// + Mahasiswa mampu memahami pembuatan Array 1 dimensi dan pengaksesan elemenya di Java.
// + Mahasiswa mampu membuat program dengan menggunakan konsep array satu dimensi.
//
//
// ## Alat dan Bahan
// + PC/laptop
// + Browser(chrome, firefox, safari)
// + Koneksi internet
// + Anaconda3 + Java kernel (opsional)
//
// ## Praktikum
// ### Percobaan 1: Mengisi Elemen Array
// 1. Pada percobaan ke-1 akan dilakukan percobaan untuk mengisi elemen array. Buat array bertipe integer dengan nama bil dengan kapasitas 4 elemen.
// ![Gambar 0](images/P1L2.png)

// %%
// Tulis Kode program Percobaan 1 Langkah 2 di atas
int[] bil = new int[4];

// %% [markdown]
// 2. Isi masing-masing elemen array bil tadi dengan angka 5, 12, 7, 20.
// ![Gambar 0](images/P1L3.png)

// %%
// Tulis Kode program Percobaan 1 Langkah 3 di atas
bil[0] = 5; 
bil[1] = 12; 
bil[2] = 7; 
bil[3] = 20;
// Out:
// 20

// %% [markdown]
// 3. Tampilkan ke layar semua isi elemennya:
// ![Gambar 4](images/P1L4.png)

// %%
// Tulis Kode program Percobaan 1 Langkah 4
System.out.println(bil[0]);
System.out.println(bil[1]);
System.out.println(bil[2]);
System.out.println(bil[3]);
// Out:
// 5
// 12
// 7
// 20

// %% [markdown]
// #### Pertanyaan
// 1. Dari percobaan 1 berapakah indeks array terbesar dan terkecil?

// %% [markdown]
// // Tulis Jawaban no 1 disini
//
// Dari percobaan 1 indeks Array yang terbesar adalah 3, bernilai 20. Lalu indeks yang terkecil adalah 0, bernilai 5.

// %% [markdown]
// 2. Jika Isi masing-masing elemen array bil diubah dengan angka 5.0, 12867, 7.5, 2000000. Apa yang terjadi? Mengapa bisa demikian?

// %%
// Tulis Jawaban no 2 yang disini
int[] bil = new int[4];
bil[0] = 5.0; 
bil[1] = 12867; 
bil[2] = 7.5; 
bil[3] = 2000000; 
System.out.println(bil[0]);
System.out.println(bil[1]);
System.out.println(bil[2]);
System.out.println(bil[3]);
// Out:
// |   bil[0] = 5.0;
// incompatible types: possible lossy conversion from double to int

// %% [markdown]
// Penjelasan dari Pertanyaan 2
//
// Jika perubahan elemen dilakukan maka akan terjadi error seperti percobaan diatas. Karena tipe data yang di deklarasikan di awal adalah integer. Sehingga ketika nilai atau elemen diubah menjadi nilai desimal (double), pecahan (float), atau bilangan apa saja selain bilangan bulat (integer) maka akan terjadi errror.

// %% [markdown]
// 3. Ubah statement pada langkah No 3 menjadi seperti berikut
// ![Gambar pertanyaan 3](images/P1T3.png)
// Apa keluaran dari program? Mengapa bisa demikian?

// %%
// Tulis Jawaban no 3 yang disini
int[] bil = new int[4];
bil[0] = 5; 
bil[1] = 12; 
bil[2] = 7; 
bil[3] = 20; 
for(int i=0; i<4; i++){
    System.out.println(bil[i]);
}
// Out:
// 5
// 12
// 7
// 20

// %% [markdown]
// Penjelasan Pertanyaan Nomer 3
//
// Statement tersebut merupakan statement perualangan. Perulangan tersebut dapat digunakan sebagai cara untuk menampilkan nilai pada output secara lebih ringkas. Kita bisa menginisialisai nilai i dengan 0, lalu membuat syarat perulangan kurang dari 4 dan menambah nilai i pada setiap perulangan. Jika kita lihat pada baris System.out.println(bil[i]);
// Kita dapat mengetahui bahwa program akan menampilkan nilai atau elemen dr i yang dimulai dari indeks 0, yaitu bernilai 5. Begitu seterusnya, sesuai dengan pertambahan nilai pada perulangan.

// %% [markdown]
// ### Percobaan 2: Meminta Inputan Pengguna untuk Mengisi Elemen Array
// 1. Pada percobaan ke-2 akan dilakukan percobaan yang meminta inputan pengguna untuk mengisi elemen array seperti pada flowchart berikut
// ![Gambar Flowchart](images/FCpercobaan2.png)

// %%
// Tulis Kode program Percobaan 2 Langkah 1 di atas

// %% [markdown]
// 2. Import dan deklarasikan Scanner untuk keperluan input.
// ![Gambar import scanner](images/P2L2.png)

// %%
// Tulis Kode program Percobaan 2 Langkah 1 di atas
import java.util.Scanner;
Scanner sc = new Scanner(System.in);

// %% [markdown]
// 3. Buat array bertipe integer dengan nama nilaiUAS, dengan kapasitas 6 elemen.
// ![Gambar deklarasi array](images/P2L3.png)

// %%
// Tulis Kode program Percobaan 2 Langkah 3 di atas
int[] nilaiUAS = new int[6];

// %% [markdown]
// 4. Menggunakan perulangan, buat input untuk mengisi elemen dari array nilaiUAS.
// ![Gambar perulangan input](images/P2L4.png)

// %%
// Tulis Kode program Percobaan 2 Langkah 4 di atas
for(int i = 0; i < 6; i++){
    System.out.print("Masukkan nilai UAS ke- " + i + ": ");
    nilaiUAS[i] = sc.nextInt();
}
// Out:
// Masukkan nilai UAS ke- 0: 7
// Masukkan nilai UAS ke- 1: 8
// Masukkan nilai UAS ke- 2: 9
// Masukkan nilai UAS ke- 3: 10
// Masukkan nilai UAS ke- 4: 10
// Masukkan nilai UAS ke- 5: 10

// %% [markdown]
// 5. Menggunakan perulangan, tampilkan semua isi elemen dari array nilaiUAS.
// ![Gambar perulangan print](images/P2L5.png)

// %%
// Tulis Kode program Percobaan 2 Langkah 5 di atas
for(int i = 0; i < 6; i++){
    System.out.println("Nilai UAS ke- " + i + " adalah: " + nilaiUAS[i]);
}
// Out:
// Nilai UAS ke- 0 adalah: 7
// Nilai UAS ke- 1 adalah: 8
// Nilai UAS ke- 2 adalah: 9
// Nilai UAS ke- 3 adalah: 10
// Nilai UAS ke- 4 adalah: 10
// Nilai UAS ke- 5 adalah: 10

// %% [markdown]
// #### Pertanyaan
// 1. Ubah statement pada langkah No 4 menjadi seperti berikut ini :
// ![Gambar pertanyaan1](images/P2T1.png)
// Jalankan program, apakah terjadi perubahan? Mengapa demikian?

// %%
// Tulis Jawaban nomor 1 disini
for(int i = 0; i < nilaiUAS.length; i++){
    System.out.print("Masukkan nilai UAS ke- " + i + ": "); 
    nilaiUAS[i] = sc.nextInt(); 
}
// Out:
// Masukkan nilai UAS ke- 0: 7
// Masukkan nilai UAS ke- 1: 8
// Masukkan nilai UAS ke- 2: 9
// Masukkan nilai UAS ke- 3: 10
// Masukkan nilai UAS ke- 4: 10
// Masukkan nilai UAS ke- 5: 10

// %% [markdown]
// 2. Apa kegunaan dari `nilaiUAS.length`?

// %%
// Tulis Jawaban nomor 2 disini
nilaiUAS.length merupakan suatu atribut yang berguna untuk menunjukkan jumlah dari Array atau total element. 
    Sintaks terebut akan mengambil total dari nilai yang telah di deklarasikan dan di instansiasi di awal, yaitu 
    
    int[] nilaiUAS = new int[6]; 

maka akan sama saja seperti i < 6;

// %% [markdown]
// 3. Ubah statement pada langkah No 5 menjadi seperti berikut ini sehingga program hanya menampilkan status mahasiswa yang lulus saja:
// ![Gambar pertanyaan1](images/P2T3.png)
// Jalankan program dan Jelaskan alur program!

// %%
// Tulis Jawaban nomor 3 disini
for(int i = 0; i < nilaiUAS.length; i++){
    if(nilaiUAS[i] > 70){
        System.out.println("Mahasiswa ke- " + i + " lulus.");
    }
}

// %% [markdown]
// ### Percobaan 3: Melakukan Operasi Aritmatika terhadap Elemen Array
// Pada praktikum ini, akan dilakukan percobaan untuk menjumlahkan Array. Program akan menerima input sebanyak 10 nilai mahasiswa. Kemudian program akan menampilkan nilai rata-rata nilai dari 10 Mahasiswa. Seperti flowchart berikut
// ![Gambar flowchart](images/FCpercobaan3.png)
//
// 1.Import dan deklarasikan Scanner untuk keperluan input.
// ![Gambar deklarasi scanner](images/P3L1.png)

// %%
// Tulis Kode program Percobaan 3 Langkah 1 di atas, disini
import java.util.Scanner;
Scanner sc = new Scanner(System.in);

// %% [markdown]
// 2. Buat array nilaiMHS bertipe integer dengan kapasitas 10. Kemudian deklarasikan variable total dan rata seperti gambar berikut ini
// ![Gambar deklarasi variabel](images/P3L2.png)

// %%
// Tulis Kode program Percobaan 3 Langkah 2 di atas, disini
int nilaiMHS[] = new int[10];
double total;
double rata;

// %% [markdown]
// 3. Menggunakan perulangan, buat input untuk mengisi array nilaiMHS
// ![Gambar perulangan input](images/P3L3.png)

// %%
// Tulis Kode program Percobaan 3 Langkah 3 di atas, disini
for(int i = 0; i < nilaiMHS.length; i++){
    System.out.print("Masukkan nilai Mahasiswa ke- " + (i+1) + ": ");
    nilaiMHS[i] = sc.nextInt();
}
// Out:
// Masukkan nilai Mahasiswa ke- 1: 70
// Masukkan nilai Mahasiswa ke- 2: 70
// Masukkan nilai Mahasiswa ke- 3: 70
// Masukkan nilai Mahasiswa ke- 4: 80
// Masukkan nilai Mahasiswa ke- 5: 80
// Masukkan nilai Mahasiswa ke- 6: 80
// Masukkan nilai Mahasiswa ke- 7: 90
// Masukkan nilai Mahasiswa ke- 8: 90
// Masukkan nilai Mahasiswa ke- 9: 90
// Masukkan nilai Mahasiswa ke- 10: 100

// %% [markdown]
// 4. Menggunakan perulangan untuk menghitung jumlah keseluruhan nilai.
// ![Gambar perulangan jumlah](images/P3L4.png)

// %%
// Tulis Kode program Percobaan 3 Langkah 4 di atas, disini
for(int i = 0; i < nilaiMHS.length; i++){
    total += nilaiMHS[i];
}

// %% [markdown]
// 5. Kemudian hitung nilai rata-rata dengan cara nilai total dibagi jumlah elemen dari array nilaiMHS\
// ![Gambar hitung rata2](images/P3L5.png)

// %%
// Tulis Kode program Percobaan 3 Langkah 3 di atas, disini
rata = total/nilaiMHS.length;
System.out.println("Rata-rata nilai Mahasiswa adalah " + rata);
// Out:
// Rata-rata nilai Mahasiswa adalah 82.0

// %% [markdown]
// #### Pertanyaan
// 1. Pada Percobaan 3 langkah ke-5. Mengapa perhitungan rata berada diluar perulangan?

// %%
// Tulis jawaban no 1 disini
Karena jika perhitungan rata-rata berada didalam perulangan, nilai rata-rata tidak akan terhitung. Karena rata rata adalah
jumlah nilai total Mahasiswa dibagi dengan jumlah Mahasiswa itu sendiri. Jika berada dalam perulangan, nilai dari Mahasiswa
belum dietahui seluruhnya dan total belum diketahui.

// %% [markdown]
// 2. Modifikasi program pada percobaan 3 sehingga bisa mengeluarkan output  seperti gambar berikut ini!
// syarat lulus nilai >70
// ![Gambar pertanyaan 2](images/P3T2.png)

// %%
// Tulis jawaban no 2 disini
import java.util.Scanner;
Scanner sc = new Scanner(System.in); 
int nilaiMHS[] = new int[10];
double total1, total2;
double rata1, rata2; 

for(int i = 0; i < nilaiMHS.length; i++){
    System.out.print("Masukkan nilai Mahasiswa ke- " + (i+1) + ": ");
    nilaiMHS[i] = sc.nextInt();
}

int length1 = 0; 
int length2 = 0;
for(int i = 0; i < nilaiMHS.length; i++){
    
        if (nilaiMHS[i] > 70){
           total1 += nilaiMHS[i];
            length1++; 
        } else {
           total2 += nilaiMHS[i];
            length2++;     
        }
    
}

rata1 = total1/length1;
rata2 = total2/length2;

System.out.println("Rata-rata nilai Mahasiswa yang lulus adalah " + rata1);
System.out.println("Rata-rata nilai Mahasiswa yang tidak lulus adalah " + rata2);
// Out:
// Masukkan nilai Mahasiswa ke- 1: 90
// Masukkan nilai Mahasiswa ke- 2: 80
// Masukkan nilai Mahasiswa ke- 3: 100
// Masukkan nilai Mahasiswa ke- 4: 70
// Masukkan nilai Mahasiswa ke- 5: 60
// Masukkan nilai Mahasiswa ke- 6: 40
// Masukkan nilai Mahasiswa ke- 7: 50
// Masukkan nilai Mahasiswa ke- 8: 20
// Masukkan nilai Mahasiswa ke- 9: 10
// Masukkan nilai Mahasiswa ke- 10: 30
// Rata-rata nilai Mahasiswa yang lulus adalah 90.0
// Rata-rata nilai Mahasiswa yang tidak lulus adalah 40.0

// %% [markdown]
// ### Percobaan 4: Pencarian menggunakan Array
// Pada praktikum ini, akan dilakukan percobaan untuk mencari lokasi/indeks sebuah angka dalam array. Sesuai dengan flowchart di bawah ini:
// ![Gambar flowchart searching](images/FCpercobaan4.png)

// %% [markdown]
// 1. Buat array arr[] bertipe integer dengan kapasitas 6 dan isi dengan nilai 6, 4, 1, 9, 7, 3, 2 dan 8. Kemudian deklarasikan variabel integer `key` untuk kata kunci pencarian dan variabel `hasil` untuk hasil indeks pencarian. Deklarasi dan inisialisasi seperti gambar berikut ini
// ![Gambar deklarasi variabel](images/P4L2.png)

// %%
// Tulis Kode program Percobaan 4 Langkah 1 di atas, disini
int[] arr = {6,4,1,9,7,3,2,8};
int key = 3;
int hasil = -1;

// %% [markdown]
// 2. Menggunakan perulangan, lakukan pencarian untuk mendapatkan nilai array yang sesuai dengan key. Bila ada yang sesuai, simpan indeksnya sebagai hasil pencarian
// ![Gambar perulangan search](images/p4L3.png)

// %%
// Tulis Kode program Percobaan 4 Langkah 2 di atas, disini
for(int i = 0; i < arr.length; i++){
    if(key == arr[i]){
        hasil = i;
        break;
    }
}

// %% [markdown]
// 3. Tampilkan hasil pencarian dengan kode berikut.
// ![Gambar perulangan jumlah](images/P4L4.png)

// %%
// Tulis Kode program Percobaan 4 Langkah 3 di atas, disini
System.out.println("Key ada di array ke- " + hasil);
// Out:
// Key ada di array ke- 5

// %% [markdown]
// #### Pertanyaan
// 1. Pada Percobaan 4 langkah ke-2. Apa kegunaan dari statement `break`?

// %%
// Tulis jawaban no 1 disini
Statement break digunakan untuk menghentikan perulangan secara paksa dan keluar dari perulangan. Jika kata kunci sama dengan 
array maka perulangan untuk searching akan dihentikan.

// %% [markdown]
// 2. Modifikasi program pada percobaan 4 sehingga key yang dicari adalah angka 5. Kemudian jalankan program, amati hasilnya! Jelaskan penyebab dari hasil tersebut!

// %%
// Tulis jawaban no 2 disini

int[] arr = {6,4,1,9,7,3,2,8};
int key = 5;
int hasil = -1;

for(int i = 0; i < arr.length; i++){
    if(key == arr[i]){
        hasil = i;
        break;
    }
}

System.out.println("Key ada di array ke- " + hasil);
// Out:
// Key ada di array ke- -1

// %%
Key ada di array ke- -1

Artinya key tidak ditemukan. Indeks -1 cerminan bahwa key yang dicari tidak ada dalam array.

// %% [markdown]
// ### Percobaan 5: Pengurutan bilangan menggunakan Array
// Pada praktikum ini, akan dilakukan percobaan untuk mengurutkan angka dalam array. Sesuai dengan flowchart di bawah ini:
// ![Gambar flowchart sorting](images/FCpercobaan5.png)
// 1.Buat array arr[] bertipe integer dengan kapasitas 8 dan isi dengan nilai 16, 4, 10, 90, 27, 3, 12 dan 28. Kemudian deklarasikan variabel integer `temp` untuk media penukaran nilai pada variabel. Deklarasi dan inisialisasi seperti gambar berikut ini
// ![Gambar deklarasi dan inisialisasi](images/P5L1.png)

// %%
// Tulis Kode program Percobaan 5 Langkah 1 disini
int[] arr = {16,4,10,90,27,3,12,28};
int temp = 0;

// %%
// Tulis Kode program Percobaan 5 Langkah 2 di atas, disini
for(int i = 0; i < arr.length; i++){
    for(int j = 1; j < (arr.length-i); j++){
        if(arr[j-1] > arr[j]){
            temp = arr[j-1];
            arr[j-1] = arr[j];
            arr[j] = temp;
        }
    }
}

// %% [markdown]
// 2. Menggunakan perulangan, lakukan pengurutan bilangan dengan menukar posisi indeks tersebut dengan indeks berikutnya. Perulangan dilakukan untuk menukar posisi berulang kali.
// ![Gambar sorting](images/P5L2.png)

// %% [markdown]
// 3. Tampilkan hasil pengurutan dengan menggunakan perulangan
// ![Gambar print](images/P5L3.png)

// %%
// Tulis Kode program Percobaan 5 Langkah 3 di atas, disini
System.out.println("Hasil pengurutan: ");
for(int i = 0; i < arr.length; i++)
    System.out.println(arr[i]);
// Out:
// Hasil pengurutan:
// 3
// 4
// 10
// 12
// 16
// 27
// 28
// 90

// %% [markdown]
// ## Tugas
// ### Soal 1
// Buatlah program yang **sesuai** dengan alur _flowchart_ di bawah ini
// ![Soal 1](images/soal1.png)
//
// Flowchart diatas menggambarkan alur program yang membaca 10 masukan pengguna berupa integer dan menyimpannya. Kemudian angka ganjil dan genap disimpan kembali ke dalam variabel lain yang terpisah

// %%
/* Jawaban Soal 1 disini */
import java.util.Scanner;

Scanner input = new Scanner(System.in);
int checkNum[] = new int[10]; 
int evenNum[] = new int[10]; 
int oddNum[] = new int[10]; 
int cEven, cOdd = 0; 

for(int i = 0; i < checkNum.length; i++){
    System.out.print("Masukkan Angka ke- " + (i+1) + ": ");
    checkNum[i] = input.nextInt();
}

for(int j = 0; j < checkNum.length; j++){
    if(checkNum[j] %2 == 0){
        evenNum[cEven] = checkNum[j];
            cEven++; 
    } else {
        oddNum[cOdd] = checkNum[j];
            cOdd++;
    }
}

System.out.print("Nilai Genap : ");
for(int i=0; i < evenNum.length; i++){
    if(evenNum[i] == 0){
        break;
    }
    System.out.print(evenNum[i] + " "); 
}

System.out.println(" ");

System.out.print("Nilai Genap : ");
for(int i=0; i < oddNum.length; i++){ 
    if(oddNum[i] == 0){
        break;
    }
     System.out.print(oddNum[i] + " ");
}
// Out:
// Masukkan Angka ke- 1: 1
// Masukkan Angka ke- 2: 2
// Masukkan Angka ke- 3: 3
// Masukkan Angka ke- 4: 4
// Masukkan Angka ke- 5: 5
// Masukkan Angka ke- 6: 6
// Masukkan Angka ke- 7: 7
// Masukkan Angka ke- 8: 8
// Masukkan Angka ke- 9: 9
// Masukkan Angka ke- 10: 10
// Nilai Genap : 2 4 6 8 10
// Nilai Genap : 1 3 5 7 9

// %% [markdown]
// ### Soal 2
// Buatlah program yang terdapat array dengan jumlah elemen 5, buatlah input untuk mengisi elemen array tersebut, kemudian tampilkan isi array tersebut dengan urutan terbalik. Seperti ilustrasi gambar dibawah ini.
// ![Soal 2](images/T2.png)

// %%
/* Jawaban Soal 2 disini */

import java.util.Scanner; 

Scanner input = new Scanner(System.in); 
int[] numbers = new int[5]; 

for(int i = 0; i < numbers.length; i++){
    System.out.print("Indeks ke- " + i + " : ");
    numbers[i] = input.nextInt();
}

System.out.println(" ");
System.out.print("Tampilan Array dengan posisi terbalik : ");

for(int i = 4; i >= 0; i--){
    System.out.print(numbers[i] + " ");
}
// Out:
// Indeks ke- 0 : 5
// Indeks ke- 1 : 2
// Indeks ke- 2 : 7
// Indeks ke- 3 : 9
// Indeks ke- 4 : 6
//
// Tampilan Array dengan posisi terbalik : 6 9 7 2 5

// %% [markdown]
// ### Soal 3
// Buatlah program yang menerima input jumlah elemen array, inputkan isi arraynya, kemudian tampilkan bilangan terbesar dari isi elemen arraynya. Contoh hasil program:
// ![Soal 3](images/t3.png)

// %%
/* Jawaban Soal 3 disini */
import java.util.Scanner; 

Scanner input = new Scanner(System.in);
int[] numbers = new int[5]; 
int bilanganTerbesar = numbers[0]; 

System.out.print("Masukkan isi array: ");
int array = input.nextInt(); 

for(int i = 0; i < numbers.length; i++){
    System.out.print("Masukkan elemen array ke- " + i + ": ");
    numbers[i] = input.nextInt();
    
    if(bilanganTerbesar < numbers[i]){
        bilanganTerbesar = numbers[i]; 
    }
}

System.out.println("Bilangan terbesar adalah " + bilanganTerbesar);
// Out:
// Masukkan isi array: 5
// Masukkan elemen array ke- 0: 25
// Masukkan elemen array ke- 1: 78
// Masukkan elemen array ke- 2: 12
// Masukkan elemen array ke- 3: 63
// Masukkan elemen array ke- 4: 99
// Bilangan terbesar adalah 99
