// %%
//import scanner
import java.util.Scanner;
Scanner sc = new Scanner(System.in);

//array jadwal, harga, dan stok film spiderman
String[] jadwalFilmSpiderman = 
    {"PAGI  08.00", "SIANG 12.00", "SORE  15.00", "MALAM 19.40"};
int[][] hargaStokSpiderman = {
    {25000, 27000, 29000, 30000},
    {10, 15, 20, 25}
};

//array jadwal, harga, dan stok film yowisben
String[] jadwalFilmYowisben = 
    {"PAGI  08.30", "SIANG 13.30", "SORE  16.30", "MALAM 19.30"};
int[][] hargaStokYowisben = {
    {25000, 27000, 29000, 30000},
    {12, 17, 22, 27}
};

//array jadwal, harga, dan stok film follow me
String[] jadwalFilmFollowme = 
    {"PAGI  10.00", "SIANG 14.00", "SORE  17.00", "MALAM 20.00"};
int[][] hargaStokFollowme = {
    {25000, 27000, 29000, 30000},
    {13, 18, 23, 28}
};

//array jadwal, harga, dan stok film eternals
String[] jadwalFilmEternals = 
    {"PAGI  09.00", "SIANG 13.00", "SORE  16.00", "MALAM 19.00"};
int[][] hargaStokEternals = {
    {25000, 27000, 29000, 30000},
    {15, 20, 25, 30}
};

//deklarasi array untuk list judul film
String[] judulFilm = {"SPIDERMAN", "YOWIS BEN 3", "FOLLOW ME", "ETERNALS"};

//instansiasi kalender otomatis
GregorianCalendar date = new GregorianCalendar();

//array nama bulan
String namaBulan[] = {"Januari", "Februari", "Maret", "April", "Mei", "Juni", "Juli", "Agustus", "September", "Oktober", "November", "Desember"};

//deklarasi integer
int pilihJadwal, pilihFilm, jumlahTiket, detik, menit, jam, hari, bulan, tahun, stok, uang, kurangUang, kembalian, metode, kembali;

//deklarasi String
String ulang = "Y";
String nama;
String ulang1 = "Y";
String ulang2 = "Y";

//digunakan untuk mengetahui waktu saat ini
detik = date.get(Calendar.SECOND);
menit = date.get(Calendar.MINUTE);
jam =  date.get(Calendar.HOUR_OF_DAY);
hari = date.get(Calendar.DAY_OF_MONTH);
bulan = date.get(Calendar.MONTH);
tahun = date.get(Calendar.YEAR);

//fungsi tampilan menu awal
static void mainMenu(){
    // menu awal judul film
    System.out.println("=========================");
    System.out.println("||  SELAMAT DATANG DI  || ");
    System.out.println("||  LOKET BIOSKOP XXI  ||");
    System.out.println("=========================");
    System.out.println();
    System.out.println("-------------------------");
    System.out.println("MAU NONTON APA HARI INI ?");
    System.out.println("-------------------------");
    
    // output judul film
    for(int i=0; i<judulFilm.length; i++){
        System.out.println((i+1) + ". " + judulFilm[i] + "\t");
    }
    
    // menu awal jadwal film
    System.out.println();
    System.out.println("---------------------------------");
    System.out.println("           JADWAL FILM           ");
    System.out.println("---------------------------------");
    
    // output jadwal film spiderman
    System.out.println("\nJADWAL SPIDERMAN");
    System.out.println("*********************************");
    System.out.println("|     JADWAL     | HARGA | STOK |");
    System.out.println("*********************************");
    for(int j=0;j<jadwalFilmSpiderman.length;j++){
        System.out.print("| " + (j+1) + ". " + jadwalFilmSpiderman[j]+" | "+hargaStokSpiderman[0][j]+" |  "+hargaStokSpiderman[1][j] +"  | " + "\n");
    }
    System.out.println("*********************************");
    
    //output jadwal film yowis ben
    System.out.println("\nJADWAL YOWIS BEN 3");
    System.out.println("*********************************");
    System.out.println("|     JADWAL     | HARGA | STOK |");
    System.out.println("*********************************");
    for(int j=0;j<jadwalFilmYowisben.length;j++){
        System.out.print("| " + (j+1) + ". " + jadwalFilmYowisben[j]+" | "+hargaStokYowisben[0][j]+ " |  "+hargaStokYowisben[1][j] +"  | " + "\n");
    }
    System.out.println("*********************************");
    
    //output jadwal film follow me
    System.out.println("\nJADWAL FOLLOW ME");
    System.out.println("*********************************");
    System.out.println("|     JADWAL     | HARGA | STOK |");
    System.out.println("*********************************");
    for(int j=0;j<jadwalFilmFollowme.length;j++){
        System.out.print("| " + (j+1) + ". " + jadwalFilmFollowme[j]+" | "+hargaStokFollowme[0][j]+" |  "+hargaStokFollowme[1][j] +"  | " + "\n");
    }
    System.out.println("*********************************");
    
    //output jadwal film eternals
    System.out.println("\nJADWAL ETERNALS");
    System.out.println("*********************************");
    System.out.println("|     JADWAL     | HARGA | STOK |");
    System.out.println("*********************************");
    for(int j=0;j<jadwalFilmEternals.length;j++){
        System.out.print("| " + (j+1) + ". " + jadwalFilmEternals[j]+" | "+hargaStokEternals[0][j]+" |  "+hargaStokEternals[1][j] + "  | " + "\n");
    }
    System.out.println("*********************************");
}

//fungsi input data penonton
static void inputPenonton(){
    while(true){
    //input nama penonton
    System.out.println("\n*********************************");
    System.out.println("|         DATA PENONTON         |");
    System.out.println("*********************************");
    System.out.print("MASUKKAN NAMA            : ");
    nama = sc.nextLine();
    
    //input judul dan jadwal film
    while(true){
        //input judul film
        System.out.print("PILIH JUDUL FILM (ANGKA) : ");
        pilihFilm = sc.nextInt();
        //jika input tidak benar maka akan disuruh mengulang dari judul film
        if(pilihFilm<0 || pilihFilm>4){
            System.out.print("(x) MAAF JUDUL FILM TIDAK TERDAFTAR. APAKAH INGIN MENGULANG LAGI (Y/T) ? ");
            Scanner sc = new Scanner(System.in);
            ulang = sc.nextLine().toUpperCase();
            //jika jawaban y maka akan di ulang
            if(ulang.equals("Y")){
                continue;
            }
            //jika jawaban t maka berhenti
            else{
                System.out.println("TRANSAKSI GAGAL");
                break;
            }
        }
        //input jadwal film
        System.out.print("PILIH JADWAL FILM (ANGKA): ");
        pilihJadwal = sc.nextInt();
        //jika input tidak benar maka akan disuruh mengulang dari judul film
        if(pilihJadwal<0 || pilihJadwal>4){
            System.out.print("(x) MAAF JADWAL FILM TIDAK TERDAFTAR. APAKAH INGIN MENGULANG LAGI (Y/T) ? ");
            Scanner sc = new Scanner(System.in);
            ulang1 = sc.nextLine().toUpperCase();
            //jika jawaban y maka akan diulang
            if(ulang1.equals("Y")){
                continue;
            }
            //jika jawaban t maka berhenti
            else{
                System.out.println("TRANSAKSI GAGAL");
                break;
            } 
        }
        break;
    }
        
    // pemanggilan fungsi film spiderman
    if(pilihFilm == 1){
        pesanSpiderman(pilihJadwal,jumlahTiket);
    }
    // pemanggilan fungsi film yowisben
    else if(pilihFilm == 2){
        pesanYowisben(pilihJadwal,jumlahTiket);
    }
    // pemanggilan fungsi film follow me
    else if(pilihFilm == 3){
        pesanFollowme(pilihJadwal,jumlahTiket);
    }
    // pemanggilan fungsi film eternals
    else if(pilihFilm == 4){
        pesanEternals(pilihJadwal,jumlahTiket);
    }
    System.out.println();
    System.out.print("APAKAH INGIN MELAKUKAN PEMBELIAN FILM LAIN(Y=1/T=0)? ");
    kembali = sc.nextInt();
    if(kembali==1){
        continue;
    }else if(kembali==0){
        System.out.println("PEMESANAN SELESAI");
        break;
    }
}
}

//fungsi pemesanan film spiderman
static void pesanSpiderman(int pilihJadwal , int jumlahTiket){
    for(int j=0; j<hargaStokSpiderman[1].length; j++){
        if(pilihJadwal==(j+1)){
            while(true){
                //input jumlah tiket yang dibeli
                System.out.print("JUMLAH TIKET YANG DIBELI : ");
                jumlahTiket = sc.nextInt();
                //jika input tidak benar maka akan disuruh mengulang dari jumlah tiket
                if(jumlahTiket>hargaStokSpiderman[1][j]){
                    System.out.println("MAAF PEMBELIAN TIKET ANDA MELEBIHI BATAS STOK. SILAHKAN MASUKKAN KEMBALI");
                    continue;
                }
                break;
            }
        }
    }
    
    System.out.println("---------------------------------");
    for(int j=0; j<jadwalFilmSpiderman.length; j++){
        if(pilihJadwal==(j+1)){
            //output cetak nota film spiderman
            System.out.println("\n=================================");
            System.out.println("||          CETAK NOTA         ||");
            System.out.println("=================================");
            System.out.println("ATAS NAMA          : " + nama);
            System.out.println("JUDUL FILM         : " + judulFilm[0]); 
            System.out.println("JADWAL FILM        : " + jadwalFilmSpiderman[j]);
            System.out.println("JUMLAH TIKET       : " + jumlahTiket);
            hargaStokSpiderman[1][j] -= jumlahTiket;
            System.out.println("TIKET YANG TERSISA : " + hargaStokSpiderman[1][j]);
            System.out.println("HARGA PER TIKET    : " + hargaStokSpiderman[0][j]);
            int totalHargaSpiderman=0;
            totalHargaSpiderman = hargaStokSpiderman[0][j]*jumlahTiket;
            System.out.println("TOTAL HARGA        : " + totalHargaSpiderman);
            System.out.println("=================================");
            //input nominal uang yang dibayarkan
            uang=0;
            System.out.print("\nMASUKKAN NOMINAL UANG PEMBAYARAN : ");
            uang = sc.nextInt();
            //jika uang kurang, lebih, atau pas maka akan ditampilkan
            if(uang<totalHargaSpiderman){
                kurangUang=0;
                kurangUang = uang-totalHargaSpiderman;
                System.out.println("KEKURANGAN UANG ANDA             : " + kurangUang);
            }else if(uang>totalHargaSpiderman){
                kembalian=0;
                kembalian = uang-totalHargaSpiderman;
                System.out.println("UANG KEMBALIAN ANDA              : " + kembalian);
            }else{
                System.out.println("TERIMAKASIH SUDAH MEMBERI UANG PAS :)");
            }
            //output waktu transaksi pembelian tiket film
            System.out.println("\nWAKTU TRANSAKSI                  : " + hari + " " + namaBulan[bulan] + " " + tahun + " pukul " + jam + " : " + menit + " : " + detik);
        }
    }
    
    
}

//fungsi pemesanan film yowisben
static void pesanYowisben(int pilihJadwal , int jumlahTiket){
    for(int j=0; j<hargaStokYowisben[1].length; j++){
        if(pilihJadwal==(j+1)){
            while(true){
                //input jumlah tiket yang dibeli
                System.out.print("JUMLAH TIKET YANG DIBELI : ");
                jumlahTiket = sc.nextInt();
                //jika input tidak benar maka akan disuruh mengulang dari jumlah tiket
                if(jumlahTiket>hargaStokYowisben[1][j]){
                    System.out.println("MAAF PEMBELIAN TIKET ANDA MELEBIHI BATAS STOK. SILAHKAN MASUKKAN KEMBALI");
                    continue;
                }
                break;
            }
        }
    }
    System.out.println("---------------------------------");
    for(int j=0; j<jadwalFilmYowisben.length; j++){
        if(pilihJadwal==(j+1)){
            //output cetak nota film yowis ben
            System.out.println("\n=================================");
            System.out.println("||          CETAK NOTA         ||");
            System.out.println("=================================");
            System.out.println("ATAS NAMA          : " + nama);
            System.out.println("JUDUL FILM         : " + judulFilm[1]);
            System.out.println("JADWAL FILM        : " + jadwalFilmYowisben[j]);
            System.out.println("JUMLAH TIKET       : " + jumlahTiket);
            hargaStokYowisben[1][j] -= jumlahTiket;
            System.out.println("TIKET YANG TERSISA : " + hargaStokYowisben[1][j]);
            System.out.println("HARGA PER TIKET    : " + hargaStokYowisben[0][j]);
            int totalHargaYowisben=0;
            totalHargaYowisben = hargaStokYowisben[0][j]*jumlahTiket;
            System.out.println("TOTAL HARGA        : " + totalHargaYowisben);
            System.out.println("=================================");
            //input nominal uang yang dibayarkan
            uang=0;
            System.out.print("\nMASUKKAN NOMINAL UANG PEMBAYARAN : ");
            uang = sc.nextInt();
            //jika uang kurang, lebih, atau pas maka akan ditampilkan
            if(uang<totalHargaYowisben){
                kurangUang=0;
                kurangUang = uang-totalHargaYowisben;
                System.out.println("KEKURANGAN UANG ANDA             : " + kurangUang);
            }else if(uang>totalHargaYowisben){
                kembalian=0;
                kembalian = uang-totalHargaYowisben;
                System.out.println("UANG KEMBALIAN ANDA              : " + kembalian);
            }else{
                System.out.println("TERIMAKASIH SUDAH MEMBERI UANG PAS :)");
            }
            //output waktu transaksi pembelian tiket film
            System.out.println("\nWAKTU TRANSAKSI                  : " + hari + " " + namaBulan[bulan] + " " + tahun + " pukul " + jam + " : " + menit + " : " + detik);
        }
    } 
}

//fungsi pemesanan film follow me
static void pesanFollowme(int pilihJadwal , int jumlahTiket){
    for(int j=0; j<hargaStokFollowme[1].length; j++){
        if(pilihJadwal==(j+1)){
            while(true){
                //input jumlah tiket yang dibeli
                System.out.print("JUMLAH TIKET YANG DIBELI : ");
                jumlahTiket = sc.nextInt();
                //jika input tidak benar maka akan disuruh mengulang dari jumlah tiket
                if(jumlahTiket>hargaStokFollowme[1][j]){
                    System.out.println("MAAF PEMBELIAN TIKET ANDA MELEBIHI BATAS STOK. SILAHKAN MASUKKAN KEMBALI");
                    continue;
                }
                break;
            }
        }
    }
    System.out.println("---------------------------------");
    for(int j=0; j<jadwalFilmFollowme.length; j++){
        if(pilihJadwal==(j+1)){
            //output cetak nota film follow me
            System.out.println("\n=================================");
            System.out.println("||          CETAK NOTA         ||");
            System.out.println("=================================");
            System.out.println("ATAS NAMA          : " + nama);
            System.out.println("JUDUL FILM         : " + judulFilm[2]);
            System.out.println("JADWAL FILM        : " + jadwalFilmFollowme[j]);
            System.out.println("JUMLAH TIKET       : " + jumlahTiket);
            hargaStokFollowme[1][j] -= jumlahTiket;
            System.out.println("TIKET YANG TERSISA : " + hargaStokFollowme[1][j]);
            System.out.println("HARGA PER TIKET    : " + hargaStokFollowme[0][j]);
            int totalHargaFollowme=0;
            totalHargaFollowme = hargaStokFollowme[0][j]*jumlahTiket;
            System.out.println("TOTAL HARGA        : " + totalHargaFollowme);
            System.out.println("=================================");
            //input nominal uang yang dibayarkan
            uang=0;
            System.out.print("\nMASUKKAN NOMINAL UANG PEMBAYARAN : ");
            uang = sc.nextInt();
            //jika uang kurang, lebih, atau pas maka akan ditampilkan
            if(uang<totalHargaFollowme){
                kurangUang=0;
                kurangUang = uang-totalHargaFollowme;
                System.out.println("KEKURANGAN UANG ANDA             : " + kurangUang);
            }else if(uang>totalHargaFollowme){
                kembalian=0;
                kembalian = uang-totalHargaFollowme;
                System.out.println("UANG KEMBALIAN ANDA              : " + kembalian);
            }else{
                System.out.println("TERIMAKASIH SUDAH MEMBERI UANG PAS :)");
            }
            //output waktu transaksi pembelian tiket film
            System.out.println("\nWAKTU TRANSAKSI                  : " + hari + " " + namaBulan[bulan] + " " + tahun + " pukul " + jam + " : " + menit + " : " + detik);
        }
    }
    
}

//fungsi pemesanan film eternals
static void pesanEternals(int pilihJadwal , int jumlahTiket){
    for(int j=0; j<hargaStokEternals[1].length; j++){
        if(pilihJadwal==(j+1)){
            while(true){
                //input jumlah tiket yang dibeli
                System.out.print("JUMLAH TIKET YANG DIBELI : ");
                jumlahTiket = sc.nextInt();
                //jika input tidak benar maka akan disuruh mengulang dari jumlah tiket
                if(jumlahTiket>hargaStokEternals[1][j]){
                    System.out.println("MAAF PEMBELIAN TIKET ANDA MELEBIHI BATAS STOK. SILAHKAN MASUKKAN KEMBALI");
                    continue;
                }
                break;
            }
        }
    }
    System.out.println("---------------------------------");
    for(int j=0; j<jadwalFilmEternals.length; j++){
        if(pilihJadwal==(j+1)){
            //output cetak nota film eternals
            System.out.println("\n=================================");
            System.out.println("||          CETAK NOTA         ||");
            System.out.println("=================================");
            System.out.println("ATAS NAMA          : " + nama);
            System.out.println("JUDUL FILM         : " + judulFilm[3]);
            System.out.println("JADWAL FILM        : " + jadwalFilmEternals[j]);
            System.out.println("JUMLAH TIKET       : " + jumlahTiket);
            hargaStokEternals[1][j] -= jumlahTiket;
            System.out.println("TIKET YANG TERSISA : " + hargaStokEternals[1][j]);
            System.out.println("HARGA PER TIKET    : " + hargaStokEternals[0][j]);
            int totalHargaEternals=0;
            totalHargaEternals = hargaStokEternals[0][j]*jumlahTiket;
            System.out.println("TOTAL HARGA        : " + totalHargaEternals);
            System.out.println("=================================");
            //input nominal uang yang dibayarkan
            uang=0;
            System.out.print("\nMASUKKAN NOMINAL UANG PEMBAYARAN : ");
            uang = sc.nextInt();
            //jika uang kurang, lebih, atau pas maka akan ditampilkan
            if(uang<totalHargaEternals){
                kurangUang=0;
                kurangUang = uang-totalHargaEternals;
                System.out.println("KEKURANGAN UANG ANDA             : " + kurangUang);
            }else if(uang>totalHargaEternals){
                kembalian=0;
                kembalian = uang-totalHargaEternals;
                System.out.println("UANG KEMBALIAN ANDA              : " + kembalian);
            }else{
                System.out.println("TERIMAKASIH SUDAH MEMBERI UANG PAS :)");
            }
            //output waktu transaksi pembelian tiket film
            System.out.println("\nWAKTU TRANSAKSI                  : " + hari + " " + namaBulan[bulan] + " " + tahun + " pukul " + jam + " : " + menit + " : " + detik);
        }
    }
}

//pemanggilan fungsi main menu dan input penonton
mainMenu();
inputPenonton();
// Out:
// ...
// ||  SELAMAT DATANG DI  ||
// ||  LOKET BIOSKOP XXI  ||
// ...
//
// -------------------------
// MAU NONTON APA HARI INI ?
// -------------------------
// 1. SPIDERMAN
// 2. YOWIS BEN 3
// 3. FOLLOW ME
// 4. ETERNALS
//
// ---------------------------------
//            JADWAL FILM
// ---------------------------------
//
// JADWAL SPIDERMAN
// *********************************
// |     JADWAL     | HARGA | STOK |
// *********************************
// | 1. PAGI  08.00 | 25000 |  10  |
// | 2. SIANG 12.00 | 27000 |  15  |
// | 3. SORE  15.00 | 29000 |  20  |
// | 4. MALAM 19.40 | 30000 |  25  |
// *********************************
//
// JADWAL YOWIS BEN 3
// *********************************
// |     JADWAL     | HARGA | STOK |
// *********************************
// | 1. PAGI  08.30 | 25000 |  12  |
// | 2. SIANG 13.30 | 27000 |  17  |
// | 3. SORE  16.30 | 29000 |  22  |
// | 4. MALAM 19.30 | 30000 |  27  |
// *********************************
//
// JADWAL FOLLOW ME
// ...
