// %% [markdown]
// # PROJEK AKHIR PERBANKAN
//
// NAMA : NUR ALIMAH
//
// NIM : 21317100004
//
// PRODI : D3 M.INFORMATIKA

// %%
import java.util.Scanner;


Scanner input = new Scanner(System.in );
char ulangi = 't';
int menu;
int b;
int size = 10;
int i;
long rek5 [] = new long[size];
String namaPenerima [] = new String[size];
long tambahSaldo [] = new long [size];
long transferSaldo [] = new long[size];
long ambilSaldo [] = new long[size];
String nama [] = new String[size];
String alamat[] = new String[size];
int pilTab[] = new int[size];
int jenisTab[] = new int[size];
int noNasabah[] = new int[size];
long norek[] = new long[size];
long nik[] = new long[size];
long saldo[] = new long[size];


do{
System.out.println(" -----------------------Selamat Datang Di Bank Kita----------------------------");
System.out.println("*****************************************************************");
System.out.println("*** 1. Masukkan Data Nasabah\t\t\t\t\t***\n*** 2. Lihat Seluruh Data Nasabah\t\t\t\t***\n*** 3. Transaksi\t\t\t\t\t\t*** ");
System.out.println("******************************************************************");
System.out.print("Masukkan Menu (1/2/3) :");
menu = input.nextInt();
System.out.print(" ");
switch(menu){
    case 1: 
       System.out.print("Masukkan Jumlah Nasabah : ");
        b = input.nextInt();
        size = b;
        for (int i = 0; i <size;i++){
            
            System.out.print("Masukkan No Nasabah : ");
            noNasabah[i] = input.nextInt();
        
            System.out.print("Masukkan Nama Nasabah : ");
            nama[i] = input.next();
        
            System.out.print("Masukkan Alamat : ");
            input.nextLine();
            alamat[i] = input.next();
        
            System.out.print("Masukkan Nomor Rekening : ");
            input.nextLine();
            norek[i] = input.nextLong();
            
            System.out.print("Masukkan NIK : ");
            nik[i] = input.nextLong();
        
            System.out.print("Masukkan saldo Yang ingin dibayar : Rp. ");
            saldo[i] = input.nextInt();
            
            System.out.println("Pilihan Jenis Tabungan\n1. Platinum\n2. Gold\n3. Silver ");
            System.out.println("Jenis Tabungan Platinum : Maksimal Ambil Tabungan Rp. 30000000 Maksimal Transfer Rp. 100000000 ");
            System.out.println("Jenis Tabungan Platinum : Maksimal Ambil Tabungan Rp. 20000000 Maksimal TranSfer Rp. 50000000 ");
            System.out.println("Jenis Tabungan Platinum : Maksimal Ambil Tabungan Rp. 10000000 Maksimal Transfer Rp. 20000000 ");
            System.out.print("Masukkan Jenis Tabungan [1/2/3]: ");
            pilTab[i] = input.nextInt();
            System.out.println();
            
        }
       
        break;
    case 2 :
       
        for(int i = 0;i<size;i++){
            
            System.out.println("No Nasabah : "+noNasabah[i]);
            System.out.println("Nama Nasabah : "+nama[i]);
            System.out.println("Alamat : "+alamat[i]);
            System.out.println("No Rekening : "+norek[i]);
            System.out.println("NIK : "+nik[i]);
            System.out.println("Saldo : Rp. "+saldo[i]);
            System.out.println("Jenis Tabungan Anda : "+pilTab[i]);
             System.out.println();
        }
        
       
        break;
        
        
    case 3 : 
        System.out.println("==================Menu Transaksi================ ");
        System.out.println("|1. Cek saldo\t\t\t\t\t|");
        System.out.println("|2. Setor tabungan\t\t\t\t|");
        System.out.println("|3. Ambil tabungan\t\t\t\t|");
        System.out.println("|4. Transfer\t\t\t\t\t|");
        System.out.println("|5. Cetak laporan\t\t\t\t|");
         System.out.println("==================**************================");
        System.out.println("Masukkan Transaki(1/2/3/4/5) : ");
        int pilihan = input.nextInt();
           switch (pilihan){
               case 1 :
            
                System.out.println("Masukkan No Rekening Nasabah : ");
                long rek = input.nextLong();
                int index = 0;
                for (i = 0;i<norek.length;i++){
                    if (rek == norek[i]){
                    index = i;
                    System.out.println("Nama Nasabah: "+nama[index]);   
                    System.out.println("Sisa Saldo : "+saldo[index]);     
                    }
               }
               break;         
               
               case 2 :
                System.out.println("Masukkan No Rekening : ");
                long rek2 = input.nextLong();
                int index1 = 0; 
                for (i = 0;i<norek.length;i++){
                 if (rek2 == norek[i]){
                     index1  = i; 
                    System.out.println("Nama Nasabah : "+nama[index1]);
                    System.out.print("Masukkan jumlah saldo yang ingin anda bayar : Rp. ");
                    tambahSaldo [i] = input.nextLong();
                    saldo[index1]+=tambahSaldo[i] ; 
                    System.out.println("Nama Nasabah : "+nama[index1]+" Sisa Saldo Nasabah : Rp. "+saldo[index1]);
                    System.out.println("----------------------------Transaksi Nasabah Berhasil---------------------------------");
                 }
               }
  
                      
            break ;
            case 3 :
                System.out.println("Masukkan No Rekening Nasabah : ");
                long rek3 = input.nextLong();
                int index2 = 0;
                    for (i = 0;i<norek.length;i++){
                    if (rek3 == norek[i]){
                         index2 = i; 
                        System.out.println("Nama Nasabah : "+nama[index2]);
                        System.out.println("Masukkan jumlah saldo yang ingin diambil : ");
                        ambilSaldo[i] = input.nextLong();
                
                        if(ambilSaldo[i] <= saldo[index2]){
                            if(pilTab[i] == 1 && ambilSaldo[i] <= 30000000){
                            saldo[index2] -= ambilSaldo[i];
                            System.out.println("----------------------------Transaksi Nasabah Berhasil-------------------------------------");
                            System.out.println("Nama Nasabah : "+nama[index2]);
                            System.out.println("Nominal Ambil Tabungan :Rp. "+ambilSaldo[i]);
                            System.out.println("Sisa Saldo Rp. "+saldo[index2]);
                             }else if(pilTab[i] == 2 && ambilSaldo[i] <= 20000000){
                            saldo[index2] -= ambilSaldo[i];
                            System.out.println("----------------------------Transaksi Nasabah Berhasil-------------------------------------");
                            System.out.println("Nama Nasabah : "+nama[index2]);
                            System.out.println("Nominal Ambil Tabungan :Rp. "+ambilSaldo[i]);
                            System.out.println("Sisa Saldo Rp. "+saldo[index2]);
                             }else if(pilTab[i] == 3 && ambilSaldo[i] <= 10000000){
                                saldo[index2] -= ambilSaldo[i];
                                System.out.println("----------------------------Transaksi Nasabah Berhasil-------------------------------------");
                                System.out.println("Nama Nasabah : "+nama[index2]);
                                System.out.println("Nominal Ambil Tabungan :Rp. "+ambilSaldo[i]);
                                System.out.println("Sisa Saldo Rp. "+saldo[index2]);
                             } else {
                                System.out.println("Nominal Transfer Melebihi Batas Ketentuan Jenis Tabungan Anda ");
                            }

                                 
                                
                     } else {
                             System.out.println(" Saldo Tidak Cukup");
                         }
                     }  
                }
                
                        
                        
                        
                        
        break;
            case 4 :
                System.out.print("Masukkan No Rekening Nasabah: ");
                long rek4 = input.nextLong();
                int index3 = 0;
                for ( i = 0;i<norek.length;i++){
                     if (rek4 == norek[i]){
                         index3 = i;
                        System.out.println("Nama Nasabah: "+nama[index3]);
                        System.out.print("Masukkan No Rekening Tujuan : ");
                        rek5 [i] = input.nextLong();
                        System.out.print("Masukkan Nama Tujuan: ");
                        namaPenerima [i] = input.next();
                        System.out.print("Masukkan jumlah saldo yang ingin anda transfer: Rp. "); 
                        transferSaldo[i] = input.nextLong();
                        if(transferSaldo[i] <= saldo[index3]){
                            if(pilTab[i] == 1 && transferSaldo[i] <= 100000000){
                            saldo[index3] -= (transferSaldo[i]+5000);
                            System.out.println("----------------------------Transaksi Nasabah Berhasil---------------------------------");
                            System.out.println("Transfer dilakukan atas nama nasabah : "+nama[index3]);
                            System.out.println("Kepada : "+namaPenerima[i]);
                            System.out.println("Nominal Transfer : "+transferSaldo[i]);
                            System.out.println("Biaya Admin : Rp. 50000");
                            System.out.println("Sisa Saldo Rp. "+saldo[index3]);
                             }else if(pilTab[i] == 2 && transferSaldo[i] <= 50000000){
                                saldo[index3] -= (transferSaldo[i]+4000);
                                System.out.println("----------------------------Transaksi Nasabah Berhasil---------------------------------");
                                System.out.println("Transfer dilakukan atas nama nasabah : "+nama[index3]);
                                System.out.println("Kepada : "+namaPenerima[i]);
                                System.out.println("Nominal Transfer : "+transferSaldo[i]);
                                System.out.println("Biaya Admin : Rp. 40000");
                                System.out.println("Sisa Saldo Rp. "+saldo[index3]);
                             }else if(pilTab[i] == 3 && transferSaldo[i] <= 20000000){
                                saldo[index3] -= (transferSaldo[i]+3000);
                                System.out.println("----------------------------Transaksi Nasabah Berhasil---------------------------------");
                                System.out.println("Transfer dilakukan atas nama nasabah : "+nama[index3]);
                                System.out.println("Kepada : "+namaPenerima[i]);
                                System.out.println("Nominal Transfer : "+transferSaldo[i]);
                                System.out.println("Biaya Admin : Rp. 30000");
                                System.out.println("Sisa Saldo Rp. "+saldo[index3]);
                             } else {
                                 System.out.println("Nominal Transfer Melebihi Batas Ketentuan Jenis Tabungan Anda ");
                             }

                                 
                                
                     } else {
                             System.out.println("Saldo Tidak Cukup");
                         }
                     }  
                }
                
     
                   
               break;
         case 5 :
                System.out.println("Masukkan No Rekening Nasabah : ");
                long rek6 = input.nextLong();
                int index4 = 0;
                for (i = 0;i<norek.length;i++){
                     if (rek6 == norek[i]){
                         index4 = i; 
                }
                
               }
            System.out.println("=======================LAPORAN TRANSAKSI NASABAH======================");
            System.out.println("----------------------------------------------------------------------");
            System.out.println("No Nasabah : "+noNasabah[index4]);
            System.out.println("Rekening Nasabah : "+norek[index4]);
            System.out.println("Nama Nasabah : "+nama[index4]);
            System.out.println("Jenis Tabungan : "+pilTab[index4]);
            System.out.println("----------------------------------------------------------------------");
            System.out.println();
            System.out.println("----------------------------------------------------------------------");
            System.out.println("Setor Tabungan: Rp. "+tambahSaldo[index4]);
            System.out.println("Tarik Tabungan: Rp. "+ambilSaldo[index4]);
            System.out.println("----------------------------------------------------------------------");
            System.out.println();
            System.out.println("----------------------------------------------------------------------");
            System.out.println("Transfer : " +namaPenerima[index4]);
            System.out.println("Nominal Transfer Rp. " +transferSaldo[index4]);
            System.out.println("Tujuan No Rekening : "+rek5[index4]);
            System.out.println("----------------------------------------------------------------------");
            System.out.println("Sisa Saldo Nasabah : Rp. "+saldo[index4]);
            System.out.println("----------------------------------------------------------------------");
             System.out.println("=========================Transaksi Sukses===============================");

            break;
           } 
        

     break;
           
    default :
        
    System.out.println ("Anda masukkan menu yang salah");
    
                
}  
        
System.out.print("Masukkan Menu lagi (Y/T): "); 
ulangi = input.next().charAt(0); 
System.out.println(" ");        

}while (ulangi == 'y' || ulangi == 'Y');
// Out:
//  -----------------------Selamat Datang Di Bank Kita----------------------------
// *****************************************************************
// *** 1. Masukkan Data Nasabah					***
// *** 2. Lihat Seluruh Data Nasabah				***
// *** 3. Transaksi						***
// ******************************************************************
// Masukkan Menu (1/2/3) :1
//  Masukkan Jumlah Nasabah : 2
// Masukkan No Nasabah : 1
// Masukkan Nama Nasabah : ima
// Masukkan Alamat : campurdarat
// Masukkan Nomor Rekening : 123456
// Masukkan NIK : 924824781634
// Masukkan saldo Yang ingin dibayar : Rp. 10000000
// Pilihan Jenis Tabungan
// 1. Platinum
// 2. Gold
// 3. Silver
// Jenis Tabungan Platinum : Maksimal Ambil Tabungan Rp. 30000000 Maksimal Transfer Rp. 100000000
// Jenis Tabungan Platinum : Maksimal Ambil Tabungan Rp. 20000000 Maksimal TranSfer Rp. 50000000
// Jenis Tabungan Platinum : Maksimal Ambil Tabungan Rp. 10000000 Maksimal Transfer Rp. 20000000
// Masukkan Jenis Tabungan [1/2/3]: 1
// ...
