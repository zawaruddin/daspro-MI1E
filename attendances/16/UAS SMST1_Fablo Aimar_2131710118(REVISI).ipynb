// %%
import java.util.Scanner;
Scanner sc = new Scanner(System.in);
String kota, kecamatan, kelurahan, prov, kotaTujuan, kecamatanTujuan, kelurahanTujuan, provTujuan, alamatPenerima, namaBarang, namaPengirim, namaPenerima;
int beratBarang, pilihJenisBarang, kembalian, totbar, totbar2, totbar3, totbar4, jenisPembayaran, hargaBarang, beratBarang, jenisPengiriman, kodePos, hargaPenanganan, yangHarusDibayarkan, harga, h;
int harga1 = 5500;
int harga2 = 7500;
int harga3 = 10500;
String jenisBank, jenisVirtualMoney; //iya, tdk;
char ulang = 'y';
char cetakResi = 'y';
System.out.println("========================================================================");
System.out.println("                          EKSPEDISI SIFABLO                             ");
System.out.println("========================================================================");
static void kotaAsal(){
    System.out.println("        KOTA ASAL       ");
    System.out.print("Masukkan Nama Pengirim \t\t: ");
    namaPengirim = sc.nextLine();
    System.out.print("Masukkan Asal Kota \t\t: ");
    kota = sc.nextLine();
    System.out.print("Masukkan Asal Kecamatan \t: ");
    kecamatan = sc.nextLine();
    System.out.print("Masukkan Asal Kelurahan \t: ");
    kelurahan = sc.nextLine();
    System.out.print("Masukkan Asal Provinsi \t\t: ");
    prov = sc.nextLine();
}
kotaAsal();
static void kotaTujuan(){
    System.out.println("========================================================================");
    System.out.println("        KOTA TUJUAN       ");
    System.out.print("Masukkan Nama Penerima \t\t: ");
    namaPenerima = sc.nextLine();
    System.out.print("Masukkan Alamat Penerima \t: ");
    alamatPenerima = sc.nextLine();
    System.out.print("Masukkan Tujuan Kota \t\t: ");
    kotaTujuan = sc.nextLine();
    System.out.print("Masukkan Tujuan Kecamatan \t: ");
    kecamatanTujuan = sc.nextLine();
    System.out.print("Masukkan Asal Kelurahan \t: ");
    kelurahan = sc.nextLine();
    System.out.print("Masukkan Tujuan Provinsi \t: ");
    provTujuan = sc.nextLine();
    System.out.print("Masukkan Kode Pos \t\t: ");
    kodePos = sc.nextInt();
}
kotaTujuan();
System.out.println("========================================================================");
System.out.println("      JENIS BARANG      ");
String [] jenisBarang = {"1. Elektronik", "2. Perabotan", "3. Makanan"};
int x;
for(x=0; x < jenisBarang.length; x++){
    System.out.println(jenisBarang[x]);
}
System.out.print("Silahkan PIlih Jenis Barang ke- : ");
pilihJenisBarang = sc.nextInt();
switch(pilihJenisBarang){
    case 1 :
        System.out.print("Masukkan Nama Barang \t\t: ");
        sc.nextLine();
        namaBarang = sc.nextLine();
        System.out.print("Masukkan Berat Barang (Kg) \t: ");
        beratBarang = sc.nextInt();
        System.out.print("Masukkan Harga Barang \t\t: ");
        hargaBarang = sc.nextInt();
        break;
    case 2 :
        System.out.print("Masukkan Nama Barang \t\t: ");
        sc.nextLine();
        namaBarang = sc.nextLine();
        System.out.print("Masukkan Berat Barang (Kg) \t: ");
        beratBarang = sc.nextInt();
        System.out.print("Masukkan Harga Barang \t\t: ");
        hargaBarang = sc.nextInt();
        break;
    case 3 :
        System.out.print("Masukkan Nama Barang \t\t: ");
        sc.nextLine();
        namaBarang = sc.nextLine();
        System.out.print("Masukkan Berat Barang (Kg) \t: ");
        beratBarang = sc.nextInt();
        System.out.print("Masukkan Harga Barang \t\t: ");
        hargaBarang = sc.nextInt();
        break;
        default : System.out.println("Error");
} 
System.out.println("========================================================================");
System.out.println(" PILIH JENIS PENGIRIMAN ");
String [] pilihJenisPengiriman = {"1. Reguler (Durasi 5 Hari Rp. 5.500)", "2. Kilat (Durasi 2 Hari Rp. 7.500)", "3. Cargo (Durasi 4 Hari Rp. 10.500)"};
int x;
for(x=0; x < pilihJenisPengiriman.length; x++){
    System.out.println(pilihJenisPengiriman[x]);
}
System.out.print("Silahkan Pilih Jenis Pengiriman ke-: ");
jenisPengiriman = sc.nextInt();
if(jenisPengiriman==1){
    System.out.println("Harga per Kg \t\t\t: Rp. " + harga1);
    h = harga1 * beratBarang + hargaBarang;
    System.out.println("Yang Harus Dibayarkan \t\t: Rp. " + h);
    System.out.print("Uang Anda \t\t\t: Rp. ");
    totbar = sc.nextInt();
    if (totbar >= h){
    kembalian = totbar - h;
    System.out.println("Kembalian \t\t\t: " + kembalian);
    }
    else if (totbar <= h){
        System.out.println("Pembayaran Ditolak, Uang Anda Kurang");
        System.out.print("Masukkan Kembali Uang Anda : Rp. ");
        totbar2 = sc.nextInt();
        if (totbar2 >= h){
            kembalian = totbar2 - h;
            System.out.println("Kembalian \t\t\t: " + kembalian);
    }
    }
} else if (jenisPengiriman==2){
    System.out.println("Harga per Kg \t\t\t: Rp. " + harga2);
    h = harga2 * beratBarang + hargaBarang;
    System.out.println("Yang Harus Dibayarkan \t\t: Rp. " + h);
    System.out.print("Uang Anda \t\t\t: Rp. ");
    totbar = sc.nextInt();
    if (totbar >= h){
    kembalian = totbar - h;
    System.out.println("Kembalian \t\t\t: " + kembalian);
    }
    else if (totbar <= h){
        System.out.println("Pembayaran Ditolak, Uang Anda Kurang");
        System.out.print("Masukkan Kembali Uang Anda : Rp. ");
        totbar3 = sc.nextInt();
        if (totbar3 >= h){
            kembalian = totbar3 - h;
            System.out.println("Kembalian \t\t\t: " + kembalian);
    }
    }
} else if (jenisPengiriman==3){
    System.out.println("Harga per Kg \t\t\t: Rp. " + harga3);
    h = harga3 * beratBarang + hargaBarang;
    System.out.println("Yang Harus Dibayarkan \t\t: Rp. " + h);
    System.out.print("Uang Anda \t\t\t: Rp. ");
    totbar = sc.nextInt();
    if (totbar >= h){
    kembalian = totbar - h;
    System.out.println("Kembalian \t\t\t: " + kembalian);
    }
    else if (totbar <= h){
        System.out.println("Pembayaran Ditolak, Uang Anda Kurang");
        System.out.print("Masukkan Kembali Uang Anda : Rp. ");
        totbar4 = sc.nextInt();
        if (totbar4 >= h){
            kembalian = totbar4 - h;
            System.out.println("Kembalian \t\t\t: " + kembalian);
    }
    }
} else {
    System.out.println("Error");
}
System.out.println("========================================================================");
System.out.println(" PILIH JENIS PEMBAYARAN ");
System.out.println("1. Tranfer Bank , 2. Virtual Money , 3. Cash On Delivery (COD)");
System.out.print("Silahkan pilih metode pembayaran : ");
jenisPembayaran = sc.nextInt();
if (jenisPembayaran == 1){
    System.out.print("Silahkan pilih Bank \t\t: ");
    sc.nextLine();
    jenisBank = sc.nextLine();
    System.out.println("Harga Penanganan \t\t: Rp.1.000");
    System.out.println("Tidak Perlu Membayar Ke Kurir");
} else if (jenisPembayaran == 2){
    System.out.print("Silahkan pilih Virtual Money \t: ");
    sc.nextLine();
    jenisVirtualMoney = sc.nextLine();
    System.out.println("Harga Penanganan \t\t: Rp.500");
    System.out.println("Tidak Perlu Membayar Ke Kurir");
} else if (jenisPembayaran == 3){
    System.out.println("Dapat Dibayarkan Kepada Kurir ");
} else {
    System.out.println("ERROR");
}
System.out.print("Apakah Anda ingin Mencetak resi ? y/t : ");
cetakResi = sc.next().charAt(0);
//cetakResi = sc.nextLine();
if(cetakResi == 'y'){
    System.out.println("========================================================================");
    System.out.println("                           EKSPEDISI SIFABLO                            ");
    System.out.println("                                  RESI                                  ");
    System.out.println("========================================================================\n");
    System.out.println("Nama Pengirim \t\t: " + namaPengirim);
    System.out.println("Asal Kota \t\t: " + kota);
    System.out.println("========================================================================");
    System.out.println("Nama Penerima \t\t: " + namaPenerima + "\t\tAlamat : "+alamatPenerima+","+kotaTujuan+","+kecamatanTujuan+","+kelurahan+","+provTujuan+","+kodePos);
    System.out.println("Jenis Barang \t\t: " + pilihJenisBarang);
    System.out.println("Nama Barang \t\t: " + namaBarang + "\tBerat Barang (Kg) : " +beratBarang);
    System.out.println("Jenis Pengiriman \t: "+ jenisPengiriman);
    System.out.println("Harga Yang Dibayarkan \t: "+ h);
    System.out.println("Kembalian \t\t: "+ kembalian);
}
// Out:
// ...
//                           EKSPEDISI SIFABLO
// ...
//         KOTA ASAL
// Masukkan Nama Pengirim 		: Fablo Aimar
// Masukkan Asal Kota 		: Surabaya
// Masukkan Asal Kecamatan 	: Gubeng
// Masukkan Asal Kelurahan 	: Baratajaya
// Masukkan Asal Provinsi 		: Jawa Timur
// ...
//         KOTA TUJUAN
// Masukkan Nama Penerima 		: Rahmat Ardianzah
// Masukkan Alamat Penerima 	: Jl. Pisang Kipas
// Masukkan Tujuan Kota 		: Malang
// Masukkan Tujuan Kecamatan 	: Lowokwaru
// Masukkan Asal Kelurahan 	: Jatimulyo
// Masukkan Tujuan Provinsi 	: Jawa Timur
// Masukkan Kode Pos 		: 20837
// ...
//       JENIS BARANG
// 1. Elektronik
// 2. Perabotan
// 3. Makanan
// Silahkan PIlih Jenis Barang ke- : 1
// Masukkan Nama Barang 		: Televisi
// Masukkan Berat Barang (Kg) 	: 3
// Masukkan Harga Barang 		: 3500000
// ...
//  PILIH JENIS PENGIRIMAN
// 1. Reguler (Durasi 5 Hari Rp. 5.500)
// 2. Kilat (Durasi 2 Hari Rp. 7.500)
// 3. Cargo (Durasi 4 Hari Rp. 10.500)
// Silahkan Pilih Jenis Pengiriman ke-: 3
// ...
