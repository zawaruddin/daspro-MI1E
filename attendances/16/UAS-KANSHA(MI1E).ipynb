// %% [markdown]
// KANSHA MAULIDYA SHYFA
//
// MI-1E
//
// 2131710148

// %%
import java.util.Scanner;
Scanner sc = new Scanner(System.in);

int novel, cerpen, ensi, matkul, fiksi, manga, inggris;
int pnovel, pcerpen, pensi, pmatkul, pfiksi, pmanga, pinggris, pilih2;
int znovel, zcerpen, zensi, zmatkul, zfiksi, zmanga, zinggris, pilih3;
int jumlahP, bayar, d, hari, pinjam, pilih;
String nama, jenis;
char back;
do{
    System.out.println("=======PERPUSTAKAAN=======");
    System.out.println("--------MENU UTAMA--------");
    System.out.println("1. Daftar Buku");
    System.out.println("2. Peminjaman");
    System.out.println("3. Pengembalian");
    System.out.println("4. Pencarian");
    System.out.println("5. Keluar");
    System.out.println("Masukkan Pilihan : ");
    pilih = sc.nextInt();
    switch(pilih){
        case 1:
        System.out.println("Jenis              Stok");
        System.out.println("=======================");
        System.out.print("1. Novel          : ");
        novel = sc.nextInt();
        System.out.print("2. Cerpen         : ");
        cerpen = sc.nextInt();
        System.out.print("3. Ensiklopedia   : ");
        ensi = sc.nextInt();
        System.out.print("4. Matkul         : ");
        matkul = sc.nextInt();
        System.out.print("5. Fiksi          : ");
        fiksi =sc.nextInt();
        System.out.print("6. Manga          : ");
        manga = sc.nextInt();
        System.out.print("7. Inggris        : ");
        inggris = sc.nextInt();break; 
            
        case 2: System.out.println("--------PEMINJAMAN--------");
        System.out.print("Nama peminjam : ");
        nama = sc.next();
        System.out.print("Banyak peminjaman: ");
        jumlahP = sc.nextInt();
        char back2;

        do{
        System.out.println("1. Novel");
        System.out.println("2. Cerpen");
        System.out.println("3. Ensiklopedia");
        System.out.println("4. Matkul");
        System.out.println("5. Fiksi");
        System.out.println("6. Manga");
        System.out.println("7. Inggris");
        System.out.println("8. Selesai memilih");
        System.out.println("Jenis        Jumlah ");
        pilih2 = sc.nextInt();
        switch(pilih2){
            case 1 : 
                if(novel== 0){
                    System.out.println("!!!!Novel Tidak Ada Stock!!!!");
                }else{
                    System.out.print("Novel         ");
                    pnovel = sc.nextInt();
                }break;
    
            case 2 :
                if(cerpen == 0){
                    System.out.println("!!!!Cerpen Tidak Ada Stock!!!!");
                }else{
                    System.out.print("Cerpen         ");
                    pcerpen = sc.nextInt();
                } break;
    
            case 3 : 
                if(ensi == 0){
                    System.out.println("!!!!Ensiklopedia Tidak Ada Stock!!!!");
                }else{
                    System.out.print("Ensiklopeda    ");
                    pensi = sc.nextInt();
                } break;

            case 4:
                if(matkul == 0){
                    System.out.println("!!!!Matkul Tidak Ada Stock!!!!");
                }else{
                     System.out.print("Matkul         ");
                     pmatkul = sc.nextInt();
                } break;

            case 5 :
                if(fiksi == 0){
                    System.out.println("!!!!Fiksi Tidak Ada Stock!!!!");
                }else{
                    System.out.print("Fiksi          ");
                    pfiksi = sc.nextInt();
                } break;
    
            case 6 :
                if(manga == 0){
                    System.out.println("!!!!Manga Tidak Ada Stock!!!!");
                }else{
                    System.out.print("Manga          ");
                    pmanga = sc.nextInt();
                } break;

            case 7 :
                if(inggris == 0){
                    System.out.println("!!!!Inggris Tidak Ada Stock!!!!");
                }else{
                    System.out.print("Inggris        ");
                    pinggris = sc.nextInt();
                } break;

            case 8 :System.out.println("Selesai"); break;
            default :System.out.println("Pilihan anda tidak ada di menu");
            }if(pilih2 == 8){
                back2 = 'T';
            }else{
                System.out.print("Kembali ke daftar buku? [Y/T]: ");
                back2 = sc.next().charAt(0);
                System.out.println("------------------------");
                }
            }
            while(back2 != 'T');
            
        bayar = 2000 * jumlahP;
        System.out.println();
        System.out.println("Total Biaya Peminjaman : " +bayar);
        System.out.println("Note : Maksimal peminjaman adalah 7 hari"); break;
            
        case 3:System.out.println("--------PENGEMBALIAN--------");
        System.out.print("Dikembalikan pada hari ke : ");
        hari = sc.nextInt();
        if(hari>7){
        d = hari - 7;
        System.out.print("Denda yang harus dibayarkan : ");
        System.out.println(d * 500 * jumlahP);
        }else{
        System.out.println("Tidak memiliki denda"); 
        }; break;
            
        case 4: System.out.println("--------PENCARIAN--------");
        char back3;
            
        do{
        System.out.println("1. Novel");
        System.out.println("2. Cerpen");
        System.out.println("3. Ensiklopedia");
        System.out.println("4. Matkul");
        System.out.println("5. Fiksi");
        System.out.println("6. Manga");
        System.out.println("7. Inggris");
        System.out.println("8. Selesai Cari");
        System.out.println("Masukkan pilihan");
        pilih3 = sc.nextInt();
        switch(pilih3){
            case 1 :
            znovel = novel - pnovel;
            if(znovel<0){
                System.out.println("Novel Tersedia        : 0 ");
            }else{
                System.out.println("Novel Tersedia        : " + znovel);
            } break;

            case 2 :
            zcerpen = cerpen - pcerpen;
            if(zcerpen<0){
                System.out.println("Cerpen Tersedia        : 0 ");
            }else{
                System.out.println("Cerpen Tersedia        : " + zcerpen);
            } break;

            case 3 :
            zensi = ensi - pensi;
            if(zensi<0){
                System.out.println("Ensiklopedia Tersedia        : 0 ");
            }else{
                System.out.println("Ensiklopedia Tersedia        : " + zensi);
            } break;

            case 4:
            zmatkul = matkul - pmatkul;
            if(zmatkul<0){
                System.out.println("Matkul Tersedia        : 0 ");
            }else{
                System.out.println("Matkul Tersedia        : " + zmatkul);
            } break;

            case 5 :
            zfiksi = fiksi - pfiksi;
            if(zfiksi<0){
                System.out.println("Fiksi Tersedia        : 0 ");
            }else{
                System.out.println("Fiksi Tersedia        : " + zfiksi);
            } break;

            case 6 :
            zmanga = manga - pmanga;
            if(zmanga<0){
                System.out.println("Manga Tersedia        : 0 ");
            }else{
                System.out.println("Manga Tersedia        : " + zmanga);
            } break;

            case 7 :
            zinggris = inggris - pinggris;
            if(zinggris<0){
                System.out.println("Manga Tersedia        : 0 ");
            }else{
                System.out.println("Manga Tersedia        : " + zinggris);
            } break;

            case 8 : System.out.println("Selesai Cari"); break;
            default :System.out.println("Pilihan anda tidak ada di menu");
            }if(pilih3 == 8){
                back3 = 'T';
            }else{
                System.out.print("Kembali ke pencarian? [Y/T]: ");
                back3 = sc.next().charAt(0);
                System.out.println("------------------------");
                }
            }
            while(back3 != 'T');
            
        case 5:System.out.println("=====SELESAI====="); break;
        default:System.out.println("Pilihan anda tidak ada di menu");
        }if(pilih == 6){
            back = 'T';
        }else{
            System.out.print("Kembali ke menu utama? [Y/T]: ");
            back = sc.next().charAt(0);
            System.out.println("-----------------------------------------------");
            }
}
while(back != 'T');
// Out:
// =======PERPUSTAKAAN=======
// --------MENU UTAMA--------
// 1. Daftar Buku
// 2. Peminjaman
// 3. Pengembalian
// 4. Pencarian
// 5. Keluar
// Masukkan Pilihan :
// 5
// =====SELESAI=====
// Kembali ke menu utama? [Y/T]:
