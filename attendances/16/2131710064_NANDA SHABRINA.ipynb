// %% [markdown]
// # PENILAIAN AKADEMIK
// ### NAMA    : NANDA SHABRINA PUTRI KURNIA
// ### NIM             : 2131710064
// ### NOMOR : 15

// %%
//deklarasi, instansiasi//
Scanner sc = new Scanner(System.in);
System.out.print("Jumlah mahasiswa   : ");
int n = sc.nextInt();
System.out.print("Jumlah mata kuliah : ");
int m = sc.nextInt();
String nama[] = new String[n];
int nim[] = new int[n];
String matkul[] = new String[m];
String kodeMK[] = new String[m];
int sksMK[] = new int[m];
System.out.println();

//input data mahasiswa//
        System.out.println("===== PROGRAM INPUT DATA MAHASISWA =====");
        for(int i=0 ; i<n ; i++){
            System.out.println("Mahasiswa absen "+(i+1));
            System.out.print("Nama : ");
            nama[i] = sc.next();
            System.out.print("NIM  : ");
            nim[i] = sc.nextInt();
            System.out.println();
        }

//cetak data mahasiswa//
System.out.println();
        System.out.println("====================================");
        System.out.println("      DATA MAHASISWA KELAS A-13     ");
        System.out.println("====================================");
        System.out.println("No. |      NIM      |     Nama      ");
        System.out.println("------------------------------------");
        for(int i=0 ; i<n ; i++){
            System.out.println((i+1)+"   |   "+(nim[i])+"  |    "+nama[i]);
        }
//nama 5 karakter//

//fitur menu mata kuliaih//
System.out.println();
System.out.println("===== PROGRAM INPUT DATA MATA KULIAH =====");
System.out.println();
        for(int i=0 ; i<m ; i++){
            System.out.print("Mata Kuliah : ");
            matkul[i] = sc.next();
            System.out.print("Kode MK     : ");
            kodeMK[i] = sc.next();
            System.out.print("Jumlah SKS  : ");
            sksMK[i] = sc.nextInt();
            System.out.println();
        }
System.out.println();
        System.out.println("================================================");
        System.out.println("               DAFTAR PAKET MATA KULIAH         ");
        System.out.println("================================================");
        System.out.println("No. |  Kode MK   |  Mata Kuliah    | Jumlah SKS ");
        System.out.println("-------------------------------------------------");
        for(int i=0 ; i<m ; i++){
            System.out.println((i+1)+"   |   "+(kodeMK[i])+"   |   "+matkul[i]+"   |  "+sksMK[i]);
        }
//mata kuliah 11 karakter//

//fitur menu input dan kelola nilai//
System.out.println();
System.out.println("====================================");
System.out.println("   PROGRAM INPUT DAN KELOLA NILAI   ");
System.out.println("====================================");
System.out.println();
int [][]kuis = new int[n][m];
int [][]uts = new int[n][m];
int [][]uas = new int[n][m];
int [][]nilaiFINAL = new int[n][m];
String [][]predikat = new String[n][m];

for(int i=0 ; i<nilaiFINAL.length ; i++){
    System.out.println("Nama        : "+nama[i]);
    System.out.println("NIM         : "+nim[i]);
    System.out.println();
    for(int j=0 ; j<nilaiFINAL[0].length ; j++){
    System.out.println("Mata kuliah : "+matkul[j]);
    System.out.println("Kode MK     : "+kodeMK[j]);
    System.out.print("Masukkan nilai kuis       : ");
    kuis[i][j] = sc.nextInt();
    System.out.print("Masukkan nilai UTS        : ");
    uts[i][j] = sc.nextInt();
    System.out.print("Masukkan nilai UAS        : ");
    uas[i][j] = sc.nextInt();
    nilaiFINAL[i][j] = (kuis[i][j] + uts[i][j] + uas[i][j]) /3;
             if(nilaiFINAL[i][j]>80 && nilaiFINAL[i][j]<=100){
                 predikat[i][j] = "A";
             }else if(nilaiFINAL[i][j]>73 && nilaiFINAL[i][j]<=80){
                 predikat[i][j] = "B+";
             }else if(nilaiFINAL[i][j]>65 && nilaiFINAL[i][j]<=73){
                 predikat[i][j] = "B";
             }else if(nilaiFINAL[i][j]>60 && nilaiFINAL[i][j]<=65){
                 predikat[i][j] = "C+";
             }else if(nilaiFINAL[i][j]>50 && nilaiFINAL[i][j]<=60){
                 predikat[i][j] = "C";
             }else if(nilaiFINAL[i][j]>39 && nilaiFINAL[i][j]<=50){
                 predikat[i][j] = "D";
             }else{
                 predikat[i][j] = "E";
             }
    System.out.println("Nilai akhir anda adalah   : "+nilaiFINAL[i][j]);
    
    System.out.println();
    }
    System.out.println("=============================================");
}


//cek cetak KHS per mahasiswa//
char answer;
int absen, answer2;

static void cetakKHS(){
    for(int i=0 ; i<nilaiFINAL.length ; i++){
    System.out.println();
    System.out.print("Apakah anda ingin mencetak KHS? (Y/T) : ");
    answer = sc.next().charAt(0);
    if(answer == 'Y' || answer == 'y'){
        System.out.print("Masukkan absen anda : ");
        answer2 = sc.nextInt();
        absen = answer2 - 1;
        System.out.println();
        System.out.println("                          KARTU HASIL STUDI                      ");
        System.out.println();
        System.out.println("NIM           : "+nim[absen]);
        System.out.println("Nama          : "+nama[absen]);
        System.out.println("Program Studi : D-III M.Informatika");
        System.out.println("Kelas         : A-13");
        System.out.println("------------------------------------------------------------------");
        System.out.println(" No. | Kode MK |    Mata Kuliah   |   SKS   |  Nilai  | Predikat  ");
        System.out.println("------------------------------------------------------------------");
        System.out.println();
        for(int j=0 ; j<nilaiFINAL[0].length ; j++){
        System.out.println(" "+(j+1)+"      "+kodeMK[j]+"     "+matkul[j]+"        "+sksMK[j]+"         "+nilaiFINAL[absen][j]+"         "+predikat[absen][j]);
        }
    }else{
    System.out.println("KHS anda tidak akan dicetak");
    break;
    }
}
}

//cetak nilai mata kuliah//
char jawab;
String kodeMatkul;
int indeks;
static void searching(String karakter){
    boolean ketemu = false;
    for(int i=0 ; i<kodeMK.length ; i++){
        if(karakter.equals(kodeMK[i])){
            ketemu = true;
            indeks = i;
        }
    }
}
static void cetakMatkul(){
for(int i=0; i<nilaiFINAL[0].length ; i++){
     System.out.println();
     System.out.print("Apakah anda ingin mencetak nilai mata kuliah? (Y/T) : ");
     jawab = sc.next().charAt(0);
     if(jawab == 'Y' || jawab == 'y'){
     System.out.print("Masukkan kode mata kuliah yang ingin dicetak : ");
     kodeMatkul = sc.next();
        searching(kodeMatkul);   
        System.out.println();
        System.out.println("                DAFTAR NILAI MAHASISWA                ");
        System.out.println();
        System.out.println("Semester      : 2021/2022 Ganjil");
        System.out.println("Mata Kuliah   : "+matkul[indeks]);
        System.out.println("Program Studi : D-III M. Informatika");
        System.out.println("Kelas         : A-13 ");
        System.out.println();
        System.out.println("------------------------------------------------------");
        System.out.println(" No. |      NIM     |   NAMA   |  NILAI  |  PREDIKAT  ");
        System.out.println("------------------------------------------------------");
        for(int j=0 ; j<n ; j++){
        System.out.println("  "+(j+1)+"    "+nim[j] + "     " + nama[j] + "      "+nilaiFINAL[j][indeks]+"         "+predikat[j][indeks]);
        }
        }else{
     System.out.println("Nilai mata kuliah tidak akan dicetak.");
     break;
     }
}
}
cetakKHS();
cetakMatkul();
// Out:
// Jumlah mahasiswa   : 5
// Jumlah mata kuliah : 2
//
// ===== PROGRAM INPUT DATA MAHASISWA =====
// Mahasiswa absen 1
// Nama : YUNHO
// NIM  : 2131710080
//
// Mahasiswa absen 2
// Nama : MINHO
// NIM  : 2131710081
//
// Mahasiswa absen 3
// Nama : YOONA
// NIM  : 2131710082
//
// Mahasiswa absen 4
// Nama : LUCAS
// NIM  : 2131710083
//
// Mahasiswa absen 5
// Nama : SIWON
// NIM  : 2131710084
//
//
// ...
//       DATA MAHASISWA KELAS A-13
// ...
// No. |      NIM      |     Nama
// ------------------------------------
// 1   |   2131710080  |    YUNHO
// 2   |   2131710081  |    MINHO
// 3   |   2131710082  |    YOONA
// 4   |   2131710083  |    LUCAS
// 5   |   2131710084  |    SIWON
//
// ===== PROGRAM INPUT DATA MATA KULIAH =====
//
// Mata Kuliah : MAT.DISKRIT
// Kode MK     : MD7788
// Jumlah SKS  : 2
//
// Mata Kuliah : PEMROGRAMAN
// Kode MK     : PR8800
// Jumlah SKS  : 2
//
//
// ...
//                DAFTAR PAKET MATA KULIAH
// ...
// No. |  Kode MK   |  Mata Kuliah    | Jumlah SKS
// ...
