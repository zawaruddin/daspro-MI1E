// %% [markdown]
// #### Fadly Ulya Satriadi - 2131710110
// #### MI - 1E
// #### Ekspedisi Pengiriman

// %%
import java.util.Scanner;
import java.text.SimpleDateFormat;
import java.util.Date;
    static int menu, jb, jl , n;
    static long bb, total, bayar, kembali, pack;
    static Scanner input = new Scanner (System.in);
    static String perkg, kotaaak, kecamatank, provk, namak, alengk, kotaaa, kecamatan, prov, nama, aleng, nb, jenis, jelay;
    static char lanjut;

Date tgl = new Date();
String month[] = {"Januari" , "Februari" , "Maret" , "April" , "Mei" , "Juni" , "Juli" , "Agustus" , "September" , "Oktober" , "November" , "Desember"};

    SimpleDateFormat d = new SimpleDateFormat("d");
        String tanggal = d.format(tgl);
    SimpleDateFormat d = new SimpleDateFormat("M");
        String ini_bulan = d.format(tgl);
    int bulan = Integer.parseInt(ini_bulan);
        SimpleDateFormat d = new SimpleDateFormat("Y");
    String tahun = d.format(tgl);

    static void Harga (int jl){
        if (jl == 1){
            System.out.println(">> STRUK TRANSAKSI <<");
            System.out.println("\nJenis Barang\t\t : " + jenis);
            System.out.println("Nama Barang\t\t : " + nb);
            System.out.println("Jenis Layanan\t\t : " + jelay);
            System.out.println("Biaya Per Kg\t\t : " + perkg);
            System.out.print("Berat Barang (Kg)\t : ");
            bb = input.nextLong();
                if (bb > 5000){
                    System.out.println("\n> Berat Melebihi Kapasitas Maksimal <");
                }
                else if (bb >= 0 && bb <= 5000){
                    total = bb * 20000;
                    System.out.println("Biaya Pengiriman\t : Rp. " + total);
                    System.out.println("Biaya Packaging\t\t : Rp. 4.000");
                    pack = total + 4000;
                    System.out.println("Total\t\t\t : Rp. " + pack);
                    
                    System.out.print("\nTotal Bayar\t\t : Rp. ");
                    bayar = input.nextInt();
                        if (bayar < pack){
                            System.out.print("\n> Uang Anda Kurang <");
                        } else if (bayar >= pack){
                            kembali = bayar - pack;
                            System.out.println("Kembalian\t\t : Rp. " + kembali);
                            System.out.println("\nNama Pengirim\t\t : " + nama);
                            System.out.println("Nama Penerima\t\t : " + namak);
                            System.out.println("Alamat Penerima\t\t : " + alengk + ", " + kecamatank + ", " + kotaaak + ", " + provk);
                            System.out.println("Tanggal Pengiriman\t : " + tanggal + " " + (month[bulan-1]) + " " + tahun);
                            String with3digits = String.format("%07d", n);
                            System.out.println("NO RESI\t\t\t : FDX" + with3digits);
                        }
                }
        } else if (jl == 2){
            System.out.println(">> STRUK TRANSAKSI <<");
            System.out.println("\nJenis Barang\t\t : " + jenis);
            System.out.println("Nama Barang\t\t : " + nb);
            System.out.println("Jenis Layanan\t\t : " + jelay);
            System.out.println("Biaya Per Kg\t\t : " + perkg);
            System.out.print("Berat Barang (Kg)\t : ");
            bb = input.nextLong();
            System.out.println("Biaya Packaging\t\t : Rp. 4.000");
            total = bb * 30000;
            if (bb > 5000){
                    System.out.println("\n> Berat Melebihi Kapasitas Maksimal <");
                }
                else if (bb >= 0 && bb <= 5000){
                    total = bb * 30000;
                    System.out.println("Biaya Pengiriman\t : Rp. " + total);
                    System.out.println("Biaya Packaging\t\t : Rp. 4.000");
                    pack = total + 4000;
                    System.out.println("Total\t\t\t : Rp. " + pack);
                    
                    System.out.print("\nTotal Bayar\t\t : Rp. ");
                    bayar = input.nextInt();
                        if (bayar < pack){
                            System.out.print("\n> Uang Anda Kurang <");
                        } else if (bayar >= pack){
                            kembali = bayar - pack;
                            System.out.println("Kembalian\t\t : Rp. " + kembali);
                            System.out.println("\nNama Pengirim\t\t : " + nama);
                            System.out.println("Nama Penerima\t\t : " + namak);
                            System.out.println("Alamat Penerima\t\t : " + alengk + ", " + kecamatank + ", " + kotaaak + ", " + provk);
                            System.out.println("Tanggal Pengiriman\t : " + tanggal + " " + (month[bulan-1]) + " " + tahun);
                            String with3digits = String.format("%07d", n);
                            System.out.println("\nNO RESI\t\t\t : FDX" + with3digits);
                        }
                }
        } else if (jl == 3){
            System.out.println(">> STRUK TRANSAKSI <<");
            System.out.println("\nJenis Barang\t\t : " + jenis);
            System.out.println("Nama Barang\t\t : " + nb);
            System.out.println("Jenis Layanan\t\t : " + jelay);
            System.out.println("Biaya Per Kg\t\t : " + perkg);
            System.out.print("Berat Barang (Kg)\t : ");
            bb = input.nextLong();
            if (bb > 5000){
                    System.out.println("\n> Berat Melebihi Kapasitas Maksimal <");
                }
                else if (bb >= 0 && bb <= 5000){
                    total = bb * 40000;
                    System.out.println("Biaya Pengiriman\t : Rp. " + total);
                    System.out.println("Biaya Packaging\t\t : Rp. 4.000");
                    pack = total + 4000;
                    System.out.println("Total\t\t\t : Rp. " + pack);
                    
                    System.out.print("\nTotal Bayar\t\t : Rp. ");
                    bayar = input.nextInt();
                        if (bayar < pack){
                            System.out.print("\n> Uang Anda Kurang <");
                        } else if (bayar >= pack){
                            kembali = bayar - pack;
                            System.out.println("Kembalian\t\t : Rp. " + kembali);
                            System.out.println("\nNama Pengirim\t\t : " + nama);
                            System.out.println("Nama Penerima\t\t : " + namak);
                            System.out.println("Alamat Penerima\t\t : " + alengk + ", " + kecamatank + ", " + kotaaak + ", " + provk);
                            System.out.println("Tanggal Pengiriman\t : " + tanggal + " " + (month[bulan-1]) + " " + tahun);
                            String with3digits = String.format("%07d", n);
                            System.out.println("\nNO RESI\t\t\t : FDX" + with3digits);
                        }
                }
        } else if (jl == 4){
            System.out.println(">> STRUK TRANSAKSI <<");
            System.out.println("\nJenis Barang\t\t : " + jenis);
            System.out.println("Nama Barang\t\t : " + nb);
            System.out.println("Jenis Layanan\t\t : " + jelay);
            System.out.println("Biaya Per Kg\t\t : " + perkg);
            System.out.print("Berat Barang (Kg)\t : ");
            bb = input.nextLong();
            if (bb > 5000){
                    System.out.println("\n> Berat Melebihi Kapasitas Maksimal <");
                }
                else if (bb >= 0 && bb <= 5000){
                    total = bb * 50000;
                    System.out.println("Biaya Pengiriman\t : Rp. " + total);
                    System.out.println("Biaya Packaging\t\t : Rp. 4.000");
                    pack = total + 4000;
                    System.out.println("Total\t\t\t : Rp. " + pack);
                    
                    System.out.print("\nTotal Bayar\t\t : Rp. ");
                    bayar = input.nextInt();
                        if (bayar < pack){
                            System.out.print("\n> Uang Anda Kurang <");
                        } else if (bayar >= pack){
                            kembali = bayar - pack;
                            System.out.println("Kembalian\t\t : Rp. " + kembali);
                            System.out.println("\nNama Pengirim\t\t : " + nama);
                            System.out.println("Nama Penerima\t\t : " + namak);
                            System.out.println("Alamat Penerima\t\t : " + alengk + ", " + kecamatank + ", " + kotaaak + ", " + provk);
                            System.out.println("Tanggal Pengiriman\t : " + tanggal + " " + (month[bulan-1]) + " " + tahun);
                            String with3digits = String.format("%07d", n);
                            System.out.println("\nNO RESI\t\t\t : FDX" + with3digits);
                        }
                }
        } else if (jl == 5){
            System.out.println(">> STRUK TRANSAKSI <<");
            System.out.println("\nJenis Barang\t\t : " + jenis);
            System.out.println("Nama Barang\t\t : " + nb);
            System.out.println("Jenis Layanan\t\t : " + jelay);
            System.out.println("Biaya Per Kg\t\t : " + perkg);
            System.out.print("Berat Barang (Kg)\t : ");
            bb = input.nextLong();
            if (bb > 5000){
                    System.out.println("\n> Berat Melebihi Kapasitas Maksimal <");
                }
                else if (bb >= 0 && bb <= 5000){
                    total = bb * 65000;
                    System.out.println("Biaya Pengiriman\t : Rp. " + total);
                    System.out.println("Biaya Packaging\t\t : Rp. 4.000");
                    pack = total + 4000;
                    System.out.println("Total\t\t\t : Rp. " + pack);
                    
                    System.out.print("\nTotal Bayar\t\t : Rp. ");
                    bayar = input.nextInt();
                        if (bayar < pack){
                            System.out.print("\n> Uang Anda Kurang <");
                        } else if (bayar >= pack){
                            kembali = bayar - pack;
                            System.out.println("Kembalian\t\t : Rp. " + kembali);
                            System.out.println("\nNama Pengirim\t\t : " + nama);
                            System.out.println("Nama Penerima\t\t : " + namak);
                            System.out.println("Alamat Penerima\t\t : " + alengk + ", " + kecamatank + ", " + kotaaak + ", " + provk);
                            System.out.println("Tanggal Pengiriman\t : " + tanggal + " " + (month[bulan-1]) + " " + tahun);
                            String with3digits = String.format("%07d", n);
                            System.out.println("\nNO RESI\t\t\t : FDX" + with3digits);
                        }
                }     
        } else {
            System.out.print("Data yang Anda Masukkan Salah");
        } 
    }
        n = 1;
        do {
        System.out.println(">>> SELAMAT DATANG DI FADLY EXPRESS <<<");
        System.out.println("\n");
        
        System.out.println("MENU : ");
        String [] pilmenu = {" 1. Jenis dan Harga Layanan", " 2. Jenis Barang yang dapat dikirim", " 3. Pengiriman"};
        int y;
        for(y = 0; y < pilmenu.length; y++){
            System.out.println(pilmenu[y]);
        }
        System.out.print("\nPilih Menu\t : ");
        menu = input.nextInt();
        if (menu == 1){
            System.out.println(" 1. Reguler Pack\t(7 - 8 Hari)\t\t - Rp. 20.000/kg \n 2. Kilat Pack\t\t(4 - 6 Hari)\t\t - Rp. 30.000/kg \n 3. One Pack\t\t(2 - 3 Hari)\t\t - Rp. 40.000/kg \n 4. Super Speed Pack\t(1 Hari)\t\t - Rp. 50.000/kg \n 5. LanDay Pack\t\t(Kurang dari 24 Jam)\t - Rp. 65.000/kg");
            System.out.println("\n Noted : Belum termasuk biaya Packaging sebesar Rp. 4.000");
        } else if (menu == 2){
            System.out.println(" 1. Elektronik \n 2. Farmasi \n 3. Apparel \n 4. Kosmetik \n 5. Kendaraan \n 6. Furniture \n 7. Makanan");
            System.out.println("\n Noted : Berat barang maksimal 5000 kg");
        } else if (menu == 3){
        System.out.println("\n");
        System.out.println("Masukkan Alamat Asal");
        System.out.print("- Nama Pengirim\t\t : ");
        input.nextLine();
        nama = input.nextLine();
        System.out.print("- Provinsi\t\t : ");
        prov = input.nextLine();
        System.out.print("- Kota / Kabupaten\t : ");
        kotaaa = input.nextLine();
        System.out.print("- Kecamatan\t\t : ");
        kecamatan = input.nextLine();
        System.out.print("- Alamat Lengkap\t : ");
        aleng = input.nextLine();
            
        System.out.println("\n");
        System.out.println("Masukkan Alamat Tujuan");
        System.out.print("- Nama Penerima\t\t : ");
        namak = input.nextLine();
        System.out.print("- Provinsi\t\t : ");
        provk = input.nextLine();
        System.out.print("- Kota / Kabupaten\t : ");
        kotaaak = input.nextLine();
        System.out.print("- Kecamatan\t\t : ");
        kecamatank = input.nextLine();
        System.out.print("- Alamat Lengkap\t : ");
        alengk = input.nextLine();
            
            
        System.out.println("\n");
        System.out.println("Jenis Jenis Barang");
        String [] jbarang = {" 1. Elektronik", " 2. Farmasi", " 3. Apparel", " 4. Kosmetik", " 5. Kendaraan", " 6. Furniture", " 7. Makanan"};
        int x;
        for(x = 0; x < jbarang.length; x++){
            System.out.println(jbarang[x]);
        }
        System.out.print("Pilih\t\t\t : ");
        jb = input.nextInt();

        if (jb == 1){
            jenis = ("Elektronik");
            System.out.print("Nama Barang\t\t : ");
            input.nextLine();
            nb = input.nextLine();
        } else if (jb == 2){
            jenis = ("Farmasi");
            System.out.print("Nama Barang\t\t : ");
            input.nextLine();
            nb = input.nextLine();
        } else if (jb == 3){
            jenis = ("Apparel");
            System.out.print("Nama Barang\t\t : ");
            input.nextLine();
            nb = input.nextLine();
        } else if (jb == 4){
            jenis = ("Kosmetik");
            System.out.print("Nama Barang\t\t : ");
            input.nextLine();
            nb = input.nextLine();
        } else if (jb == 5){
            jenis = ("Kendaraan");
            System.out.print("Nama Barang\t\t : ");
            input.nextLine();
            nb = input.nextLine();
        } else if (jb == 6){
            jenis = ("Furniture");
            System.out.print("Nama Barang\t\t : ");
            input.nextLine();
            nb = input.nextLine();
        } else if (jb == 7){
            jenis = ("Makanan");
            System.out.print("Nama Barang\t\t : ");
            input.nextLine();
            nb = input.nextLine();
        } else {
            System.out.print("Data yang Anda Masukkan Salah");
        }

        System.out.println("\n");
        System.out.println("Layanan Yang Tersedia");
        String[] jlayanan = {" 1. Reguler Pack\t(7 - 8 Hari)\t\t- Rp. 20.000/kg ", " 2. Kilat Pack\t\t(4 - 6 Hari)\t\t- Rp. 30.000/kg", " 3. One Pack\t\t(2 - 3 Hari)\t\t- Rp. 40.000/kg", " 4. Super Speed Pack\t(1 Hari)\t\t- Rp. 50.000/kg", " 5. LanDay Pack\t\t(Kurang dari 24 Jam)\t- Rp. 65.000/kg"};
        for (String s : jlayanan) {
            System.out.println(s);
        }
        System.out.print("Pilih\t\t\t : ");
        jl = input.nextInt();
            if (jl == 1){
                jelay = ("Reguler Pack");
                perkg = ("Rp. 20.000"); 
            } else if (jl == 2){
                jelay = ("Kilat Pack");
                perkg = ("Rp. 30.000");
            } else if (jl == 3){
                jelay = ("One Pack");
                perkg = ("Rp. 40.000");
            } else if (jl == 4){
                jelay = ("Super Speed Pack");
                perkg = ("Rp. 50.000");
            } else if (jl == 5){
                jelay = ("LanDay Pack");
                perkg = ("Rp. 65.000");
            } else {
            System.out.print("Data yang Anda Masukkan Salah");
        }
            
        System.out.println("\n");
        Harga(jl); 
        }
            
        System.out.println("\n");
        System.out.print("Lakukan Tranksaksi Ulang ? (Y/T) : ");
        lanjut = input.next().charAt(0);
            n++;
        System.out.print("\n");
    } while (lanjut == 'y' || lanjut == 'Y');

        System.out.println("\n");
        System.out.println("!!!  TERIMA KASIH  !!!");
// Out:
// >>> SELAMAT DATANG DI FADLY EXPRESS <<<
//
//
// MENU :
//  1. Jenis dan Harga Layanan
//  2. Jenis Barang yang dapat dikirim
//  3. Pengiriman
//
// Pilih Menu	 : 1
//  1. Reguler Pack	(7 - 8 Hari)		 - Rp. 20.000/kg
//  2. Kilat Pack		(4 - 6 Hari)		 - Rp. 30.000/kg
//  3. One Pack		(2 - 3 Hari)		 - Rp. 40.000/kg
//  4. Super Speed Pack	(1 Hari)		 - Rp. 50.000/kg
//  5. LanDay Pack		(Kurang dari 24 Jam)	 - Rp. 65.000/kg
//
//  Noted : Belum termasuk biaya Packaging sebesar Rp. 4.000
//
//
// Lakukan Tranksaksi Ulang ? (Y/T) : Y
//
// >>> SELAMAT DATANG DI FADLY EXPRESS <<<
//
//
// MENU :
//  1. Jenis dan Harga Layanan
//  2. Jenis Barang yang dapat dikirim
//  3. Pengiriman
//
// Pilih Menu	 : 2
//  1. Elektronik
//  2. Farmasi
//  3. Apparel
//  4. Kosmetik
//  5. Kendaraan
//  6. Furniture
//  7. Makanan
//
//  Noted : Berat barang maksimal 5000 kg
//
//
// Lakukan Tranksaksi Ulang ? (Y/T) : Y
//
// >>> SELAMAT DATANG DI FADLY EXPRESS <<<
//
//
// MENU :
// ...
