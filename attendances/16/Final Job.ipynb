// %%
//fungsi fitur isi nama
static String[] inputNama(int a) {
    Scanner sc = new Scanner(System.in);
    System.out.println("\nPenginputan Nama Pegawai");
    String[] nama = new String[a];
    for (int i=0; i<nama.length; i++) {
        System.out.print("Masukkan Nama Pegawai: ");
        nama[i] = sc.nextLine();
    }
    System.out.print("Fitur Input Nama Pegawai Selesai");
    return nama;
}

//fungsi fitur isi data 
static int[][] inputData(int baris, int kolom) {
    int[][] data = new int[baris][kolom];
    Scanner sc = new Scanner(System.in);
    System.out.println();
    System.out.println("\nPenginputan Data Lama Kerja, Lama Lembur, Terlambat Pegawai");
    for(int i=0; i<data.length; i++) {
        System.out.println();
        System.out.println("Masukkan Data Pegawai atas Nama: " + namaPegawai[i]);
        System.out.print("Masukkan Data Lama Kerja per Hari: ");
        data[i][0] = sc.nextInt();
        System.out.print("Masukkan Data Lama Lembur per Jam: ");
        data[i][1] = sc.nextInt();
        System.out.print("Masukkan Data Terlambat per Jam: ");
        data[i][2] = sc.nextInt();
    }
    System.out.print("Fitur Input Data Pegawai Selesai");
    return data;
}

//fungsi fitur penghitungan
static void penghitungan(int [][] array) {
    for (int i=0; i<array.length; i++) {
        array[i][3] = array[i][0] * 200000;
    }
    for (int i=0; i<array.length; i++) {
        array[i][4] = array[i][3] / 100 * 10;
    }
    for (int i=0; i<array.length; i++) {
        array[i][5] = array[i][1] * 8000;
    }
    for (int i=0; i<array.length; i++) {
        array[i][6] = array[i][2] * (200000 / 100 * 10);
    }
    for (int i=0; i<array.length; i++) {
        array[i][7] = array[i][3] + array[i][4] + array[i][5] - array[i][6];
    }
}

//fungsi cetak gaji semua
static void cetakGajiSemua(int [][] array) {
    System.out.println("========Cetak Gaji Pegawai========");
    for(int i=0; i<array.length; i++) {
        System.out.println("----------SLIP GAJI----------");
        System.out.println("Nama Pegawai \t:\t " + namaPegawai[i]);
        System.out.println("Gaji Pokok \t:\t " + array[i][3]);
        System.out.println("Tunjangan \t:\t " + array[i][4]);
        System.out.println("Lembur \t\t:\t " + array[i][5]);
        System.out.println("Terlambat \t:\t -" + array[i][6]);
        System.out.println("___________________________________ +");
        System.out.println("Total Gaji \t:\t " + array[i][7]);
    }
    System.out.print("Fitur Cetak Gaji Selesai");
}

//fungsi cetak gaji 1 orang
static void cetakGaji(int [][] array) {
    String key1;
    int a, hasil1;
    Scanner sc = new Scanner(System.in);
    System.out.println();
    System.out.println();
    System.out.println("========Cetak Gaji Pegawai========");
    for(int i=0; i<array.length; i++) {
        System.out.print("Masukkan Nama yang Ingin Dilakukan Cetak Gaji: ");
        key1 = sc.nextLine();
        for (int j=0; j<array.length; j++) {
            if(namaPegawai[j].equals(key1)) {
                a = j;
                System.out.println("----------SLIP GAJI----------");
                System.out.println("Nama Pegawai \t:\t " + namaPegawai[a]);
                System.out.println("Gaji Pokok \t:\t " + array[a][3]);
                System.out.println("Tunjangan \t:\t " + array[a][4]);
                System.out.println("Lembur \t\t:\t " + array[a][5]);
                System.out.println("Terlambat \t:\t -" + array[a][6]);
                System.out.println("___________________________________ +");
                System.out.println("Total Gaji \t:\t " + array[a][7]);
            } 
        }
        System.out.print("Apakah Anda ingin Melanjutkan Cetak Gaji Pegawai(1=ya / 0=tidak)?");
        hasil1 = sc.nextInt();
        if(hasil1==0) {
            break;
        }
    }
    System.out.print("Fitur Cetak Gaji Selesai");
}

//fungsi pencarian
static void cetakPencarian(int[][] array) {
    String key2;
    int b, hasil2;
    for(int i=0; i<=10; i++) {
        Scanner sc = new Scanner(System.in);
        System.out.println();
        System.out.println();
        System.out.println("========Pencarian Pegawai========");
        System.out.print("Masukkan Nama yang Ingin Dilakukan Pencarian: ");
        key2 = sc.nextLine();
        for (int j=0; j<array.length; j++) {
            if(namaPegawai[j].equals(key2)) {
                b = j;
                System.out.println("Nama Pegawai\t" + "Gaji Pokok\t" + "Tunjangan\t" + "Lembur\t" + "Terlambat\t" + "Total Gaji");
                System.out.println(namaPegawai[b] + "\t" + array[b][3] + "\t\t" + array[b][4] + "\t\t" + array[b][5] + "\t\t" + array[b][6] + "\t\t" + array[b][7]);
            } 
        }
        System.out.print("Apakah Anda ingin Melanjutkan Pencarian Pegawai(1=ya / 0=tidak)?");
        hasil2 = sc.nextInt();
        if(hasil2==0) {
            break;
        }
    }
    System.out.print("Fitur Pencarian Pegawai Selesai"); 
}

//fungsi laporan
static void cetakLaporan(int[][] array) {
    System.out.println();
    System.out.println();
    System.out.println("=====Laporan Gaji Pegawai=====");
    System.out.println("Nama Pegawai\t" + "Gaji Pokok\t" + "Tunjangan\t" + "Lembur\t" + "Terlambat\t" + "Total Gaji");
    for(int i=0; i<array.length; i++) {
        System.out.println(namaPegawai[i] + "\t" + array[i][3] + "\t\t" + array[i][4] + "\t\t" + array[i][5] + "\t\t" + array[i][6] + "\t\t" + array[i][7]); 
    }
    System.out.print("Fitur Laporan Pegawai Selesai");
}

import java.util.Scanner;
Scanner sc = new Scanner(System.in);
System.out.println("Selamat Datang di Program Penggajian");
String[] namaPegawai = inputNama(10);
int[][] dataPegawai = inputData(10, 8);
penghitungan(dataPegawai);
for(int i=0; i<10; i++) {
    int pilih;
    char jawab;
    System.out.println();
    System.out.println();
    System.out.println("Menu Program Penggajian");
    System.out.println("1. Cetak Slip Gaji Semua Pegawai");
    System.out.println("2. Cetak Slip Gaji 1 Pegawai");
    System.out.println("3. Pencarian Pegawai");
    System.out.println("4. Laporan Pegawai");
    System.out.print("Pilih Menu Program: ");
    pilih = sc.nextInt();
    if(pilih==1) {
        cetakGajiSemua(dataPegawai);
    } else if(pilih==2) {
        cetakGaji(dataPegawai);
    } else if(pilih==3) {
        cetakPencarian(dataPegawai);
    } else if(pilih==4) {
        cetakLaporan(dataPegawai);
    }
    System.out.print("\nApakah Anda Mau Kembali ke Menu? (y/n)");
    jawab = sc.next().charAt(0);
    if(jawab=='n' || jawab=='N') {
        break;
    }
}
System.out.println("Terima Kasih dan Selamat Datang Kembali");
// Out:
// Selamat Datang di Program Penggajian
//
// Penginputan Nama Pegawai
// Masukkan Nama Pegawai: neddy
// Masukkan Nama Pegawai: pratama
// Masukkan Nama Pegawai: wiryawan
// Fitur Input Nama Pegawai Selesai
//
// Penginputan Data Lama Kerja, Lama Lembur, Terlambat Pegawai
//
// Masukkan Data Pegawai atas Nama: neddy
// Masukkan Data Lama Kerja per Hari: 23
// Masukkan Data Lama Lembur per Jam: 12
// Masukkan Data Terlambat per Jam: 2
//
// Masukkan Data Pegawai atas Nama: pratama
// Masukkan Data Lama Kerja per Hari: 23
// Masukkan Data Lama Lembur per Jam: 12
// Masukkan Data Terlambat per Jam: 1
//
// Masukkan Data Pegawai atas Nama: wiryawan
// Masukkan Data Lama Kerja per Hari: 23
// Masukkan Data Lama Lembur per Jam: 12
// Masukkan Data Terlambat per Jam: 1
// Fitur Input Data Pegawai Selesai
//
// Menu Program Penggajian
// 1. Cetak Slip Gaji Semua Pegawai
// 2. Cetak Slip Gaji 1 Pegawai
// 3. Pencarian Pegawai
// 4. Laporan Pegawai
// Pilih Menu Program: 4
//
//
// ...
