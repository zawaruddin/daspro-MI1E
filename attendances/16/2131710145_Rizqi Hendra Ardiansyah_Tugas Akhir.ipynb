// %% [markdown]
// ### PROJECT TUGAS BESAR UAS PRAKTIKUM DASAR PEMROGRAMAN ###
//
// #### Nama : Rizqi Hendra Ardiansyah ####
// #### Kelas : MI-1E ####
// #### NIM    : 2131710145 ####

// %%
import java.util.Scanner;
Scanner sc = new Scanner(System.in);

//Deklarasi Bertipe Data Array 
String s;
int pilihMenu;
String[] menuAkademik = {"Data Mahasiswa", "Mata Kuliah", "Input Nilai ","Cetak Nilai Mata Kuliah",  "Nilai per Mata Kuliah"};
String[] dataMahasiswa = {"Bangkit Maulana Caniago", "Ega Fadhilla Febryana", "Fablo Aimar", "Fadly Ulya Satriadi", "Ferly Yanuar Prasetyo", "Fitrah Rahmadhani Ahmad", "Halim Teguh Saputro", "Indah Retno Iriani", "Jati Wahyu Kusuma", "Kansha Maulidya Shyfa"};
String[] mataKuliah = {"Dasar Pemrograman", "Teknik Dokumentasi", "Matematika Diskrit", "Konsep Teknologi Informasi", "Aplikasi Komputer Perkantoran"};
int[][] nilaiMatkul = new int[10][5];  //Instansiasi Bertipe Data Int 

//Fungsi untuk menampilkan Menu 
static void menuData(){
    
//Perulangan untuk menampilkan Data Menu
        do{ 
        System.out.println("===========================");
        System.out.println("| Menu Penilaian Akademik |");
        System.out.println("|     Mahasiswa MI-1E     |");
        System.out.println("===========================");
        System.out.println("Fitur Menu : ");
    
        for(int i=0; i<menuAkademik.length; i ++){
            System.out.println((i+1) + ". " + menuAkademik[i]);
        }
       
        System.out.println();
        System.out.print("=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=");
        System.out.println();
        System.out.print(" Pilih menu yang ingin dipilih : ");
        System.out.println();
        System.out.print("=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=");
        System.out.println();
        pilihMenu = sc.nextInt();
        System.out.println();
        
//pemilihan Menu 
        if(pilihMenu==1){
            tampilDataMahasiswa();
        }else if(pilihMenu==2){
            tampilMataKuliah();
        }else if(pilihMenu==3){
            inputNilai();
        }else if(pilihMenu==4){
            cetakNilai();
        }else if(pilihMenu==5){
            nilaiMahasiswa();

        }else{

        System.out.println("Menu Data Yang Anda pilih Tidak Tersedia!");

        }

        System.out.print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~");
        System.out.println();
        System.out.println("| Ingin kembali ke Menu Utama (Y/T)? |");
        System.out.print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~");
        System.out.println();
        s = sc.next();
        System.out.println();
        
        
    }while((s.charAt(0)=='Y')||(s.charAt(0)=='y'));
    }

//fungsi untuk menampilkan Data Mahasiswa
static void tampilDataMahasiswa(){
    System.out.print("+-------------------------+");
    System.out.println();  
    System.out.println("|  Data Nama Mahasiswa :  |");
    System.out.print("+-------------------------+");
    System.out.println();  
            for(int i=0; i<dataMahasiswa.length; i ++){
                System.out.println((i+1) + ". " + dataMahasiswa[i]);
            }
    }

//fungsi untuk menampilkan Mata Kuliah
static void tampilMataKuliah(){
    System.out.print("+-------------------------+");
    System.out.println();  
    System.out.println("|    Nama Mata Kuliah :   | ");
    System.out.print("+-------------------------+");
    System.out.println();  
            for(int i=0; i<mataKuliah.length; i ++){
                System.out.println((i+1) + ". " + mataKuliah[i]);
            }
    }

//fungsi untuk menginputkan Nilai per Mata Kuliah
static void inputNilai(){
    System.out.println( "                      ~ | Input Nilai Mata Kuliah | ~                  " );
    System.out.println();
    System.out.print("Masukan Jumlah Mahasiswa yang ingin di Inputkan : ");
    System.out.println();
            int jumlah = sc.nextInt();
            for(int i=0 ;i <jumlah;i ++){
                System.out.println();   
                System.out.print( "     =------------------------------------------------------------=     " );
                System.out.println();   
                System.out.print( "            Atas Nama Mahasiswa : " + dataMahasiswa[i] + "\n     " );
                System.out.print( "=------------------------------------------------------------=" );
                System.out.println();    
                for (int j = 0;j < nilaiMatkul[0].length ;j++ ) {
                    System.out.print("Masukkan Nilai Mata Kuliah " + mataKuliah[j] + " : ");
                    nilaiMatkul[i][j] = sc.nextInt();
                }   
            }
    }

//fungsi untuk mencetak Nilai Mata Kuliah
static void cetakNilai(){
        System.out.print( "          = Cetak Nilai Mata Kuliah =         " );
        System.out.println();
        System.out.println();
        System.out.print("Masukkan Absen Mahasiswa : " );
            int absen = sc.nextInt();
                System.out.println("Atas Nama Mahasiswa : "+dataMahasiswa[absen-1]);
                System.out.print("~------------------------------------------------~");
                System.out.println();
    
                for (int j = 0;j < nilaiMatkul[0].length ;j++ ) {
                    System.out.println("Nilai dari Mata Kuliah "+mataKuliah[j]+" : "+nilaiMatkul[absen-1][j]);
                }
                    System.out.println();
    }

//fungsi untuk menampilkan Nilai per Mata Kuliah
static void nilaiMahasiswa(){
     System.out.println("Nilai Per Mata Kuliah : ");
            for(int i=0;i<mataKuliah.length;i++){
                System.out.print((i+1)+ ". "+mataKuliah[i]);
                System.out.println();
                }
                    System.out.print("Masukkan Nomor Mata Kuliah : " );
                    int nomor = sc.nextInt();
                    System.out.println();
    
            System.out.print("===================================================");
            System.out.println();
            System.out.println("Nama Mata Kuliah : "+mataKuliah[nomor-1]   );
            System.out.print("===================================================");
            System.out.println();
    
            for (int j = 0;j < nilaiMatkul.length ;j++ ) {
                System.out.println("Nilai dari Mahasiswa "+dataMahasiswa[j]+" : "+nilaiMatkul[j][nomor-1]);
            }
                System.out.println();
    }

menuData();
