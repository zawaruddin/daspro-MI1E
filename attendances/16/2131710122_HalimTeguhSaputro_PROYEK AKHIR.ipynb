// %%
static void menuHarga(){
    System.out.println("=============MENU HARGA BARANG==============");
    String[][] menu = new String[namaBarang.length][2];
    for(int i = 0; i < menu.length; i++){
        for(int j = 0; j < menu[0].length; j++){
            menu[i][0] = namaBarang[i];
            menu[i][1] = Integer.toString(hargaBarang[i]);
        }
    }
    
    for(int i = 0; i < menu.length; i++){
        for(int j = 0; j < menu[0].length; j++){
            System.out.print(menu[i][j] + "\t\t");
        }
        System.out.println();
    }
    System.out.println();
}

static int TransaksiMulti(){
        System.out.print("Nama Barang "+ (++nomor) + " : ");
        barang = inputStr.nextLine();
        total = 0;
        beli = 0;
        satuan = 0;
        for(int j = 0; j < namaBarang.length; j++){
            if(barang.equalsIgnoreCase(namaBarang[j])){
                System.out.print("Berapa Banyak Barang: ");
                banyak = input.nextInt();
                if(jumlahBarang[j] <= 0){
                    System.out.println("!!Maaf Stok Barang Sudah Habis!!");
                    total = 0;
                    beli = 0;
                    satuan = 0;
                    break;
                }else if(banyak > jumlahBarang[j]){
                    System.out.println("!!Maaf Stok kurang. hanya ada " + jumlahBarang[j] + "!!");
                    harga = jumlahBarang[j] * hargaBarang[j];
                    beli = jumlahBarang[j];
                    jumlahBarang[j] -= banyak;
                    satuan = hargaBarang[j];
                }else if(banyak <= jumlahBarang[j]){
                    jumlahBarang[j] -= banyak;
                    beli = banyak;
                    harga = banyak * hargaBarang[j];
                    satuan = hargaBarang[j];
                }
            }else{
                continue;
            }
        total = harga;
        }
    return total;
}

static int Pembayaran(){
    boolean bool = true; 
    int uang = 0;
    while(bool){
        System.out.print("Masukkan Uang anda : ");
        int f = input.nextInt();
        bayar = f;
        if(bayar < totalPembelian){
            System.out.println("Maaf, Uang anda Kurang");
        }else if(bayar >= total){
            uang = bayar - totalPembelian;
            bool = false;
        }
    }
    return (uang);
}

static String[][] StokBarang(){
    System.out.println("==============MENU STOK BARANG==============");
    String[][] Barang = new String[namaBarang.length][3];
    System.out.println("   NAMA\t\t  HARGA\t\t  JUMLAH STOK");
    for (int i = 0; i < Barang.length; i++){
        for(int j = 0; j < Barang[0].length; j++){
            Barang[i][0] = namaBarang[i];
            Barang[i][1] = Integer.toString(hargaBarang[i]);
            if(jumlahBarang[i] < 0){
                jumlahBarang[i] = 0;
            }
            Barang[i][2] = Integer.toString(jumlahBarang[i]);
            
        }
    }
    return Barang;
}

static int menuUtama(){
    int q = 0, pilih;
    System.out.println("=================MENU UTAMA=================");
    while(q < fitur.length){
        System.out.println((q+1) + ". " + fitur[q]);
        q++;
    }
    System.out.println("============================================");
    System.out.print("Silahkan Pilih Menu : ");
    pilih = input.nextInt();
    System.out.println();
    return (pilih);
}

//INISIALISASI
Scanner input = new Scanner(System.in);
Scanner inputStr = new Scanner(System.in);
Scanner inputChr = new Scanner(System.in);

String[] namaBarang = {"Mineral", "Cola", "Susu", "Nescafe", 
                       "Sasa", "Rinso", "kecap", "mentega", 
                       "Mie", "Sabun", "Tissue"};

int[] hargaBarang = {3000, 5000, 4000, 4000, 
                     6000, 25000, 8000, 7000, 
                     3000, 6000, 18000};

int[] jumlahBarang = {100, 100, 100, 100, 
                      80, 50, 100, 100, 
                      100, 100, 60};

String[][] nota = new String[100][4];
String[] fitur = {"Menu dan Harga", "Transaksi", "Stok Barang", "STOP"};
String barang;
int jumlahPembelian, total, banyak, totalPembelian, kembalian, bayar, harga, satuan, beli, nomor;


//MAIN PROGRAM
System.out.println("Selamat Datang di MiniMarket Halim Sejahtera");
System.out.println("============================================");
boolean indikator = true;
do{
    switch(menuUtama()){
        case 1 : 
            menuHarga();
            break;
        case 2 :
            boolean bool1 = false;
            for(int i = 0; !bool1; i++){
                int hasil = TransaksiMulti();
                nota[i][0] = barang;
                nota[i][1] = Integer.toString(beli);
                nota[i][2] = Integer.toString(satuan);
                nota[i][3] = Integer.toString(hasil);
                totalPembelian += hasil;
                System.out.print("ingin beli lagi? (y/n) : ");
                char jawab = inputChr.next().charAt(0);
                System.out.println();
                if(jawab == 'n'){
                    bool1 = true;
                }else if(jawab == 'y'){
                    bool1 = false;
                }
            }
            System.out.println("============================================");
            for(int i = 0; i<nota.length; i++){
                if(nota[i][0] == null){
                    break;
                }else{
                    for(int j=0; j<nota[0].length; j++){
                        System.out.print(nota[i][j] + "\t" );
                    }
                }
                System.out.println();
            }
            System.out.println("============================================");
            System.out.println("Total : " + totalPembelian);
            kembalian = Pembayaran();
            System.out.println("============================================\n");
            
            System.out.println("===============HALIM SEJAHTERA==============\n");
            for(int i = 0; i<nota.length; i++){
                if(nota[i][0] == null){
                    break;
                }else{
                    for(int j=0; j<nota[0].length; j++){
                        System.out.print(nota[i][j] + "\t" );
                    }
                }
                System.out.println();
            }
            System.out.println("============================================");
            System.out.println("\tTotal\t\t: " + totalPembelian);
            System.out.println("\tBayar\t\t: " + bayar);
            System.out.println("\tKembalian\t: " + kembalian);
            System.out.println("============================================\n");
            break;
        case 3 :
            String[][] tampungStok = StokBarang();
            for (int i = 0; i<tampungStok.length; i++){
                for (int j = 0; j<tampungStok[0].length; j++){
                    System.out.print(tampungStok[i][j] + "\t\t");
                }
            System.out.println();
            }
            System.out.println();
            break;
        case 4 :
            System.out.println("============================================================");
            System.out.println("TERIMA KASIH TELAH BERBELANJA DI MINI MARKET HALIM SEJAHTERA");
            System.out.println("============================================================");
            indikator = false;
            break;
        default :
            System.out.println("Masukkan Sesuai Nomor Menu yang Tersedia");
    }
}while(indikator == true);
// Out:
// Selamat Datang di MiniMarket Halim Sejahtera
// ...
// =================MENU UTAMA=================
// 1. Menu dan Harga
// 2. Transaksi
// 3. Stok Barang
// 4. STOP
// ...
// Silahkan Pilih Menu : 1
//
// =============MENU HARGA BARANG==============
// Mineral		3000
// Cola		5000
// Susu		4000
// Nescafe		4000
// Sasa		6000
// Rinso		25000
// kecap		8000
// mentega		7000
// Mie		3000
// Sabun		6000
// Tissue		18000
//
// =================MENU UTAMA=================
// 1. Menu dan Harga
// 2. Transaksi
// 3. Stok Barang
// 4. STOP
// ...
// Silahkan Pilih Menu : 3
//
// ==============MENU STOK BARANG==============
//    NAMA		  HARGA		  JUMLAH STOK
// Mineral		3000		100
// Cola		5000		100
// Susu		4000		100
// Nescafe		4000		100
// Sasa		6000		80
// Rinso		25000		50
// kecap		8000		100
// mentega		7000		100
// Mie		3000		100
// Sabun		6000		100
// Tissue		18000		60
//
// =================MENU UTAMA=================
// 1. Menu dan Harga
// 2. Transaksi
// 3. Stok Barang
// 4. STOP
// ...
