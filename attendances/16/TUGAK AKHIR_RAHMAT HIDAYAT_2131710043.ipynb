// %%
import java.util.Scanner;
    static int menu, jenisB, berat, jenisL, total, bayar, kembalian;
    static Scanner input = new Scanner (System.in);
    static String nama, alamat, kota, kecamatan, prov;
    static char lanjut;

    static void Total(int jenisL){
        if (jenisL == 1){
            System.out.println("Biaya Pengiriman per Kg\t\t : Rp. 15.500");
            System.out.print("Berat Barang yang dikirim (Kg)\t : ");
            berat = input.nextInt();
            total = berat * 15500;
            System.out.print("Total Harga\t\t\t : Rp. " + total);
            System.out.print("\n");
            System.out.print("Jumlah uang anda\t\t : Rp. ");
            bayar = input.nextInt();
            if (bayar >= total){
                kembalian = bayar - total;
                System.out.print("Kembalian anda\t\t\t : Rp. " + kembalian);
            }
            else if (bayar <= total){
                System.out.print("\n");
                System.out.print("========PEMBAYARAN DITOLAK========");
            }
        } else if (jenisL == 2){
            System.out.println("Biaya Pengiriman per Kg\t\t : Rp. 19000");
            System.out.print("Berat Barang yang dikirim (Kg)\t : ");
            berat = input.nextInt();
            total = berat * 19000;
            System.out.print("Total Harga\t\t\t : Rp. " + total);
            System.out.print("\n");
            System.out.print("Jumlah uang anda\t\t : Rp. ");
            bayar = input.nextInt();
            kembalian = bayar - total;
            System.out.print("Kembalian anda\t\t\t : Rp. " + kembalian);
        } else if (jenisL == 3){
            System.out.println("Biaya Pengiriman per Kg\t\t : Rp. 30.000");
            System.out.print("Berat Barang yang dikirim (Kg)\t : ");
            berat = input.nextInt();
            total = berat * 30000;
            System.out.print("Total Harga\t\t\t : Rp. " + total);
            System.out.print("\n");
            System.out.print("Jumlah uang anda\t\t : Rp. ");
            bayar = input.nextInt();
            if (bayar >= total){
                kembalian = bayar - total;
                System.out.print("Kembalian anda\t\t\t : Rp. " + kembalian);
            }
            else if (bayar <= total){
                System.out.print("\n");
                System.out.print("========PEMBAYARAN DITOLAK========");
        } else if (jenisL == 4){
            System.out.println("Biaya Pengiriman per Kg\t : Rp. 100.000");
            System.out.print("Berat Barang yang dikirim (Kg)\t : ");
            berat = input.nextInt();
            total = berat * 100000;
            System.out.print("Total Harga\t\t\t : Rp. " + total);
            System.out.print("\n");
            System.out.print("Jumlah uang anda\t : Rp. ");
            bayar = input.nextInt();
            if (bayar >= total){
                kembalian = bayar - total;
                System.out.print("Kembalian anda\t\t\t : Rp. " + kembalian);
            }
            else if (bayar <= total){
                System.out.print("\n");
                System.out.print("========PEMBAYARAN DITOLAK========");
        } else if (jenisL == 5){
            System.out.println("Biaya Pengiriman per Kg\t\t : Rp. 5.000");
            System.out.print("Berat Barang yang dikirim (Kg)\t : ");
            berat = input.nextInt();
            total = berat * 5000;
            System.out.print("Total Harga\t\t : Rp. " + total);
            System.out.print("\n");
            System.out.print("Jumlah uang anda\t\t\t : Rp. ");
            bayar = input.nextInt();
            if (bayar >= total){
                kembalian = bayar - total;
                System.out.print("Kembalian anda\t\t\t : Rp. " + kembalian);
            }
            else if (bayar <= total){
                System.out.print("\n");
                System.out.print("========PEMBAYARAN DITOLAK========");
        } else {
            System.out.print("Data yang Anda Masukkan Salah");
        }
    }

        do{System.out.println("========PILIH MENU========");
        String [] pilmenu = {" 1. Jasa Layanan Pengiriman", " 2. Jenis Barang yang dapat dikirim", " 3. Pengiriman"};
        int x;
        for(x = 0; x < pilmenu.length; x++){
            System.out.println(pilmenu[x]);
        }
        System.out.print("\nPilih Menu\t : ");
        menu = input.nextInt();
        System.out.print("\n");
        if (menu == 1){
            System.out.print(" 1. Reguler\t (6 - 7 Hari)\t HARGA Rp. 15.500/kg \n 2. Kilat\t (3 - 4 Hari)\t HARGA Rp. 19.000/kg \n 3. Sicepat\t (2 - 3 Hari)\t HARGA Rp. 30.000/kg \n 4. The Flash\t (1 Hari)\t HARGA Rp. 100.000/kg \n 5. Insyaallah\t\t\t HARGA Rp. 5.000/kg");
        } else if (menu == 2){
            System.out.print(" 1. Elektronik \n 2. Makanan \n 3. Otomotif \n 4. Apparel");
        }else if (menu == 3){
        System.out.println("========ASAL BARANG========");
        System.out.print("Nama Pengirim\t: ");
        nama = input.next();   
        System.out.print("Alamat pengirim\t: ");
        alamat = input.next();
        System.out.print("Kecamatan\t: ");
        kecamatan = input.next();
        System.out.print("Kota\t\t: ");
        kota = input.next();
        System.out.print("Provinsi\t: ");
        prov = input.next();
        System.out.println("\n");

        System.out.println("\n");
        System.out.println("========TUJUAN BARANG========");
        System.out.print("Nama penerima\t: ");
        nama = input.next();
        System.out.print("Alamat penerima\t: ");
        alamat = input.next();
        System.out.print("Kecamatan\t: ");
        kecamatan = input.next();
        System.out.print("Kota\t\t: ");
        kota = input.next();
        System.out.print("Provinsi\t: ");
        prov = input.next();
        System.out.print("\n");
            
        System.out.println("\n");
        System.out.println("========JENIS BARANG========");
        String [] jenisbarang = {" 1. Elektronik", " 2. Makanan", " 3. Otomotif", " 4. Apparel"};
        int z;
        for(z = 0; z < jenisbarang.length; z++){
            System.out.println(jenisbarang[z]);
        }
        System.out.print("Pilih Jenis Barang yang dikirim\t : ");
        jenisB = input.nextInt();

        System.out.println("\n");
        System.out.println("========JENIS LAYANAN========");
        String[] jenislayanan = {" 1. Reguler\t\t(6 - 7 Hari)", " 2. Kilat\t\t(3 - 6 Hari)", " 3. Sicepat\t\t(2 - 3 Hari)", " 4. The Flash\t\t(1 Hari)", " 5. Insyaallah"};
        for (String s : jenislayanan) {
            System.out.println(s);
        }
        System.out.print("Pilih Jenis Layanan yang ingin di gunakan\t : ");
        jenisL = input.nextInt();
        System.out.println("\n");
        Total(jenisL);


            
        } System.out.println("\n");
        System.out.print("Lakukan Tranksaksi Ulang ? (Y/T) : ");
        lanjut = input.next().charAt(0);
           System.out.print("\n");
           System.out.print("\n");
    }while(lanjut=='y'||lanjut=='Y');
            

        System.out.println("\n");
// Out:
// ========PILIH MENU========
//  1. Jasa Layanan Pengiriman
//  2. Jenis Barang yang dapat dikirim
//  3. Pengiriman
//
// Pilih Menu	 : 3
//
// ========ASAL BARANG========
// Nama Pengirim	: q
// Alamat pengirim	: q
// Kecamatan	: q
// Kota		: q
// Provinsi	: q
//
//
//
//
// ========TUJUAN BARANG========
// Nama penerima	: q
// Alamat penerima	: q
// Kecamatan	: q
// Kota		: q
// Provinsi	:
// q
//
//
//
// ========JENIS BARANG========
//  1. Elektronik
//  2. Makanan
//  3. Otomotif
//  4. Apparel
// Pilih Jenis Barang yang dikirim	 : 1
//
//
// ========JENIS LAYANAN========
//  1. Reguler		(6 - 7 Hari)
//  2. Kilat		(3 - 6 Hari)
//  3. Sicepat		(2 - 3 Hari)
//  4. The Flash		(1 Hari)
//  5. Insyaallah
// Pilih Jenis Layanan yang ingin di gunakan	 : 1
//
//
// Biaya Pengiriman per Kg		 : Rp. 15.500
// Berat Barang yang dikirim (Kg)	 : 2
// Total Harga			 : Rp. 31000
// Jumlah uang anda		 : Rp. 1
// Ditolak
//
// Lakukan Tranksaksi Ulang ? (Y/T) :
