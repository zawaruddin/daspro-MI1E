// %% [markdown]
// # UAS PRAKTIKUM DASAR PEMROGRAMAN
//
//
// ### NIM : 2131710046
// ### NAMA : SABILA NADIA ISLAMIA

// %% [markdown]
// ## SISTEM PENGGAJIAN PEGAWAI

// %%
import java.util.Scanner;

// Fungsi Menu 1
public static void MenuKetentuan(){
    System.out.println("\t\t\t\t\t\tKETENTUAN PENGGAJIAN PEGAWAI");
            System.out.println("\t\t\t\t\t(Periode 1 Desember 2021 - 30 Desember 2021)");
            System.out.println();


            System.out.println("Sesuai dengan ketentuan yang telah dibuat, berikut sistem penggajian Perusahaan Sky periode 2021.");
            System.out.println();

            System.out.println("\t# Gaji Pokok akan dihitung per hari, dengan ketentuan : ");
            System.out.println("\t\tGolongan 1\t : IT");
            System.out.println("\t\tGolongan 2\t : HRD dan Finance");
            System.out.println("\t\tGolongan 3\t : Kreatif dan Staff");
            System.out.println();
            System.out.println("\t\tGolongan 1\t : Rp 200.000,- / hari");
            System.out.println("\t\tGolongan 2\t : Rp 150.000,- / hari");
            System.out.println("\t\tGolongan 3\t : Rp 100.000,- / hari");
            System.out.println();

            System.out.println("\t# Tunjangan Kesehatan Pegawai per bulan, dengan ketentuan : ");
            System.out.println("\t\tGolongan 1\t : 15%");
            System.out.println("\t\tGolongan 2\t : 10%");
            System.out.println("\t\tGolongan 3\t : 5%");
            System.out.println();

            System.out.println("\t# Lembur Pegawai akan di hitung per jam, dengan ketentuan : ");
            System.out.println("\t\tPer jam : Rp 8.000,-");
            System.out.println();

            System.out.println("\t# Keterlambatan akan berlaku ketentuan : ");
            System.out.println("\t\tPemotongan 10% dari gaji pokok per hari dikalikan berapa jam keterlambatan");
}

// Fungsi Menu 2
public static void MenuDataPegawai(){
    System.out.println("\t\t\t\t\t\tDATA PEGAWAI PERUSAHAAN SKY"); 
    for(int i = 0; i < 10; i++){
                System.out.println((i+1) + (". ") + "\tNama Pegawai\t\t : " + nama[i]);
                System.out.println("\tNomor Induk Kependudukan : " + nomorInduk[i]);
                System.out.println("\tTempat Tanggal Lahir\t : " + ttl[i]);
                System.out.println("\tJenis Kelamin\t\t : " + jk[i]);
                System.out.println("\tAgama\t\t\t : " + agama[i]);
                System.out.println("\tAlamat\t\t\t : " + alamat[i]);
                System.out.println("\tJabatan\t\t\t : " + jabatan[i]);
                System.out.println("\tDivisi\t\t\t : " + divisi[i]);
                System.out.println();
    }
}

// Fungsi Menu 3
public static void MenuPerhitunganGaji(){
    do{
        long[] no = new long[1]; 

        System.out.println("Daftar Nomor Induk Pegawai"); 
        for(int h = 0; h < nomorPegawai.length; h++){
            System.out.println(nomorPegawai[h] + " : " + nama[h]); 
        } 
        
            for(int i = 0; i < no.length; i++){
                System.out.println();
                System.out.print("Masukkan Nomer Induk Pegawai : ");
                no[i] = input.nextInt();
                System.out.print("Nomor Induk Pegawai yang Anda masukkan adalah " + no[i]);
                System.out.println();
                System.out.println();

                    int j = 0;
                    while (j < 10){
                        if(no[i] == nomorPegawai[j]){
                            System.out.println("\t\t\t\t\t\t\tSistem Penggajian");
                            System.out.println("Nama Pegawai\t\t : " + nama[j]);
                            System.out.println("Nomor Induk Kependudukan : " + nomorInduk[j]);
                            System.out.println("Tempat Tanggal Lahir\t : " + ttl[j]);
                            System.out.println("Jenis Kelamini\t\t : " + jk[j]);
                            System.out.println("Agama\t\t\t : " + agama[j]);
                            System.out.println("Alamat\t\t\t : " + alamat[j]);
                            System.out.println("Jabatan\t\t\t : " + jabatan[j]);
                            System.out.println("Divisi\t\t\t : " + divisi[j]);  
                            
                                // Peogram Menentukan Golongan Gaji
                                System.out.println();
                                System.out.println("--- Golongan Gaji ----");
                            
                                // Golongan 1
                                if(divisi[j] == macamDivisi[4]){
                                    gapok = gaji[0] * bulan;
                                    tnjgn = gapok * tunjangan[0]; 
                                    gatot = gapok + tnjgn;
                                    System.out.println();
                                    System.out.println("Gaji yang akan di terima adalah Gaji Golongan 1");
                                    System.out.println("Gaji Pokok dalam satu bulan penuh sejumlah " + gapok);
                                    System.out.println("Tunjangan yang di dapatkan sebanyak " + tnjgn);
                                    System.out.println("Total Gaji sebanyak " + gatot);

                                    System.out.println();
                                    System.out.println("--- Bonus dan Pengurangan dari Data Lembur, Keterlambatan, dan Absen ---");
                                    System.out.println();
                                    System.out.print("Masukkan Data Absen (hari / dalam 1 bulan) \t\t: ");
                                    absenHari = input.nextInt();
                                    System.out.print("Masukkan Data Lembur (jam / dalam 1 bulan) \t\t: ");
                                    lemburJam = input.nextInt();
                                    System.out.print("Masukkan Data Keterlambatan (jam / dalam 1 bulan) \t: ");
                                    lambatJam = input.nextInt();
                                    
                                    // Program Perhitungan Bonus, Lambat, Absen
                                    absen = bulan - absenHari; 
                                    gatotProses = absen * gaji[0];
                                    bonus = lemburJam * 8000; 
                                    lambat = gaji[0] * 0.1 * lambatJam; 
                                    nominalAbsen = absenHari * gaji[0];

                                    gajiAkhir = gatotProses + tnjgn + bonus - lambat;
                                    System.out.println("Gaji Akhir yang di Dapatkan " + gajiAkhir);

                                // Golongan 2
                                } else if (divisi[j] == macamDivisi[0] || divisi[0] == macamDivisi[1]){
                                    gapok = gaji[1] * bulan;
                                    tnjgn = gapok * tunjangan[1]; 
                                    gatot = gapok + tnjgn; 
                                    System.out.println();
                                    System.out.println("Gaji yang akan di terima adalah Gaji Golongan 2");
                                    System.out.println("Gaji Pokok dalam satu bulan sejumlah " + gapok);
                                    System.out.println("Tunjangan yang di dapatkan sebanyak " + tnjgn);
                                    System.out.println("Total Gaji sebanyak " + gatot);

                                    System.out.println();
                                    System.out.println("--- Bonus dan Pengurangan dari Data Lembur, Keterlambatan, dan Absen ---");
                                    System.out.println();
                                    System.out.print("Masukkan Data Absen (hari / dalam 1 bulan) \t\t: ");
                                    absenHari = input.nextInt();
                                    System.out.print("Masukkan Data Lembur (jam / dalam 1 bulan) \t\t: ");
                                    lemburJam = input.nextInt();
                                    System.out.print("Masukkan Data Keterlambatan (jam / dalam 1 bulan) \t: ");
                                    lambatJam = input.nextInt();
                                    
                                    // Program Perhitungan Bonus, Lambat, Absen
                                    absen = bulan - absenHari; 
                                    gatotProses = absen * gaji[1];
                                    bonus = lemburJam * 8000; 
                                    lambat = gaji[1] * 0.1 * lambatJam; 
                                    nominalAbsen = absenHari * gaji[1];

                                    gajiAkhir = gatotProses + tnjgn + bonus - lambat;
                                    System.out.println("Gaji Akhir yang di Dapatkan " + gajiAkhir);

                                // Golongan 3
                                } else if (divisi[j] == macamDivisi[2] || divisi[0] == macamDivisi[3]){
                                    gapok = gaji[2] * bulan;
                                    tnjgn = gapok * tunjangan[2]; 
                                    gatot = gapok + tnjgn; 
                                    System.out.println();
                                    System.out.println("Gaji yang akan di terima adalah Gaji Golongan 3");
                                    System.out.println("Gaji Pokok dalam satu bulan sejumlah " + gapok);
                                    System.out.println("Tunjangan yang di dapatkan sebanyak " + tnjgn);
                                    System.out.println("Total Gaji sebanyak " + gatot);

                                    System.out.println();
                                    System.out.println("--- Bonus dan Pengurangan dari Data Lembur, Keterlambatan, dan Absen ---");
                                    System.out.println();
                                    System.out.print("Masukkan Data Absen (hari / dalam 1 bulan) \t\t: ");
                                    absenHari = input.nextInt();
                                    System.out.print("Masukkan Data Lembur (jam / dalam 1 bulan) \t\t: ");
                                    lemburJam = input.nextInt();
                                    System.out.print("Masukkan Data Keterlambatan (jam / dalam 1 bulan) \t: ");
                                    lambatJam = input.nextInt();
                                
                                    // Program Perhitungan Bonus, Lambat, Absen
                                    absen = bulan - absenHari; 
                                    gatotProses = absen * gaji[2];
                                    bonus = lemburJam * 8000; 
                                    lambat = gaji[2] * 0.1 * lambatJam; 
                                    nominalAbsen = absenHari * gaji[2];

                                    gajiAkhir = gatotProses + tnjgn + bonus - lambat;
                                    System.out.println("Gaji Akhir yang di Dapatkan " + gajiAkhir);
                                    
                        } else {
                            System.out.println("Golongan tidak ditemukan.");
                        }
                            
                        System.out.println();
                        System.out.println("===================================================");
                        System.out.print("Cetak Slip Gaji? (Y/T) : ");
                        slip = input.next().charAt(0); 
                        System.out.println("==================================================="); 

                        // Program Mencetak Slip Gaji
                        if(slip == 'Y' || slip == 'y'){
                            System.out.println();
                            System.out.println("\t\t\t\t\t\t\tPERUSAHAAN SKY");
                            System.out.println("\t\t\t\t\t(Periode 1 Desember 2021 - 30 Desember 2021)"); 
                            System.out.println();
                            System.out.println("Nama Pegawai\t\t : " + nama[j]);
                            System.out.println("Nomor Induk Kependudukan : " + nomorInduk[j]);
                            System.out.println("Tempat Tanggal Lahir\t : " + ttl[j]);
                            System.out.println("Jenis Kelamini\t\t : " + jk[j]);
                            System.out.println("Agama\t\t\t : " + agama[j]);
                            System.out.println("Alamat\t\t\t : " + alamat[j]);
                            System.out.println("Jabatan\t\t\t : " + jabatan[j]);
                            System.out.println("Divisi\t\t\t : " + divisi[j]); 

                            System.out.println();
                            System.out.println("KETERANGAN GAJI");
                            System.out.println("Gaji Pokok\t\t : Rp" + gapok);
                            System.out.println("Tunjangan\t\t : Rp" + tnjgn);
                            System.out.println("Absen (Izin)\t\t : " + absenHari + " hari (- Rp" + nominalAbsen + ")");
                            System.out.println("Keterlambatan\t\t : " + lambatJam + " jam (- Rp" + lambat + ")");
                            System.out.println("Bonus (Lembur)\t\t : "+ lemburJam + " jam (+ Rp" + bonus + ")");
                            System.out.println("TOTAL\t\t\t : Rp" + gajiAkhir);

                            System.out.println();
                            System.out.println("\t\t\t\t\t\t\t\t\t\t\tMalang, 31 Desember 2021");
                            System.out.println("\t\t\t\t\t\t\t\t\t\t\tManajer Operasional");
                            System.out.println();
                            System.out.println();
                            System.out.println("\t\t\t\t\t\t\t\t\t\t\tSabila Nadia Islamia");
                        }
                            
                        }
                        j++;
                    }
                    
                System.out.println();
                System.out.print("Apakah Anda ingin menghitung kembali? (Y/T) "); 
                ulang = input.next().charAt(0);

                System.out.println();
            }

    } while (ulang == 'Y' || ulang == 'y'); 
    
}

// Fungsi Menu 4
public static void MenuPencarianPegawai(){  
    do{
        System.out.println("Daftar Nomor Induk Pegawai"); 
        for(int h = 0; h < nomorPegawai.length; h++){
            System.out.println(nomorPegawai[h] + " : " + nama[h]); 
        }
        
        long[] no = new long[1]; 

            for(int i = 0; i < no.length; i++){
                System.out.println();
                System.out.print("Masukkan Nomer Induk Pegawai : ");
                no[i] = input.nextInt();
                System.out.print("Nomor Induk Pegawai yang Anda masukkan adalah " + no[i]);
                System.out.println();
                System.out.println();

                    int j = 0;
                    while (j < 10){ 
                        if(no[i] == nomorPegawai[j]){
                            System.out.println("\t\t\t\t\t\t\tData Pegawai");
                            System.out.println("Nama Pegawai\t\t : " + nama[j]);
                            System.out.println("Nomor Induk Kependudukan : " + nomorInduk[j]);    
                            System.out.println("Tempat Tanggal Lahir\t : " + ttl[j]);
                            System.out.println("Jenis Kelamini\t\t : " + jk[j]);
                            System.out.println("Agama\t\t\t : " + agama[j]);
                            System.out.println("Alamat\t\t\t : " + alamat[j]);
                            System.out.println("Jabatan\t\t\t : " + jabatan[j]);
                            System.out.println("Divisi\t\t\t : " + divisi[j]);  
                            break; 
                        }
                            j++;
                    }
                    
                    System.out.println();
                    System.out.print("Apakah Anda ingin mencari lagi? (Y/T) ");
                    ulang = input.next().charAt(0);

                    System.out.println();
            }

    } while (ulang == 'Y' || ulang == 'y'); 
}

// Fungsi Menu 5
public static void MenuPelaporan(){
    System.out.println("\t\t\t\t\t\tLaporan Keuangan Perusahaan Sky");
            System.out.println("\t\t\t\t\t(Periode 1 Desember 2021 - 30 Desember 2021)"); 

    for(int i = 0; i < nomorPegawai.length; i++){
        System.out.println();
        System.out.println("Nama Pegawai\t\t : " + nama[i]);
        System.out.println("Nomor Induk Kependudukan : " + nomorInduk[i]);
        System.out.println("Tempat Tanggal Lahir\t : " + ttl[i]);
        System.out.println("Jenis Kelamini\t\t : " + jk[i]);
        System.out.println("Agama\t\t\t : " + agama[i]);
        System.out.println("Alamat\t\t\t : " + alamat[i]);
        System.out.println("Jabatan\t\t\t : " + jabatan[i]);
        System.out.println("Divisi\t\t\t : " + divisi[i]);  
                            
        // Peogram Menentukan Golongan Gaji
        System.out.println();
        System.out.println("--- Input Data ----");
                            
        // Golongan 1
        if(divisi[i] == macamDivisi[4]){
            gapok = gaji[0] * bulan;
            tnjgn = gapok * tunjangan[0]; 
            gatot = gapok + tnjgn;
                            
        System.out.print("Masukkan Data Absen (hari / dalam 1 bulan) \t\t: ");
        absenHari = input.nextInt();
        System.out.print("Masukkan Data Lembur (jam / dalam 1 bulan) \t\t: ");
        lemburJam = input.nextInt();
        System.out.print("Masukkan Data Keterlambatan (jam / dalam 1 bulan) \t: ");
        lambatJam = input.nextInt();
                                    
        // Program Perhitungan Bonus, Lambat, Absen
        absen = bulan - absenHari; 
        gatotProses = absen * gaji[0];
        bonus = lemburJam * 8000; 
        lambat = gaji[0] * 0.1 * lambatJam; 

        pelaporanGaji[i] = gatotProses + + tnjgn + bonus - lambat;
                                    
        System.out.println("_________________________________________________________________________________________________");
     
        // Golongan 2
        } else if (divisi[i] == macamDivisi[0] || divisi[i] == macamDivisi[1]){
            gapok = gaji[1] * bulan;
            tnjgn = gapok * tunjangan[1]; 
            gatot = gapok + tnjgn; 
            System.out.println();

        System.out.print("Masukkan Data Absen (hari / dalam 1 bulan) \t\t: ");
        absenHari = input.nextInt();
        System.out.print("Masukkan Data Lembur (jam / dalam 1 bulan) \t\t: ");
        lemburJam = input.nextInt();
        System.out.print("Masukkan Data Keterlambatan (jam / dalam 1 bulan) \t: ");
        lambatJam = input.nextInt();
                                    
        // Program Perhitungan Bonus, Lambat, Absen
        absen = bulan - absenHari; 
        gatotProses = absen * gaji[1];
        bonus = lemburJam * 8000; 
        lambat = gaji[1] * 0.1 * lambatJam; 

        pelaporanGaji[i] = gatotProses + + tnjgn + bonus - lambat;
                                    
        System.out.println("_________________________________________________________________________________________________");
                                    
        // Golongan 3
        } else if (divisi[i] == macamDivisi[2] || divisi[i] == macamDivisi[3]){
            gapok = gaji[2] * bulan;
            tnjgn = gapok * tunjangan[2]; 
            gatot = gapok + tnjgn; 

        System.out.print("Masukkan Data Absen (hari / dalam 1 bulan) \t\t: ");
        absenHari = input.nextInt();
        System.out.print("Masukkan Data Lembur (jam / dalam 1 bulan) \t\t: ");
        lemburJam = input.nextInt();
        System.out.print("Masukkan Data Keterlambatan (jam / dalam 1 bulan) \t: ");
        lambatJam = input.nextInt();
                                
        // Program Perhitungan Bonus, Lambat, Absen
        absen = bulan - absenHari; 
        gatotProses = absen * gaji[2];
        bonus = lemburJam * 8000; 
        lambat = gaji[2] * 0.1 * lambatJam; 

        pelaporanGaji[i] = gatotProses + + tnjgn + bonus - lambat;
                                    
        System.out.println("_________________________________________________________________________________________________");
                                    
        } else {
            System.out.println("Golongan tidak ditemukan.");
        }
        
    }       
    
            System.out.println();
            System.out.println("_________________________________________________________________________________________________");
            System.out.println("\t\tNama\t\t|\t\tDivisi\t\t|\t\tGaji\t\t|");
            System.out.println("_________________________________________________________________________________________________");
    
                
                total = 0;
                for(int k = 0; k < nama.length; k++){ 
                    System.out.println((k+1) + ".\t" + nama[k] + "\t\t\t\t" + divisi[k] + "\t\t\t\t" + pelaporanGaji[k]);
                    total += pelaporanGaji[k];
                }

            System.out.println("_________________________________________________________________________________________________");
            System.out.println("\t\t\t\t\t\t\t\t\t\t\tTOTAL : " + total);
    
}

// Deklarasi, insialisasi, dan instansiasi
Scanner input = new Scanner(System.in); 
char ulangi, lagi, ulang, slip;
int bulan = 20; // Pegawai masuk di hari Senin - Jumat dalam 1 bulan 
int gapok, absenHari, lambatJam, lemburJam;
double tnjgn, gatot, total, lambat, bonus, absen, gatotProses, gajiAkhir;
double[] pelaporanGaji = new double[10];
double nominalAbsen; 

// Nama Pegawai
String[] nama = new String[10];
nama[0] = "Aulia Hana";
nama[1] = "Bagus Dewa";
nama[2] = "Cantika Yana";
nama[3] = "Devano Raga";
nama[4] = "Elang Yanuar";
nama[5] = "Fina Nur";
nama[6] = "Gilang Ardi";
nama[7] = "Hana Wicak"; 
nama[8] = "Ivano Maurer";
nama[9] = "Jefri Nikol";

// Jenis Kelamin Pegawai
String[] jk = new String[10]; 
jk[0] = "Perempuan";
jk[1] = "Laki-Laki";
jk[2] = "Perempuan";
jk[3] = "Laki-Laki";
jk[4] = "Laki-Laki";
jk[5] = "Perempuan";
jk[6] = "Laki-Laki";
jk[7] = "Perempuan";
jk[8] = "Laki-Laki";
jk[9] = "Laki-Laki";

// Tempat Tanggal Lahir Pegawai
String[] ttl = new String[10];
ttl[0] = "Malang, 2 September 2002";
ttl[1] = "Malang, 3 Oktober 2002";
ttl[2] = "Malang, 4 November 2002";
ttl[3] = "Malang, 5 Desember 2002";
ttl[4] = "Malang, 6 Januari 2002";
ttl[5] = "Malang, 7 Februari 2002";
ttl[6] = "Malang, 8 Maret 2002";
ttl[7] = "Malang, 9 April 2002";
ttl[8] = "Malang, 10 Mei 2002";
ttl[9] = "Malang, 11 Juni 2002";

// Agama Pegawai
String[] agama = new String[10];
agama[0] = "Islam";
agama[1] = "Kristen";
agama[2] = "Katolik";
agama[3] = "Kristen";
agama[4] = "Katolik";
agama[5] = "Islam";
agama[6] = "Katolik";
agama[7] = "Islam";
agama[8] = "Katolik";
agama[9] = "Kristen";

// Alamat Rumah Pegawai
String[] alamat = new String[10]; 
alamat[0] = "Jalan Matahari, No 13, Kota Malang";
alamat[1] = "Jalan Jingga, No 11, Kota Malang";
alamat[2] = "Jalan Senja, No 23, Kota Malang";
alamat[3] = "Jalan Jingga, No 32, Kota Malang";
alamat[4] = "Jalan Mawar, No 02, Kota Malang";
alamat[5] = "Jalan Melati, No 01, Kota Malang";
alamat[6] = "Jalan Anggrek, No 20, Kota Malang";
alamat[7] = "Jalan Semanggi, No 33, Kota Malang";
alamat[8] = "Jalan Remujung, No 22, Kota Malang";
alamat[9] = "Jalan Kaliurang, No 13, Kota Malang";

// Nomor Induk Pegawai
long[] nomorPegawai = new long[10];
nomorPegawai[0] = 123;
nomorPegawai[1] = 234;
nomorPegawai[2] = 345;
nomorPegawai[3] = 456;
nomorPegawai[4] = 567;
nomorPegawai[5] = 678;
nomorPegawai[6] = 789;
nomorPegawai[7] = 890;
nomorPegawai[8] = 900;
nomorPegawai[9] = 101;

// Jabatan Pegawai
String[] jabatan = new String[10];
jabatan[0] = "Kepala Bidang 1";
jabatan[1] = "Kepala Bidang 2";
jabatan[2] = "Kepala Bidang 3";
jabatan[3] = "Kepala Bidang 4";
jabatan[4] = "Kepala Bidang 5";
jabatan[5] = "Kepala Bidang 6";
jabatan[6] = "Kepala Bidang 7";
jabatan[7] = "Kepala Bidang 8"; 
jabatan[8] = "Kepala Bidang 9";
jabatan[9] = "Kepala Bidang 10";

// Macam Divisi
String[] macamDivisi = new String[5];
macamDivisi[0] = "HRD";
macamDivisi[1] = "Finance";
macamDivisi[2] = "Kreatif";
macamDivisi[3] = "Staff";
macamDivisi[4] = "IT"; 


// Divisi Pegawai
String[] divisi = new String[10];
divisi[0] = "HRD";
divisi[1] = "HRD";
divisi[2] = "Finance";
divisi[3] = "Kreatif";
divisi[4] = "Staff";
divisi[5] = "IT";
divisi[6] = "IT";
divisi[7] = "IT";
divisi[8] = "IT";
divisi[9] = "IT";

// Nomor Induk Kependudukan
String[] nomorInduk = new String[10];
nomorInduk[0] = "34719482650003";
nomorInduk[1] = "346289659362002";
nomorInduk[2] = "43618543720007";
nomorInduk[3] = "32436485930007";
nomorInduk[4] = "43728854639008";
nomorInduk[5] = "43729198000003";
nomorInduk[6] = "326154827465008";
nomorInduk[7] = "326573928573500";
nomorInduk[8] = "547382950475900";
nomorInduk[9] = "768493756493005";

// Golongan Gaji Pegawai (1-3)
int[] gaji = new int[3];
gaji[0] = 200000; // Golongan 1
gaji[1] = 150000; // Golongan 2
gaji[2] = 100000; // Golongan 3

// Tunjangan sesuai golongan gaji
double[] tunjangan = new double[3];
tunjangan[0] = 0.15; // Golongan 1
tunjangan[1] = 0.1;  // Golongan 2
tunjangan[2] = 0.05; // Golongan 3

// PILIHAN MENU atau FITUR  
do {    
    System.out.println();
    System.out.println("\t\t\t\t\t\tSISTEM PENGGAJIAN PEGAWAI");
    System.out.println();
    System.out.println("[1] Menu Ketentuan Penggajian");
    System.out.println("[2] Menu Data Pegawai");
    System.out.println("[3] Menu Perhitungan dan Cetak Slip Gaji");
    System.out.println("[4] Menu Pencarian Pegawai");
    System.out.println("[5] Menu Pelaporan" );
    System.out.println();

    // Input Nomor Menu yang ingin di akses 
    System.out.println("===================================================");
    System.out.print("Masukkan Nomor Menu yang Ingin di Akses : ");
    int nomor = input.nextInt();
    
    switch(nomor){
        case 1 :
            System.out.println("Anda Masuk pada Menu Ketentuan Penggajian");
            System.out.println("===================================================");
            System.out.println();

            MenuKetentuan();
            break;
            
        case 2: 
            System.out.println("Anda Masuk pada Menu Data Pegawai");
            System.out.println("===================================================");
            System.out.println();
            
            MenuDataPegawai(); 
            break;
            
        case 3: 
            System.out.println("Anda Masuk pada Menu Perhitungan dan Cetak Slip Gaji");
            System.out.println("===================================================");
            System.out.println();
            
            MenuPerhitunganGaji();
            break;
            
        case 4:
            System.out.println("Anda Masuk pada Menu Pencarian");
            System.out.println("===================================================");
            System.out.println();
            
            MenuPencarianPegawai(); 
            break;
            
        case 5: 
            System.out.println("Anda Masuk pada Menu Pelaporan");
            System.out.println("===================================================");
            System.out.println();
            
            MenuPelaporan();
            break;
    }
    
System.out.println();
    System.out.println("===================================================");
    System.out.print("Apakah Anda ingin menelusuri kembali (Y/T): ");
    ulangi = input.next().charAt(0);
    System.out.println("===================================================");
    System.out.println();  
    
} while (ulangi == 'y' || ulangi == 'Y');
// Out:
// 						SISTEM PENGGAJIAN PEGAWAI
//
// [1] Menu Ketentuan Penggajian
// [2] Menu Data Pegawai
// [3] Menu Perhitungan dan Cetak Slip Gaji
// [4] Menu Pencarian Pegawai
// [5] Menu Pelaporan
//
// ...
// Masukkan Nomor Menu yang Ingin di Akses : 1
// Anda Masuk pada Menu Ketentuan Penggajian
// ...
//
// 						KETENTUAN PENGGAJIAN PEGAWAI
// 					(Periode 1 Desember 2021 - 30 Desember 2021)
//
// Sesuai dengan ketentuan yang telah dibuat, berikut sistem penggajian Perusahaan Sky periode 2021.
//
// 	# Gaji Pokok akan dihitung per hari, dengan ketentuan :
// 		Golongan 1	 : IT
// 		Golongan 2	 : HRD dan Finance
// 		Golongan 3	 : Kreatif dan Staff
//
// 		Golongan 1	 : Rp 200.000,- / hari
// 		Golongan 2	 : Rp 150.000,- / hari
// 		Golongan 3	 : Rp 100.000,- / hari
//
// 	# Tunjangan Kesehatan Pegawai per bulan, dengan ketentuan :
// 		Golongan 1	 : 15%
// 		Golongan 2	 : 10%
// 		Golongan 3	 : 5%
//
// 	# Lembur Pegawai akan di hitung per jam, dengan ketentuan :
// 		Per jam : Rp 8.000,-
//
// ...
