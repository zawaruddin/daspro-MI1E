// %% [markdown]
// # JOBSHEET 11. ARRAY 2
// Nama:Ega Fadhilla Febryana
// NIM:2131710072

// %% [markdown]
// ## Tujuan
// * Mahasiswa mampu memahami pembuatan array dua dimensi
// * Mahasiswa mampu menyelesaikan studi kasus dengan memanfaatkan array dua dimensi

// %% [markdown]
// ## Alat dan Bahan
// * PC/Laptop
// * Browser
// * Koneksi internet
// * Anaconda3 + Java kernel (opsional)

// %% [markdown]
// ## Praktikum

// %% [markdown]
// ### Percobaan 1: Deklarasi, Inisialisasi, dan Menampilkan Array 2 Dimensi
// Pada Percobaan 1, kode program yang dibuat digunakan untuk menyimpan nilai praktikum dari 2 orang mahasiswa pada 3 mata kuliah yang berbeda.
// 1.	Buat array bertipe **integer** dengan nama **nilai** dengan kapasitas baris 2 elemen (menyatakan jumlah mahasiswa) dan kolom 3 elemen (menyatakan jumlah mata kuliah)
// ![Gambar 1](images/percobaan1-1.PNG)

// %%
// Tuliskan kode program Percobaan 1 Langkah 1
int[] [] nilai = new int[2][3];

// %% [markdown]
// 2. Isi masing-masing elemen array **nilai** sebagai berikut:
// ![Gambar 2](images/percobaan1-2.PNG)

// %%
// Tuliskan kode program Percobaan 1 Langkah 2
nilai[0] [0] = 75;
nilai[0] [1] = 90;
nilai[0] [2] = 88;
nilai[1] [0] = 79;
nilai[1] [1] = 82;
nilai[1] [2] = 67;
// Out:
// 67

// %% [markdown]
// 3. Tampilkan semua isi elemen array **nilai**
// ![Gambar 3](images/percobaan1-3.PNG)

// %%
// Tuliskan kode program Percobaan 1 Langkah 2
System.out.println(nilai[0] [0] + " " + nilai [0] [1] + " " + nilai[0] [2]);
System.out.println(nilai[1] [0] + " " + nilai [1] [1] + " " + nilai[1] [2]);
// Out:
// 75 90 88
// 79 82 67

// %% [markdown]
// #### Pertanyaan
// 1. Apakah pengisian elemen array harus dilakukan secara berurutan mulai dari indeks 0? Jelaskan!

// %% [markdown]
//  mesti . akan tetapi jika menggunakan looping harus berurutan , karena jika menggunakan lopping harus dimulai dari index 0 samapai index n .

// %% [markdown]
// 2. Lakukan modifikasi pada Percobaan 1 Langkah 3 untuk menampilkan semua isi elemen array **nilai** menggunakan perulangan *for*

// %%
// Tuliskan jawaban nomor 2
import java.util.Scanner;
Scanner sc = new Scanner(System.in);
int[] [] nilai = new int[2] [3];
nilai[0] [0] = 75;
nilai[0] [1] = 90;
nilai[0] [2] = 88;
nilai[1] [0] = 79;
nilai[1] [1] = 82;
nilai[1] [2] = 67;
for (int i=0; i < nilai.length; i++){
 for (int j = 0; j < nilai[0].length; j++){
 System.out.print(nilai[i][j] + " ");
 }
 System.out.println(" ");
}
// Out:
// 75 90 88
// 79 82 67

// %% [markdown]
// ### Percobaan 2: Mengisi Elemen Array 2 Dimensi Menggunakan Input Keyboard
// Pada Percobaan 2, kode program yang dibuat digunakan untuk menyimpan nilai rating restoran yang terdaftar pada aplikasi pemesanan makanan online. Rating diberikan oleh 4 orang pengguna kepada 2 restoran yang terdaftar.
// 1. Import dan deklarasikan Scanner dengan nama **sc**
// ![Gambar 4](images/percobaan2-1.jpg)

// %%
// Tuliskan kode program Percobaan 2 Langkah 1
import java.util.Scanner;
Scanner sc = new Scanner(System.in);

// %% [markdown]
// 2.	Buat array bertipe **integer** dengan nama **rating** dengan kapasitas baris 4 elemen (menyatakan jumlah pengguna) dan kolom 2 elemen (menyatakan jumlah restoran)
// ![Gambar 5](images/percobaan2-2.PNG)

// %%
// Tuliskan kode program Percobaan 2 Langkah 2
int[] [] rating = new int[4] [2];

// %% [markdown]
// 3. Dengan menggunakan perulangan *for*, buat input untuk mengisi elemen array **rating**
// ![Gambar 6](images/percobaan2-3.PNG)

// %%
// Tuliskan kode program Percobaan 2 Langkah 3
for (int i = 0; i < rating.length; i++) {
 for (int j = 0; j < rating[0].length; j++) {
 System.out.print("Masukkan rating pengguna " + i + " untuk restoran " + j + " : ");
 rating[i] [j] = sc.nextInt();
 }
 System.out.println("");
}
// Out:
// Masukkan rating pengguna 0 untuk restoran 0 : 0
// Masukkan rating pengguna 0 untuk restoran 1 : 1
//
// Masukkan rating pengguna 1 untuk restoran 0 : 2
// Masukkan rating pengguna 1 untuk restoran 1 : 3
//
// Masukkan rating pengguna 2 untuk restoran 0 : 4
// Masukkan rating pengguna 2 untuk restoran 1 : 5
//
// Masukkan rating pengguna 3 untuk restoran 0 : 6
// Masukkan rating pengguna 3 untuk restoran 1 : 7

// %% [markdown]
// 4. Dengan menggunakan perulangan *for-each*, tampilkan semua isi elemen dari array **rating**
// ![Gambar 7](images/percobaan2-4.PNG)

// %%
// Tuliskan kode program Percobaan 2 Langkah 4
for (int[] rtg : rating) {
 for (int r: rtg) {
 System.out.print(r + " ");
 }
 System.out.println("");
}
// Out:
// 0 1
// 2 3
// 4 5
// 6 7

// %% [markdown]
// #### Pertanyaan
// 1. Pada Percobaan 2 Langkah 3, dapatkah posisi i ditukar dengan posisi j? Jelaskan alasannya!

// %% [markdown]
//  Tuliskan jawaban nomor 1 :
//  Posisi variabel j dan i tentu saja bisa bisa ditukar , akan tetapi untuk outputnya jika ditukar dari posisi perulangan for akan sama . Dan jika dimulai dari system outPrintln maka hasilnya akan berbeda.

// %% [markdown]
// 2. Tambahkan kode program untuk menentukan banyaknya baris dan kolom elemen array secara dinamis (baris dan kolom ditentukan saat program berjalan melalui input keyboard)!

// %%
// Tuliskan jawaban nomor 2
import java.util.Scanner;
Scanner sc = new Scanner(System.in);
int[] [] rating = new int[4] [2];
for (int j = 0; j < rating.length; j++) {
 for (int i = 0; i < rating[0].length; i++) {
 System.out.print("Masukan rating pengguna " + j + " untuk restoran " + i + " : ");
 rating[j][i] = sc.nextInt();
 }
 System.out.println("");
}
// Out:
// Masukan rating pengguna 0 untuk restoran 0 : 0
// Masukan rating pengguna 0 untuk restoran 1 : 1
//
// Masukan rating pengguna 1 untuk restoran 0 : 2
// Masukan rating pengguna 1 untuk restoran 1 : 3
//
// Masukan rating pengguna 2 untuk restoran 0 : 4
// Masukan rating pengguna 2 untuk restoran 1 : 5
//
// Masukan rating pengguna 3 untuk restoran 0 : 6
// Masukan rating pengguna 3 untuk restoran 1 : 7

// %% [markdown]
// ### Percobaan 3: Melakukan Operasi Aritmatika pada Elemen Array 2 Dimensi
// Pada Percobaan 3, kode program yang dibuat digunakan untuk menghitung nilai rata-rata harga setiap bahan pokok selama 1 semester. Terdapat 3 bahan pokok yang dicatat harganya setiap akhir bulan. Program dibuat berdasarkan flowchart berikut.
// ![Gambar 8](images/percobaan3.jpg)
// 1. Import dan deklarasikan Scanner dengan nama **sc**
// ![Gambar 9](images/percobaan3-1.jpg)

// %%
import java.util.Scanner;
Scanner sc = new Scanner(System.in);// Tuliskan kode program Percobaan 3 Langkah 1

// %% [markdown]
// 2.	Buat array bertipe **integer** dengan nama **harga** dengan kapasitas baris 3 elemen (menyatakan jumlah bahan pokok) dan kolom 6 elemen (menyatakan jumlah bulan). Deklarasikan juga variabel **total** dan **rata** bertipe **double**
// ![Gambar 10](images/percobaan3-2.PNG)

// %%
// Tuliskan kode program Percobaan 3 Langkah 2
int [] [] harga = new int [3][6];
int i,j ;
double total, rata;

// %% [markdown]
// 3. Dengan menggunakan perulangan *for*, buat input untuk mengisi elemen array **harga**. Kemudian, perhitungan total harga dilakukan untuk setiap bulan (kolom) pada setiap bahan pokok (baris). Setelah itu, nilai rata-rata dihitung untuk setiap bahan pokok (tiap satu baris) dan ditampilkan
// ![Gambar 11](images/percobaan3-3.PNG)

// %%
// Tuliskan kode program Percobaan 3 Langkah 3
for (int i = 0; i < harga.length; i++) {
 total = 0;
 rata = 0;
 for (int j = 0; j < harga[0].length; j++) {
 System.out.printf("Masukan harga[%d][%d]: ", i, j);
 harga[i][j] = sc.nextInt();
 total += harga[i][j];
 }
 rata = total / harga[0].length;
 System.out.printf("Rata-rata harga bahan ke-%d adalah %.2f\n", i, rata);
}
// Out:
// Masukan harga[0][0]: 2000
// Masukan harga[0][1]: 3000
// Masukan harga[0][2]: 4000
// Masukan harga[0][3]: 5000
// Masukan harga[0][4]: 6000
// Masukan harga[0][5]: 7000
// Rata-rata harga bahan ke-0 adalah 4500.00
// Masukan harga[1][0]: 1000
// Masukan harga[1][1]: 2
// Masukan harga[1][2]: 3
// Masukan harga[1][3]: 4
// Masukan harga[1][4]: 5
// Masukan harga[1][5]: 6
// Rata-rata harga bahan ke-1 adalah 170.00
// Masukan harga[2][0]: 3
// Masukan harga[2][1]: 4
// Masukan harga[2][2]: 5
// Masukan harga[2][3]: 6
// Masukan harga[2][4]: 7
// Masukan harga[2][5]: 6
// Rata-rata harga bahan ke-2 adalah 5.17

// %% [markdown]
// #### Pertanyaan
// 1. Jelaskan fungsi dari **rata = total / harga[0].length**!

// %% [markdown]
// // Tuliskan jawaban nomor 1: Fungsi dari rata=total/harga[0].length yaitu untuk menghitung rata-rata dari baris 0 dan kolom 0 sampai banyaknya kolom dan baris.

// %% [markdown]
// 2. Mengapa insialisasi variabel **total = 0** dan **rata = 0** berada di dalam perulangan *for* yang pertama? Menurut Anda, apa yang terjadi jika inisialisasi kedua variabel tersebut diletakkan di luar perulangan *for* (setelah deklarasi array)?

// %% [markdown]
// // Tuliskan jawaban nomor 2: karena insialisasi variabel total = 0 dan rata-rata = 0 . Hal ini dibutuhkan untuk menentukan total dari insialisasi tersebut .

// %% [markdown]
// ## Tugas

// %% [markdown]
// 1. Perhatikan flowchart berikut.
// ![Gambar 12](images/tugas-1.jpg)
// Buat kode program sesuai dengan flowchart tersebut untuk mencari suhu tertinggi yang dicatat dari 5 kota di Jepang selama 7 hari berturut-turut!

// %%
// Tuliskan jawaban nomor 1
import java.util.Scanner;
Scanner sc = new Scanner(System.in);
double[][] suhu = new double [5][7];
int x, y;
double max=0;
for (x=0; x<suhu.length; x++){
 for (y=0; y<suhu[0].length; y++){
 System.out.print("Masukkan suhu kota " + (x+1) + " hari ke " + (y+1) + " : ");
 suhu[x] [y] = sc.nextDouble();
 if(suhu[x] [y] > max){
 max = suhu[x] [y];
 }
 }System.out.printf('\n' + " ");
}
System.out.print("Suhu tertinggi dari 5 kota di Jepang selama 7 hari adalah "+ max);
// Out:
// Masukkan suhu kota 1 hari ke 1 : 10
// Masukkan suhu kota 1 hari ke 2 : 11
// Masukkan suhu kota 1 hari ke 3 : 12
// Masukkan suhu kota 1 hari ke 4 : 13
// Masukkan suhu kota 1 hari ke 5 : 14
// Masukkan suhu kota 1 hari ke 6 : 15
// Masukkan suhu kota 1 hari ke 7 : 16
//
//  Masukkan suhu kota 2 hari ke 1 : 17
// Masukkan suhu kota 2 hari ke 2 : 18
// Masukkan suhu kota 2 hari ke 3 : 19
// Masukkan suhu kota 2 hari ke 4 : 20
// Masukkan suhu kota 2 hari ke 5 : 21
// Masukkan suhu kota 2 hari ke 6 : 22
// Masukkan suhu kota 2 hari ke 7 : 23
//
//  Masukkan suhu kota 3 hari ke 1 : 24
// Masukkan suhu kota 3 hari ke 2 : 25
// Masukkan suhu kota 3 hari ke 3 : 26
// Masukkan suhu kota 3 hari ke 4 : 27
// Masukkan suhu kota 3 hari ke 5 : 28
// Masukkan suhu kota 3 hari ke 6 : 29
// Masukkan suhu kota 3 hari ke 7 : 30
//
//  Masukkan suhu kota 4 hari ke 1 : 31
// Masukkan suhu kota 4 hari ke 2 : 32
// Masukkan suhu kota 4 hari ke 3 : 33
// Masukkan suhu kota 4 hari ke 4 : 34
// Masukkan suhu kota 4 hari ke 5 : 35
// Masukkan suhu kota 4 hari ke 6 : 36
// Masukkan suhu kota 4 hari ke 7 : 37
//
//  Masukkan suhu kota 5 hari ke 1 : 38
// Masukkan suhu kota 5 hari ke 2 : 39
// Masukkan suhu kota 5 hari ke 3 : 40
// Masukkan suhu kota 5 hari ke 4 : 41
// Masukkan suhu kota 5 hari ke 5 : 42
// Masukkan suhu kota 5 hari ke 6 : 43
// Masukkan suhu kota 5 hari ke 7 : 44
//
//  Suhu tertinggi dari 5 kota di Jepang selama 7 hari adalah 44.0

// %% [markdown]
// # 2. Terdapat hasil pencatatan data lima mahasiswa yang berisi informasi mengenai umur, berat badan (kg), dan tinggi badan (cm). Data tersebut disimpan ke dalam array dua dimensi.
// ![Gambar 13](images/tugas-2.PNG)
// *Keterangan: penyimpanan nilai dapat dilakukan melalui inisialisasi menggunakan operator assignment*
//  * Tampilkan *berat badan terendah* di antara kelima mahasiswa tersebut
//  * Tampilkan *rata-rata tinggi badan* dari kelima mahasiswa tersebut
//  * Tampilkan nama mahasiswa dengan *umur tertua* di antara kelima mahasiswa tersebut

// %%
// Tuliskan jawaban nomor 2
import java.util.Scanner;
Scanner sc = new Scanner(System.in);

int i,j;
int [][] dataMahasiswa = {{19,51,155},{18,55,163},{18,45,153},{20,46,158},{19,58,160}};
int min = 100;
int indeks;
int tua=0;
double totalTinggiBadan = 0;
double rataTinggiBadan = 0;
String[] nama = {"Desi", "Rofan", "Lala", "Beky", "Ega"};
for(i=0; i<dataMahasiswa.length; i++){
    for(j=0; j<dataMahasiswa[1].length; j++){
        if(dataMahasiswa[i][1] < min){
            min = dataMahasiswa[i][1];
        }
    }
}
for(i=0; i<dataMahasiswa.length; i++){
    for(j=0; j<dataMahasiswa[0].length; j++){
    if(j == 2)
        totalTinggiBadan += dataMahasiswa[i][j];
    }
}
for(i=0; i<dataMahasiswa.length; i++){
    for(j=0; j<dataMahasiswa[0].length; j++){
        if(dataMahasiswa[i][0] > tua){
            tua = dataMahasiswa[i][0];
            indeks = i;
        }
    }
}
System.out.println("Berat badan terendah mahasiswa yaitu\t\t\t\t\t : " + min);
rataTinggiBadan = totalTinggiBadan / dataMahasiswa.length;
System.out.println("Total tinggi badan\t\t\t\t\t\t\t : " + totalTinggiBadan);
System.out.println("Rata-rata tinggi badan dari kelima mahasiswa tersebut yaitu\t\t : " + rataTinggiBadan);
System.out.println("Umur tertua\t\t\t\t\t\t\t\t : " + tua);
System.out.println("Nama mahasiswa\t\t\t\t\t\t\t\t : " + nama[indeks]);
// Out:
// Berat badan terendah mahasiswa yaitu					 : 45
// Total tinggi badan							 : 789.0
// Rata-rata tinggi badan dari kelima mahasiswa tersebut yaitu		 : 157.8
// Umur tertua								 : 20
// Nama mahasiswa								 : Beky
