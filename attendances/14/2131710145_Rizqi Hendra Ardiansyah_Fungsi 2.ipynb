// %% [markdown]
// #### Nama : Rizqi Hendra Ardiansyah ####
// #### Kelas : MI-1E ####
// #### NIM    : 2131710145 ####
//
//
// # JOBSHEET 14. Fungsi 2

// %% [markdown]
// ## Tujuan
// * Mahasiswa memahami konsep fungsi rekursif
// * Mahasiswa mampu mengimplementasikan fungsi rekursif dalam kode program

// %% [markdown]
// ## Alat dan Bahan
// * PC/Laptop
// * Browser
// * Koneksi internet
// * Anaconda3 + Java kernel (opsional)

// %% [markdown]
// ## Praktikum

// %% [markdown]
// ### Percobaan 1
// Pada percobaan ini akan dilakukan pembuatan program untuk menghitung nilai faktorial dari suatu bilangan dengan menggunakan fungsi rekursif. Selain itu, akan dibuat juga fungsi untuk menghitung nilai faktorial dengan menggunakan algoritma iteratif sebagai pembandingnya
//
// 1. Buat fungsi static dengan nama **faktorialRekursif()**, dengan tipe data kembalian fungsi int dan memiliki 1 parameter dengan tipe data int berupa bilangan yang akan dihitung nilai faktorialnya
//
//     ![Gambar 1](images/code14-1.png)

// %%
// Tuliskan kode program Percobaan 1 Langkah 1
static int faktorialRekursif(int n) {
    if (n == 0) {
        return (1);
    } else {
        return (n * faktorialRekursif(n - 1));
    }
}

// %% [markdown]
// 2. Buat lagi fungsi static dengan nama **faktorialIteratif()**, dengan tipe data kembalian fungsi int dan memiliki 1 parameter dengan tipe data int berupa bilangan yang akan dihitung nilai faktorialnya.
//
//     ![Gambar 2](images/code14-2.png)

// %%
// Tuliskan kode program Percobaan 1 Langkah 2
static int faktorialIteratif(int n) {
    int faktor = 1;
    for (int i = n; i >= 1; i --) {
        faktor = faktor * i;
    }
    return faktor;
}

// %% [markdown]
// 3. Lakukan pemanggilan terhadap kedua fungsi yang telah dibuat sebelumnya, dan tampilkan hasil yang didapatkan.
//
//     ![Gambar 3](images/code14-3.png)

// %%
// Tuliskan kode program Percobaan 1 Langkah 1, 2, 3
static int faktorialRekursif(int n) {
    if (n == 0) {
        return (1);
    } else {
        return (n * faktorialRekursif(n - 1));
    }
}

static int faktorialIteratif(int n) {
    int faktor = 1;
    for (int i = n; i >= 1; i --) {
        faktor = faktor * i;
    }
    return faktor;
}

System.out.println(faktorialRekursif(5));
System.out.println(faktorialIteratif(5));
// Out:
// 120
// 120

// %% [markdown]
// 4. Jika ditelusuri, pada saat pemanggilan fungsi faktorialRekursif(5),maka proses yang terjadi dapat diilustrasikan sebagai berikut:
//
//     ![Gambar 4](images/code14-4.png)

// %% [markdown]
// #### Pertanyaan
// 1. Apa yang dimaksud dengan fungsi rekursif?
// 2. Bagaimana contoh kasus penggunaan fungsi rekursif ?
// 3. Pada Percobaan1, apakah hasil yang diberikan fungsi faktorialRekursif() dan fungsi faktorialIteratif() sama? Jelaskan perbedaan alur jalannya program pada penggunaan fungsi rekursif dan fungsi iteratif!
//
// #### Jawab
// 1. Fungsi rekursif adalah fungsi  yang memanggil secara berulang-ulang sampai ada kondisi yang menghentikannya. Fungsi rekursif sering dipakai ketika ada kasus yang membutuhkan perulangan contohnya seperti faktorial.
// 2. Contoh kasus penggunaan fungsi rekursif yaitu saat menghitung nilai dari faktorial, perpangkatan, dan lain-lain.
// 3. Tidak sama, karena jika kita menggunakan fungsi faktorialrekursif yang akan dilakuan adalah pemilihan yang menentukan apakah nilai n = 0 jika iya maka akan mengembalikan nilai 1, tetapi jika tidak maka nilai n akan dikalikan dengan hasil faktorial n - 1. Lalu jika kita menggunakan fungsi faktorialIteratif maka menggunakan perulangan for, dalam kasus program diatas jika i >= n dan i -- , maka akan menghitung nilai dari faktorial sampai perulangan tersebut berhenti. Lalu faktorial akan dikembalikan ke dalam fungsi faktorialIteratif.

// %% [markdown]
// ### Percobaan 2
// Pada percobaan ini akan dilakukan pembuatan program untuk menghitung pangkat sebuah bilangan dengan menggunakan fungsi rekursif.

// %% [markdown]
// 1. Buat fungsi static dengan nama **hitungPangkat()**, dengan tipe data kembalian fungsi int dan memiliki 2 parameter dengan tipe data int berupa bilangan yang akan dihitung pangkatnya dan bilangan pangkatnya
//
//     ![Gambar 5](images/code14-5.png)

// %% [markdown]
// 2.	Deklarasikan Scanner dengan nama sc
// 3.	Buatlah dua buah variabel bertipe int dengan nama bilangan dan pangkat
// 4.	Tambahkan kode berikut ini untuk menerima input dari keyboard
//
//     ![Gambar 6](images/code14-6.png)
//
// 5. Lakukan pemanggilan fungsi hitungPangkat yang telah dibuat sebelumnya dengan mengirimkan dua nilai parameter.
//
//     ![Gambar 7](images/code14-7.png)

// %%
// Tuliskan kode program Percobaan 2 Langkah 1 - 5
static int hitungPangkat (int x, int y) {
    if (y == 0) {
        return (1);
    } else {
        return (x * hitungPangkat(x, y - 1));
    }
}

import java.util.Scanner;
Scanner sc = new Scanner (System.in);
int bilangan, pangkat;
System.out.print("Bilangan yang dihitung: ");
bilangan = sc.nextInt();
System.out.print("Pangkat: ");
pangkat = sc.nextInt();
System.out.println(hitungPangkat(bilangan, pangkat));
// Out:
// Bilangan yang dihitung: 8
// Pangkat: 2
// 64

// %% [markdown]
// #### Pertanyaan
// 1. Pada Percobaan2, terdapat pemanggilan fungsi rekursif hitungPangkat(bilangan, pangkat) pada fungsi main, kemudian dilakukan pemanggilan fungsi hitungPangkat() secara berulangkali. Jelaskan sampai kapan proses pemanggilan fungsi tersebut akan dijalankan!
//
// #### Jawab
//
// 1. Pada proses pemanggilan fungsi akan dijalankan terus menerus selama y tidak sama dengan 0 dan akan berhenti sampai y = 0

// %% [markdown]
// ### Percobaan 3
// Pada percobaan ini akan dilakukan pembuatan program untuk menghitung jumlah uang nasabah yang disimpan di Bank setelah mendapatkan bunga selama beberapa tahun dengan menggunakan fungsi rekursif.
//
// 1. Buat fungsi static dengan nama **hitungBunga()**, dengan tipe data kembalian fungsi double dan memiliki 2 parameter dengan tipe  data int berupa saldo nasabah dan lamanya menabung. Pada kasus ini dianggap bunga yang ditentukan oleh bank adalah 11% per tahun. Karena perhitungan bunga adalah bunga * saldo, sehingga untuk menghitung besarnya uang setelah ditambah bunga adalah saldo + bunga * saldo. Dalam hal ini, besarnya bunga adalah 0.11 * saldo, dan saldo dianggap 1 * saldo, sehingga 1 * saldo + 0.11 * saldo dapat diringkas menjadi 1.11 * saldo untuk perhitungan saldo setelah ditambah bunga (dalam setahun).
//
//     ![Gambar 8](images/code14-8.png)

// %% [markdown]
// 2.	Deklarasikan Scanner dengan nama sc
// 3.	Buatlah sebuah variabel bertipa double dengan nama saldoAwal dan sebuah variabel bertipe int bernama tahun
// 4.	Tambahkan kode berikut ini untuk menerima input dari keyboard
//
//  ![Gambar 9](images/code14-9.png)

// %% [markdown]
// 5. Lakukan pemanggilan fungsi hitungBunga yang telah dibuat sebelumnya dengan mengirimkan dua nilai parameter.
//
//     ![Gambar 10](images/code14-10.png)

// %%
// Tuliskan kode program Percobaan 3 Langkah 1 - 5
static double hitungBunga(double saldo, int tahun) {
    if (tahun == 0) {
        return (saldo);
    } else {
        return (1.11 * hitungBunga(saldo, tahun - 1));
    }
}

import java.util.Scanner;
Scanner sc = new Scanner (System.in);
double saldoAwal;
int tahun;

System.out.print("Jumlah saldo awal: ");
saldoAwal = sc.nextInt();
System.out.print("Lamanya menabung (tahun): ");
tahun = sc.nextInt();
System.out.println("Jumlah uang setelah " + tahun + " tahun: ");
System.out.println(hitungBunga(saldoAwal, tahun));
// Out:
// Jumlah saldo awal: 5000
// Lamanya menabung (tahun): 2
// Jumlah uang setelah 2 tahun:
// 6160.500000000002

// %% [markdown]
// #### Pertanyaan
// 1. Pada Percobaan3, sebutkan blok kode program manakah yang merupakan “base case” dan “recursion call”!
//
// ####  Jawab
//
// 1. base case : (tahun == 0)
//    recursion call : (1.11 * hitungBunga(saldo, tahun))

// %% [markdown]
// ## Tugas

// %% [markdown]
// 1. Buatlah program untuk menampilkan bilangan n sampai 0 dengan menggunakan fungsi rekursif dan fungsi iteratif. (**DeretDescendingRekursif**).

// %%
// Tuliskan jawaban tugas nomor 1
// fungsi rekursif
static int deretDescendingRekursif(int n){
    if(n==0){
        return 0;
    }else{
        System.out.print(n + " - ");
        return deretDescendingRekursif(n-1);
    }
}

// fungsi iteratif
static int deretDescendingIteratif(int n){
    int deretIteratif=0;
    for(int i=n; i>0; i--){
        System.out.print(i + " - ");
    }
    return deretIteratif;
}

import java.util.Scanner;
Scanner sc = new Scanner(System.in);
System.out.print("Masukkan sebuah bilangan yang diinginkan: ");
int angka = sc.nextInt();
System.out.println("=----------------------------------------=");
System.out.println("\nFungsi Rekursif :");
System.out.println(deretDescendingRekursif(angka));
System.out.println("\nFungsi Iteratif :");
System.out.print(deretDescendingIteratif(angka));
// Out:
// Masukkan sebuah bilangan yang diinginkan: 6
// =----------------------------------------=
//
// Fungsi Rekursif :
// 6 - 5 - 4 - 3 - 2 - 1 - 0
//
// Fungsi Iteratif :
// 6 - 5 - 4 - 3 - 2 - 1 - 0

// %% [markdown]
// 2. Buatlah program yang di dalamnya terdapat fungsi rekursif untuk menghitung bilangan faktorial. Misalniya f = 8, maka akan dihasilkan 1+2+3+4+5+6+7+8 = 36 (**PenjumlahanRekursif**).

// %%
// Tuliskan jawaban tugas nomor 2
import java.util.Scanner;
Scanner sc = new Scanner(System.in);

int n, hasil;
System.out.print("Masukkan nilai yang ingin dihitung penjumlahan: ");
n = sc.nextInt();
System.out.println("=-------------------------------------------=");
int a = 1;

static int PenjumlahanRekursif(int awal, int nilai){
    if(awal == nilai){
        System.out.print(nilai);
        return nilai;
    }else{
        System.out.print( awal + " + ");
        return (awal + PenjumlahanRekursif((awal + 1), nilai));
    }
}

hasil = PenjumlahanRekursif(a, n);
System.out.println(" = " + hasil);
// Out:
// Masukkan nilai yang ingin dihitung penjumlahan: 7
// =-------------------------------------------=
// 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28

// %% [markdown]
// 3.	Buat program yang di dalamnya terdapat fungsi rekursif untuk mengecek apakah suatu bilangan n merupakan bilangan prima atau bukan. n dikatakan bukan bilangan prima jika ia habis dibagi dengan bilangan kurang dari n. (**CekPrimaRekursif**).

// %%
// Tuliskan jawaban tugas nomor 3
Scanner sc = new Scanner(System.in);
static void cekPrimaRekursif(int x,int y){
    if (y==1){
        System.out.println("Bilangan Prima");
    }else if(x%y==0){
        System.out.println("Bukan Bilangan Prima");
    }else{
        cekPrimaRekursif(x,y-1);
    }
}
System.out.print ("Masukkan sebuah bilangan yang diinginkan : ");
int n = sc.nextInt();
cekPrimaRekursif(n,n-1);
// Out:
// Masukkan sebuah bilangan yang diinginkan : 5
// Bilangan Prima

// %% [markdown]
// 4.	Sepasang marmut yang baru lahir (jantan dan betina) ditempatkan pada suatu pembiakan.  Setelah dua bulan pasangan marmut tersebut melahirkan sepasang marmut kembar (jantan dan betina). Setiap pasangan marmut yang lahir juga akan melahirkan sepasang marmut juga setiap 2 bulan.  Berapa pasangan marmut yang ada pada akhir bulan ke-12? Buatlah programnya menggunakan fungsi rekursif! (**Fibonacci**).
// Berikut ini adalah ilustrasinya dalam bentuk tabel.
//
//  ![Gambar 11](images/code14-11.PNG)

// %%
// Tuliskan jawaban tugas nomor 4
Scanner sc = new Scanner(System.in);
static int fibonacci(int n)  {
    if(n < 2){
        return n;
    }
    else{ 
        return fibonacci(n - 1) + fibonacci(n - 2);
    }
}
System.out.print ("Masukkan bulan : ");
int n = sc.nextInt();
System.out.println("Pada bulan ke-"+n+" terdapat "+fibonacci(n)+" total pasangan Marmut");
// Out:
// Masukkan bulan : 6
// Pada bulan ke-6 terdapat 8 total pasangan Marmut
