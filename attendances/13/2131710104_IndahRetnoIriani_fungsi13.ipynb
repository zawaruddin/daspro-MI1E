// %% [markdown]
// # JOBSHEET 13. Fungsi 1
// ### Nama : Indah Retno Iriani
// ### NIM : Indah Retno Iriani
// ### Kelas : MI1E

// %% [markdown]
// ## Tujuan
// * Mahasiswa mampu memahami penggunaan fungsi static pada Java dengan parameter dan mengembalikan nilai.
// * Mahasiswa mampu membuat program menggunakan fungsi static dan mengeksekusi fungsi tersebut.

// %% [markdown]
// ## Alat dan Bahan
// * PC/Laptop
// * Browser
// * Koneksi internet
// * Anaconda3 + Java kernel (opsional)

// %% [markdown]
// ## Praktikum

// %% [markdown]
// ### Percobaan 1: Fungsi Void (tidak menggunakan return value)
//
// 1.	Buat fungsi **beriSalam** bertipe void yang digunakan untuk mencetak **“Halo! Selamat Pagi”**.
// ![Gambar 1](images/1.1.png)

// %% [markdown]
// 2. Eksekusi atau panggil fungsi **beriSalam**.
// ![Gambar 2](images/1.2.png)

// %%
// Tuliskan kode program Percobaan 1 Langkah 1 & 2
static void beriSalam(){
    System.out.println("Halo! Selamat Pagi");
}
static void beriSalam(){
    System.out.println("Halo! Selamat Pagi");
}
beriSalam();
// Out:
// Halo! Selamat Pagi

// %% [markdown]
// 3. Buat fungsi **beriUcapan** dengan sebuah parameter bertipe String.
// ![Gambar 3](images/1.3.png)

// %% [markdown]
// 4. Buatlah variabel **salam** bertipe String kemudian eksekusi atau panggil fungsi **beriUcapan** dengan mengisi parameternya dengan variable **salam** yang sudah dibuat.
// ![Gambar 3](images/1.4.png)

// %%
// Tuliskan kode program Percobaan 1 Langkah 1, 2, 3 & 4
static void beriSalam(){
    System.out.println("Halo! Selamat Pagi");
}
static void beriSalam(){
    System.out.println("Halo! Selamat Pagi");
}
beriSalam();
static void beriSalam(){    
}
static void beriUcapan(String ucapan){
    System.out.println(ucapan);
}
beriSalam();
String salam = "Selamat datang di pemrograman Java";
beriUcapan(salam);
// Out:
// Halo! Selamat Pagi
// Selamat datang di pemrograman Java

// %% [markdown]
// #### Pertanyaan
// 1. Jelaskan perbedaan fungsi **beriSalam** dan **beriUcapan** pada praktikum 1!

// %% [markdown]
// 2. Jelaskan cara pemanggilan sebuah fungsi void yang berparameter dan tanpa parameter!

// %% [markdown]
// ### Jawab
//
// 1. Perbedaan fungsi beriSalam dan beriUcapan adalah fungsi beriSalam di deklarasikan dulu baru di panggil atau dieksekusi
// sedangkan fungsi beriUcapan menampung nilai terlebih dahulu dengan menggunakan parameter bertipe data string yang berperan sebagai input dalam fungsi sebelum di panggil atau dieksekusi.
//
// 2. cara pemanggilan fungsi void yang berparameter harus diberikan tipe data dan harus di deklarasikan terlebih dahulu untuk
// memanggil nilai nya fungsi tanpa parameter tidak perlu dideklarasikan terlebih dahulu

// %% [markdown]
// ### Percobaan 2: Fungsi dengan return value (Bukan void)
// Pada Percobaan 2, kode program yang dibuat digunakan untuk menghitung luas persegi dengan membuat fungsi **luasPersegi** yang menggunakan parameter.
// 1. Buat fungsi **luasPersegi**  untuk menghitung luas persegi yang mengembalikan nilai luas (int) dan parameter masukan sisi (int).
// ![Gambar 4](images/2.1.png)

// %% [markdown]
// 2.	Eksekusi atau panggil fungsi luasPersegi dengan cara membuat variabel baru yaitu **luasan**, kemudian isi variabel tersebut dengan memanggil fungsi luasPersegi dan mengisi parameter sisi. Selanjutnya cetak variabel luasan untuk menampilkan luas persegi panjang
// ![Gambar 5](images/2.2.png)

// %%
// Tuliskan kode program Percobaan 2 Langkah 1 & 2
static int luasPersegi(int sisi){
    int luas = sisi*sisi;
    return luas;
}
static int luasPersegi(int sisi){
    int luas = sisi*sisi;
    return luas;
}
int luasan = luasPersegi(5);
System.out.println("Luas Persegi dengan sisi 5 = "+luasan);
// Out:
// Luas Persegi dengan sisi 5 = 25

// %% [markdown]
// #### Pertanyaan
// 1. jelaskan mengapa ketika memanggil fungsi **luasPersegi** harus membuat variabel baru yaitu luasan?

// %% [markdown]
// 2. Jelaskan kegunaan **return luas** pada percobaan 2 diatas!

// %% [markdown]
// 3. Modifikasilah program di percobaan 2, dengan membuat panjang **sisi** sebagai inputan!

// %% [markdown]
// ### Jawab
// 1. karena variabel luasan diperlukan saat menghitung nilai luas persegi sisi * sisi
// 2. pengembalian nilai pada fungsi untuk diolah ke fungsi berikutnya

// %%
//Percobaan 2 Jawaban nomor 3
static int luasPersegi(int sisi1, int sisi2){
    int luas = sisi1*sisi2;
    return luas;
}
int luasan = luasPersegi(5,7);
System.out.println("Luas Persegi dengan sisi 5 = "+luasan);
// Out:
// Luas Persegi dengan sisi 5 = 35

// %% [markdown]
// ### Percobaan 3: Fungsi dapat meng-CALL Fungsi Lain
// Pada Percobaan 3, kode program yang dibuat digunakan untuk mengimplementasikan bahwa fungsi dapat meng-CALL fungsi yang lain. Dimana dalam percobaan ini terdapat fungsi **Kali dan Kurang**.
// 1. Buatlah fungsi **Kali** yang mengembalikan nilai H (int) dan parameter masukan C dan D (int).
// ![Gambar 9](images/3.1.png)

// %% [markdown]
// 2.	Buatlah fungsi **Kurang** yang mengembalikan nilai X (int) dan parameter masukan A dan B (int) dan memanggil fungsi Kali.
// ![Gambar 10](images/3.2.png)

// %% [markdown]
// 3. Lakukan import class Scanner sebagai inputan di langkah selajutnya.

// %% [markdown]
// 4. Eksekusi atau panggil fungsi **Kurang** .
// ![Gambar 11](images/3.4.png)

// %%
// Tuliskan kode program Percobaan 3 Langkah 1, 2, 3 & 4
static int Kali(int C, int D){
    int H;
    H = (C + 10) % (D + 19);
    return H;
}
static int Kurang(int A, int B){
    int X;
    A = A + 7;
    B = B + 4;
    X = Kali(A, B);
    return X;
}
int nilai1, nilai2;
Scanner input = new Scanner (System.in);
System.out.println("Masukkan Nilai 1 : ");
nilai1 = input.nextInt();
System.out.println("Masukkan Nilai 2: ");
nilai2 = input.nextInt();
int hasil = Kurang(nilai1, nilai2);
System.out.println("Hasil akhir adalah " + hasil);
// Out:
// Masukkan Nilai 1 :
// 2
// Masukkan Nilai 2:
// 3
// Hasil akhir adalah 19

// %% [markdown]
// #### Pertanyaan
// 1. Modifikasilah percobaan diatas dimana di fungsi **Kali** dapat memanggil fungsi **Kurang** kemudian eksekusi atau panggil fungsi Kali

// %%
// Tuliskan jawaban nomor 1
static int Kurang(int C, int D){
    int H;
    H = (C + 10) % (D + 19);
    return H;
}
static int Kali(int A, int B){
    int X;
    A = A + 7;
    B = B + 4;
    X = Kali(A, B);
    return X;
}
int nilai1, nilai2;
Scanner input = new Scanner (System.in);
System.out.println("Masukkan Nilai 1 : ");
nilai1 = input.nextInt();
System.out.println("Masukkan Nilai 2: ");
nilai2 = input.nextInt();
int hasil = Kurang(nilai1, nilai2);
System.out.println("Hasil akhir adalah " + hasil);
// Out:
// Masukkan Nilai 1 :
// 2
// Masukkan Nilai 2:
// 3
// Hasil akhir adalah 12

// %% [markdown]
// 2. Jelaskan alur jalannya program di percobaan 3 mulai dari input sampai keluar output!
// Jawab : Melakukan inisialisasi nilai1 dan nilai 2 sebagai input yang akan di operasikan. Selanjutnya variabel hasil memanggil fungsi Kurang dengan parameter dari 2 inputan sebelumnya. dan di fungsi kurang akan dilakukan operasi nilai1 sebagai A ditambah 7, dan nilai2 sebagai B ditambah dengan 4. lalu X digunakan memnaggil fungsi kali dengan parameter.

// %% [markdown]
// ### Percobaan 4: Mengubah Program Tidak Menggunakan Fungsi dan Menggunakan Fungsi
// Pada Percobaan 4, kode program yang dibuat digunakan untuk menghitung luas persegi panjang dan volume balok tanpa menggunakan fungsi dan dengan menggunakan fungsi.
// 1. Import dan deklarasikan Scanner dengan nama **input**
// ![Gambar 9](images/4.1.png)

// %% [markdown]
// 2. Buatlah inputan panjang, lebar, dan tinggi
// ![Gambar 10](images/4.2.png)

// %% [markdown]
// 3. Hitung luas persegi panjang dan volume balok
// ![Gambar 10](images/4.3.png)

// %%
// Tuliskan kode program Percobaan 4 Langkah 1, 2, & 3
import java.util.Scanner;
Scanner input = new Scanner(System.in);

int p, l, t, L, vol;
 
System.out.print("Masukkan panjang: ");
p = input.nextInt();
System.out.print("Masukkan lebar: ");
l = input.nextInt();
System.out.print("Masukkan tinggi: ");
t = input.nextInt();

L = p*l;
System.out.println("Luas Persegi panjang adalah "+L);

vol = p*l*t;
System.out.println("Volume valok adalah "+vol);
// Out:
// Masukkan panjang: 8
// Masukkan lebar: 5
// Masukkan tinggi: 3
// Luas Persegi panjang adalah 40
// Volume valok adalah 120

// %% [markdown]
// 4. Program menghitung luas persegi dan volume balok diatas jika dibuatkan fungsi maka terdapat 3 fungsi yaitu hitungLuas, hitungVolume dan fungsi main, seperti dibawah ini:
//
// Fungsi hitungLuas
//
// ![Gambar 10](images/4.4Luas.png)
//
// Fungsi hitungVolume
// ![Gambar 10](images/4.4Volume.png)

// %% [markdown]
// 5. Eksekusi/panggil fungsi **hitungLuas** dan **hitungVolume**
//
// ![Gambar 10](images/4.5.png)

// %%
// Tuliskan kode program Percobaan 4 Langkah 1, 2, & 3
static int hitungLuas (int pjg, int lb){
    int Luas = pjg * lb;
    return Luas;
}

static int hitungVolume (int tinggi, int a, int b){
    int volume = hitungLuas(a, b)*tinggi;
    return volume;
}
Scanner input = new Scanner (System.in);
int p, l, t, L, vol;
System.out.print("Masukkan panjang : ");
p = input.nextInt();
System.out.print("Masukkan lebar : ");
l = input.nextInt();
System.out.print("Masukkan tinggi : ");
t = input.nextInt();

L = hitungLuas(p, l);
System.out.println("Luas persegi panjang adalah : " + L);
    vol = hitungVolume(t, p, l);
                   System.out.println("Volume Balok adalah "+ vol);
// Out:
// Masukkan panjang : 8
// Masukkan lebar : 7
// Masukkan tinggi : 3
// Luas persegi panjang adalah : 56
// Volume Balok adalah 168

// %% [markdown]
// #### Pertanyaan
// 1. Jelaskan kegunaan parameter yang terdapat didalam fungsi hitungLuas dan hitungVolume!

// %% [markdown]
// 2. Setelah melakukan percobaan 4, menurut anda manakah program yg lebih efisien apakah menggunakan fungsi atau tanpa fungsi? Jelaskan!

// %% [markdown]
// ### Jawab
// 1. Parameter pada fungsi hitungLuas berguna untuk tempat memasukkan data yang akan diolah pada fungsi hitungLuas dimana untuk menghitung luas diperlukan data panjang dan lebar. Parameter pada fungsi hitungVolume berguna untuk menampung atau memasukkan nilai yang akan digunakan untuk menghitung volume.
//
// 2. Untuk operasi yang membutuhkan banyak inputan lebih efisien menggunakan fungsi

// %% [markdown]
// ### Percobaan 5: Fungsi Menggunakan Array dan Variabel Global
// Pada Percobaan 5, kode program yang dibuat digunakan untuk menghitung total nilai yang ada didalam array dengan membuat 3 fungsi yaitu isiarray, hitTol, dan tampilArray.
// 1. Buatlah **variable global total dan i** bertipe int
// ![Gambar 9](images/5.1pertama.png)

// %% [markdown]
// 2. Buatlah fungsi **isiarray** bertipe int dengan parameter angka bertipe int
//
// ![Gambar 10](images/5.1.png)

// %% [markdown]
// 3. Buatlah fungsi **tampilArray** bertipe **void** dengan parameter data array **arr** bertipe int
//
// ![Gambar 10](images/5.2.png)

// %% [markdown]
// 4. Buatlah fungsi **hitTot** bertipe int dengan parameter data array **arr** bertipe int
//
// ![Gambar 10](images/5.3.png)

// %% [markdown]
// 5. Import dan deklarasikan Scanner dengan nama **input**
//
// ![Gambar 10](images/4.1.png)

// %% [markdown]
// 6. Eksekusi atau panggil ketiga fungsi yaitu **isiarray, tampilArray, dan hitTot**, kemudian jalankan program!
//
// ![Gambar 10](images/5.6.png)

// %%
// Tuliskan kode program Percobaan 4 Langkah 1 s/d 6
static int total = 0, i;
static int [] isiarray (int angka){
Scanner input = new Scanner (System.in);
int array[] = new int [angka];
for (i = 0; i<array.length; i++){
System.out.println("Masukkan data ke- "+i);
array[i]=input.nextInt();
}
return array;
}
static void tampilArray(int [] arr){
for(i = 0; i<arr.length; i++){
System.out.print("Nilai yang Anda inputkan ke "+i);
System.out.println(arr[i]);
}
}

static int hitTot(int []arr){
for(i = 0; i<arr.length; i++){
total += arr[i];
}
return total;
}
System.out.println("Masukkan jumlah data yang ingin Anda inputkan: ");
int jum = input.nextInt();
int []dataArray = isiarray(jum);
tampilArray(dataArray);
total = hitTot(dataArray);
System.out.println("Total nilai = "+total);
// Out:
// Masukkan jumlah data yang ingin Anda inputkan:
// 11
// Masukkan data ke- 0
// 34
// Masukkan data ke- 1
// 31
// Masukkan data ke- 2
// 2
// Masukkan data ke- 3
// 3
// Masukkan data ke- 4
// 4
// Masukkan data ke- 5
// 5
// Masukkan data ke- 6
// 6
// Masukkan data ke- 7
// 7
// Masukkan data ke- 8
// 8
// Masukkan data ke- 9
// 9
// Masukkan data ke- 10
// 12
// Nilai yang Anda inputkan ke 034
// Nilai yang Anda inputkan ke 131
// Nilai yang Anda inputkan ke 22
// Nilai yang Anda inputkan ke 33
// Nilai yang Anda inputkan ke 44
// Nilai yang Anda inputkan ke 55
// Nilai yang Anda inputkan ke 66
// Nilai yang Anda inputkan ke 77
// Nilai yang Anda inputkan ke 88
// Nilai yang Anda inputkan ke 99
// Nilai yang Anda inputkan ke 1012
// Total nilai = 121

// %% [markdown]
// ### Pertanyaan
// 1. Jelaskan mengapa fungsi tampil array dibuat bertipe void, sedangkan isiarray dan hitTot bertipe int!

// %% [markdown]
// 2. Menurut pendapat anda apakah fugsi isiarray dan hitTot dapat diganti dengan tipe void? Jelaskan dan buktikan dengan program!

// %% [markdown]
// ### Jawab
// 1. karena output isiarray dan hitTot harus dikembalikan karena akan digunakan untuk operasi selanjutnya. sedangkan fungsi tampil array hanya inputan nilai sehingga tidak perlu dikembalikan jadi menggunakan tipe void.

// %%
// Tuliskan jawaban nomor 2
static int total = 0,i;
static void[] isiArray (int angka){
   Scanner input = new Scanner(System.in);
    int[] array = new int[angka];
    for(int i=0; i<array.length; i++){
        System.out.println("Masukkan data ke-" + i);
        array[i]= input.nextInt();
    }
}

static void tampilArray(int [] arr){
    for (int i = 0; i<arr.length; i++){
        System.out.println("Nilai yang anda inputkan ke " + i);
        System.out.println(arr[i]);
    }
}

static void hitTot(int []arr){
    for (int i=0; i<arr.length; i++){
        total+=arr[i];
    }
}

import java.util.Scanner;
Scanner input = new Scanner(System.in);

System.out.println("Masukkan jumlah data yang ingin anda inputkan: ");
int jum=input.nextInt();

int[] dataArray = isiArray(jum);
tampilArray(dataArray);
total= hitTot(dataArray);
System.out.println("Total nilai = "+ total); 
//terjadi error karena isiarray dan hitTot akan dikembalikan untuk operasi berikutnya
// Out:
// |   static void[] isiArray (int angka){
// illegal start of expression
//
// |   static void[] isiArray (int angka){
// ';' expected
//
// |   static void[] isiArray (int angka){
// '.class' expected
//
// |   static void[] isiArray (int angka){
// ';' expected
//
// |   static void[] isiArray (int angka){
// unexpected type
//   required: value
//   found:    class
//
// |       int[] array = new int[angka];
// cannot find symbol
//   symbol:   variable angka

// %% [markdown]
// ## Tugas

// %% [markdown]
// 1. Buatlah sebuah static method yang bernama Max3(int bil1, int bil2, int bil3) yang menerima 3 buah parameter bilangan integer dan mengembalikan sebuah bilangan integer yang merupakan nilai maksimum diantara ketiga bilangan tersebut.

// %%
// Tuliskan jawaban nomor 1
import java.util.Scanner;
Scanner input = new Scanner(System.in);

int a, b, c;
System.out.print("Masukkan bilangan 1: ");
a = input.nextInt();
System.out.print("Masukkan bilangan 2: ");
b = input.nextInt();
System.out.print("Masukkan bilangan 3: ");
c = input.nextInt();

static int Max3(int bil1, int bil2, int bil3){
    if ( bil1 > bil2 &&  bil1 > bil3){
        hasil = bil1;
    }else if(bil2 >  bil1 && bil2 > bil3){
        hasil = bil2;
    }else if(bil3 >  bil1 && bil3 > bil2){
        hasil = bil3;
    }
    return hasil;
}
int hasil = Max3(a, b, c);
System.out.print("Nilai  maksimal diantara ketiga bilangan adalah: " + hasil);
// Out:
// Masukkan bilangan 1: 9
// Masukkan bilangan 2: 1
// Masukkan bilangan 3: 8
// Nilai  maksimal diantara ketiga bilangan adalah: 9

// %% [markdown]
// 2. Disebuah restoran terdapat 3 menu yang dijual yaitu nasi goreng, soto, dan sate. Harga nasi goreng Rp. 20.000, soto Rp. 15.000, dan sate Rp. 25.000. Restoran tersebut buka dari hari senin sampai jumat. Berikut ini merupakan tabel pejualan perhari untuk masing-masing menu di restoran tersebut dari hari senin sampai jumat
// ![Gambar 13](images/soal3.png)
//
// Buatlah Fungsi sebagai berikut:
//  * Fungsi menampilkan menu favorit di hari selasa dan jumat (menu favorit diasumsikan adalah menu yang paling banyak terjual di hari tersebut)
//  * Fungsi untuk menghitung pemasukan restoran tersebut mulai hari senin sampai jumat.
//  * Fungsi untuk menghitung berapa porsi yang terjual untuk masing-masing menu yaitu nasi goreng, soto, dan sate mulai senin sampai jumat.

// %%
// Tuliskan jawaban nomor 2
int[][] dataJual = {
    {20, 15, 35, 24, 70},
    {30, 40, 10, 28, 35},
    {5, 10, 50, 48, 15},
};
String[] dataHari = {"Senin", "Selasa", "Rabu", "Kamis", "Jumat"};
String[] dataMenu = {"Nasi Goreng", "Soto", "Sate"};
String menu, hari;
int total;
static void menuFavorit(){
    for(int i = 1; i < dataJual[0].length; i += 3){
        int maks = 0;
        for(int j = 0; j < dataJual.length; j++){
            if (dataJual[j][i] > maks){
                maks = dataJual[j][i];
                menu = dataMenu[j];
                hari = dataHari[i];
            }           
        }
        System.out.println("Masakan favorit hari " + hari + " adalah " + menu);
    }
}
static void pemasukan(){
    for(int i = 0; i < dataJual.length; i++){
        int totalJual = 0, totalHarga = 0;
        for(int j = 0; j < dataJual[0].length; j++){
            totalJual += dataJual[i][j];
            if(i == 0){
                totalHarga = totalJual * 20000;
            }else if(i == 1){
                totalHarga = totalJual * 15000;
            }else{
                totalHarga = totalJual * 25000;
            }
        }
        total += totalHarga;
    }
    System.out.println("Total pemasukan dari hari Senin sampai hari Jumat adalah Rp" + total);
}
static void jumlahPorsi(){
    for(int i = 0; i < dataJual.length; i++){
        int totalJual = 0, totalHarga = 0;
        for(int j = 0; j < dataJual[0].length; j++){
            totalJual += dataJual[i][j];
        }
        menu = dataMenu[i];
        System.out.println(menu + " yang terjual adalah: " + totalJual + " porsi");
    }
}
menuFavorit();
pemasukan();
jumlahPorsi();
// Out:
// Masakan favorit hari Selasa adalah Soto
// Masakan favorit hari Jumat adalah Nasi Goreng
// Total pemasukan dari hari Senin sampai hari Jumat adalah Rp8625000
// Nasi Goreng yang terjual adalah: 164 porsi
// Soto yang terjual adalah: 143 porsi
// Sate yang terjual adalah: 128 porsi
